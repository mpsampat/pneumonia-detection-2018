# %% [markdown]
# **Mask-RCNN Sample Starter Model for the RSNA Pneumonia Detection Challenge**
#
# [MD.ai](https://www.md.ai). The dataset for this challenge, created on the MD.ai platform in collaboration with the Radiological Society of North America (RSNA), the Society of Thoracic Radiology (STR), the US National Institutes of Health (NIH), and Kaggle.
# This notebook covers the basics of parsing the competition dataset, training using a detector basd on the [Mask-RCNN algorithm](https://arxiv.org/abs/1703.06870) for object detection and instance segmentation.
# **Note that the Mask-RCNN detector configuration parameters have been selected to reduce training time for demonstration purposes, they are not optimal.
# **
#
# This is based on our deep learning for medical imaging lessons:
#
# - Lesson 1. Classification of chest vs. adominal X-rays using TensorFlow/Keras [Github](https://github.com/mdai/ml-lessons/blob/master/lesson1-xray-images-classification.ipynb) [Annotator](https://public.md.ai/annotator/project/PVq9raBJ)
# - Lesson 2. Lung X-Rays Semantic Segmentation using UNets. [Github](https://github.com/mdai/ml-lessons/blob/master/lesson2-lung-xrays-segmentation.ipynb)
# [Annotator](https://public.md.ai/annotator/project/aGq4k6NW/workspace)
# - Lesson 3. RSNA Pneumonia detection using Kaggle data format [Github](https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-kaggle.ipynb) [Annotator](https://public.md.ai/annotator/project/LxR6zdR2/workspace)
# - Lesson 3. RSNA Pneumonia detection using MD.ai python client library [Github](https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-mdai-client-lib.ipynb) [Annotator](https://public.md.ai/annotator/project/LxR6zdR2/workspace)
#
# *Copyright 2018 MD.ai, Inc.
# Licensed under the Apache License, Version 2.0*

# %%
import os 
import sys
import random
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt
import json
import pydicom
from imgaug import augmenters as iaa
from tqdm import tqdm
import pandas as pd 
import glob

# %% [markdown]
# ### First: Install Kaggle API for download competition data.

# %%
DATA_DIR = '../input'

# Directory to save logs and trained model
ROOT_DIR = '../working_copy2'

# %% [markdown]
# ###  MD.ai Annotator
#
# Additionally, If you are interested in augmenting the existing annotations, you can use the MD.ai annotator to view DICOM images, and create annotatios to be exported.
# MD.ai annotator project URL for the Kaggle dataset: https://public.md.ai/annotator/project/LxR6zdR2/workspace
#
# **Annotator features**
# - The annotator can be used to view DICOM images and create image and exam level annotations.
# - You can apply the annotator to filter by label, adjudicate annotations, and assign annotation tasks to your team.
# - Notebooks can be built directly within the annotator for rapid model development.
# - The data wrangling is abstracted away by the interface and by our MD.ai library.
# - Simplifies image annotation in order to widen the participation in the futrue of medical image deep learning.
#
# The annotator allows you to create initial annotations, build and run models, modify/finetune the annotations based on predicted values, and repeat.
# The MD.ai python client library implements functions to easily download images and annotations and to prepare the datasets used to train the model for classification. See the following example notebook for parsing annotations and training using MD.ai annotator:
# https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-mdai-client-lib.ipynb
# - MD.ai URL: https://www.md.ai
# - MD.ai documentation URL: https://docs.md.ai/

# %% [markdown]
# ### Install Matterport's Mask-RCNN model from github.
# See the [Matterport's implementation of Mask-RCNN](https://github.com/matterport/Mask_RCNN).

# %%
#!git clone https://www.github.com/matterport/Mask_RCNN.git
#os.chdir('Mask_RCNN')
##!python setup.py -q install

# %%
# Import Mask RCNN
sys.path.append(os.path.join("/home/mehul/kaggle/pneumonia-detection-2018", 'Mask_RCNN'))  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log
# Out:
# Using TensorFlow backend.

# %%
train_dicom_dir = os.path.join(DATA_DIR, 'stage_1_train_images')
test_dicom_dir = os.path.join(DATA_DIR, 'stage_1_test_images')

# %% [markdown]
# ### Some setup functions and classes for Mask-RCNN
#
# - dicom_fps is a list of the dicom image path and filenames
# - image_annotions is a dictionary of the annotations keyed by the filenames
# - parsing the dataset returns a list of the image filenames and the annotations dictionary

# %%
def get_dicom_fps(dicom_dir):
    dicom_fps = glob.glob(dicom_dir+'/'+'*.dcm')
    return list(set(dicom_fps))

def parse_dataset(dicom_dir, anns): 
    image_fps = get_dicom_fps(dicom_dir)
    image_annotations = {fp: [] for fp in image_fps}
    for index, row in anns.iterrows(): 
        fp = os.path.join(dicom_dir, row['patientId']+'.dcm')
        image_annotations[fp].append(row)
    return image_fps, image_annotations

# %%
# The following parameters have been selected to reduce running time for demonstration purposes 
# These are not optimal 

class DetectorConfig(Config):
    """Configuration for training pneumonia detection on the RSNA pneumonia dataset.
    Overrides values in the base Config class.
    """
    
    # Give the configuration a recognizable name  
    NAME = 'pneumonia'
    
    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 2 
    
    BACKBONE = 'resnet50'
    
    NUM_CLASSES = 2  # background + 1 pneumonia classes
    
    IMAGE_MIN_DIM = 256
    IMAGE_MAX_DIM = 256
    RPN_ANCHOR_SCALES = (32, 64, 128, 256)
    TRAIN_ROIS_PER_IMAGE = 32
    MAX_GT_INSTANCES = 5
    DETECTION_MAX_INSTANCES = 3
    DETECTION_MIN_CONFIDENCE = 0.4
    DETECTION_NMS_THRESHOLD = 0.1

    STEPS_PER_EPOCH = 1024
    LOSS_WEIGHTS = {
        "rpn_class_loss": 1.,
        "rpn_bbox_loss": 1.,
        "mrcnn_class_loss": 1.,
        "mrcnn_bbox_loss": 1.,
        "mrcnn_mask_loss": 0.
    }

    
config = DetectorConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [ 0.1  0.1  0.2  0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        3
# DETECTION_MIN_CONFIDENCE       0.4
# DETECTION_NMS_THRESHOLD        0.1
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_MAX_DIM                  256
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  256
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [256 256   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 0.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               5
# MEAN_PIXEL                     [ 123.7  116.8  103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           pneumonia
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [ 0.1  0.1  0.2  0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1024
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
class DetectorDataset(utils.Dataset):
    """Dataset class for training pneumonia detection on the RSNA pneumonia dataset.
    """

    def __init__(self, image_fps, image_annotations, orig_height, orig_width):
        super().__init__(self)
        
        # Add classes
        self.add_class('pneumonia', 1, 'Lung Opacity')
        
        # add images 
        for i, fp in enumerate(image_fps):
            annotations = image_annotations[fp]
            self.add_image('pneumonia', image_id=i, path=fp, 
                           annotations=annotations, orig_height=orig_height, orig_width=orig_width)
            
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

    def load_image(self, image_id):
        info = self.image_info[image_id]
        fp = info['path']
        ds = pydicom.read_file(fp)
        image = ds.pixel_array
        # If grayscale. Convert to RGB for consistency.
        if len(image.shape) != 3 or image.shape[2] != 3:
            image = np.stack((image,) * 3, -1)
        return image

    def load_mask(self, image_id):
        info = self.image_info[image_id]
        annotations = info['annotations']
        count = len(annotations)
        if count == 0:
            mask = np.zeros((info['orig_height'], info['orig_width'], 1), dtype=np.uint8)
            class_ids = np.zeros((1,), dtype=np.int32)
        else:
            mask = np.zeros((info['orig_height'], info['orig_width'], count), dtype=np.uint8)
            class_ids = np.zeros((count,), dtype=np.int32)
            for i, a in enumerate(annotations):
                if a['Target'] == 1:
                    x = int(a['x'])
                    y = int(a['y'])
                    w = int(a['width'])
                    h = int(a['height'])
                    mask_instance = mask[:, :, i].copy()
                    cv2.rectangle(mask_instance, (x, y), (x+w, y+h), 255, -1)
                    mask[:, :, i] = mask_instance
                    class_ids[i] = 1
        return mask.astype(np.bool), class_ids.astype(np.int32)

# %% [markdown]
# ### Examine the annotation data, parse the dataset, and view dicom fields

# %%
# training dataset
anns = pd.read_csv(os.path.join(DATA_DIR, 'stage_1_train_labels.csv'))
anns.head()
# Out:
#                               patientId      x      y  width  height  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1

# %%
image_fps, image_annotations = parse_dataset(train_dicom_dir, anns=anns)

# %%
ds = pydicom.read_file(image_fps[0]) # read dicom image from filepath 
image = ds.pixel_array # get image array

# %%
# show dicom fields 
ds
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.8323329.26435.1517874472.175648
# (0008, 0020) Study Date                          DA: '19010101'
# (0008, 0030) Study Time                          TM: '000000.00'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 103e) Series Description                  LO: 'view: AP'
# (0010, 0010) Patient's Name                      PN: '50d8b462-8e52-4b60-abde-10fd98b51cf8'
# (0010, 0020) Patient ID                          LO: '50d8b462-8e52-4b60-abde-10fd98b51cf8'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1010) Patient's Age                       AS: '32'
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 5101) View Position                       CS: 'AP'
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.8323329.26435.1517874472.175647
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.8323329.26435.1517874472.175646
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1024
# (0028, 0011) Columns                             US: 1024
# (0028, 0030) Pixel Spacing                       DS: ['0.168', '0.168']
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 2110) Lossy Image Compression             CS: '01'
# (0028, 2114) Lossy Image Compression Method      CS: 'ISO_10918_1'
# (7fe0, 0010) Pixel Data                          OB: Array of 85578 bytes

# %%
# Original DICOM image size: 1024 x 1024
ORIG_SIZE = 1024

# %% [markdown]
# ### Split the data into training and validation datasets
# **Note: We have only used only a portion of the images for demonstration purposes. See comments below.**
#
#  - To use all the images do: image_fps_list = list(image_fps)
#  - Or change the number of images from 100 to a custom number

# %%
######################################################################
# Modify this line to use more or fewer images for training/validation. 
# To use all images, do: image_fps_list = list(image_fps)
image_fps_list = list(image_fps) 
#####################################################################

# split dataset into training vs. validation dataset 
# split ratio is set to 0.9 vs. 0.1 (train vs. validation, respectively)
sorted(image_fps_list)
random.seed(42)
random.shuffle(image_fps_list)

validation_split = 0.1
split_index = int((1 - validation_split) * len(image_fps_list))

image_fps_train = image_fps_list[:split_index]
image_fps_val = image_fps_list[split_index:]

print(len(image_fps_train), len(image_fps_val))
# Out:
# 23115 2569

# %% [markdown]
# ### Create and prepare the training dataset using the DetectorDataset class.

# %%
# prepare the training dataset
dataset_train = DetectorDataset(image_fps_train, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_train.prepare()

# %% [markdown]
# ### Let's look at a sample annotation. We see a bounding box with (x, y) of the the top left corner as well as the width and height.

# %%
# Show annotation(s) for a DICOM image 
test_fp = random.choice(image_fps_train)
image_annotations[test_fp]
# Out:
# [patientId    56a10b62-f721-4bbe-805f-3a90af981515
#  x                                             NaN
#  y                                             NaN
#  width                                         NaN
#  height                                        NaN
#  Target                                          0
#  Name: 7387, dtype: object]

# %%
# prepare the validation dataset
dataset_val = DetectorDataset(image_fps_val, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_val.prepare()

# %% [markdown]
# ### Display a random image with bounding boxes

# %%
# Load and display random samples and their bounding boxes
# Suggestion: Run this a few times to see different examples. 

image_id = random.choice(dataset_train.image_ids)
image_fp = dataset_train.image_reference(image_id)
image = dataset_train.load_image(image_id)
mask, class_ids = dataset_train.load_mask(image_id)

print(image.shape)

plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(image[:, :, 0], cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
masked = np.zeros(image.shape[:2])
for i in range(mask.shape[2]):
    masked += image[:, :, 0] * mask[:, :, i]
plt.imshow(masked, cmap='gray')
plt.axis('off')

print(image_fp)
print(class_ids)
# Out:
# (1024, 1024, 3)
# ../input/stage_1_train_images/f9bb71fc-fec8-4faf-8c59-2e5391e6327c.dcm
# [0]

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)

# %% [markdown]
# ### Image Augmentation. Try finetuning some variables to custom values

# %%
# Image augmentation 
augmentation = iaa.SomeOf((0, 2), [
    iaa.Affine(
        scale={"x": (0.95, 1.05), "y": (0.95, 1.05)},
        translate_percent={"x": (-0.05, 0.05), "y": (-0.05, 0.05)},
        rotate=(-5, 5),
        shear=(-2, 2)
    ),
    iaa.Multiply((0.9, 1.1))
])

# %% [markdown]
# ### Now it's time to train the model. Note that training even a basic model can take a few hours.
#
# Note: the following model is for demonstration purpose only. We have limited the training to one epoch, and have set nominal values for the Detector Configuration to reduce run-time.
#
# - dataset_train and dataset_val are derived from DetectorDataset
# - DetectorDataset loads images from image filenames and  masks from the annotation data
# - model is Mask-RCNN

# %%
NUM_EPOCHS = 50

# Train Mask-RCNN Model 
import warnings 
warnings.filterwarnings("ignore")
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=25, 
            layers='heads',
            augmentation=augmentation)

model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE/10, 
            epochs=50, 
            layers='all',
            augmentation=augmentation)

model.train(dataset_train, dataset_val,
                     learning_rate=config.LEARNING_RATE/100,
                     epochs=75,
                     layers='all',
                     augmentation=augmentation)

# %%
import warnings 
warnings.filterwarnings("ignore")
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=20, 
            layers='all')
# Out:
# WARNING:tensorflow:From /home/mehul/miniconda3/envs/tf7/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
#
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: ../working_copy2/pneumonia20180919T2000/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/20
# 1024/1024 [==============================] - 234s 229ms/step - loss: 1.6135 - rpn_class_loss: 0.0661 - rpn_bbox_loss: 0.5624 - mrcnn_class_loss: 0.3522 - mrcnn_bbox_loss: 0.6327 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.3968 - val_rpn_class_loss: 0.0490 - val_rpn_bbox_loss: 0.4315 - val_mrcnn_class_loss: 0.3471 - val_mrcnn_bbox_loss: 0.5691 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 2/20
# 1024/1024 [==============================] - 215s 210ms/step - loss: 1.3974 - rpn_class_loss: 0.0460 - rpn_bbox_loss: 0.4654 - mrcnn_class_loss: 0.3333 - mrcnn_bbox_loss: 0.5528 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.3204 - val_rpn_class_loss: 0.0491 - val_rpn_bbox_loss: 0.4047 - val_mrcnn_class_loss: 0.3277 - val_mrcnn_bbox_loss: 0.5390 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 3/20
# 1024/1024 [==============================] - 215s 210ms/step - loss: 1.3065 - rpn_class_loss: 0.0405 - rpn_bbox_loss: 0.4162 - mrcnn_class_loss: 0.3220 - mrcnn_bbox_loss: 0.5279 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.3842 - val_rpn_class_loss: 0.0401 - val_rpn_bbox_loss: 0.5111 - val_mrcnn_class_loss: 0.3178 - val_mrcnn_bbox_loss: 0.5152 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 4/20
# 1024/1024 [==============================] - 216s 211ms/step - loss: 1.2733 - rpn_class_loss: 0.0368 - rpn_bbox_loss: 0.4132 - mrcnn_class_loss: 0.3064 - mrcnn_bbox_loss: 0.5170 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.2515 - val_rpn_class_loss: 0.0363 - val_rpn_bbox_loss: 0.3772 - val_mrcnn_class_loss: 0.3420 - val_mrcnn_bbox_loss: 0.4960 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 5/20
# 1024/1024 [==============================] - 215s 210ms/step - loss: 1.2399 - rpn_class_loss: 0.0343 - rpn_bbox_loss: 0.4012 - mrcnn_class_loss: 0.3073 - mrcnn_bbox_loss: 0.4972 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1963 - val_rpn_class_loss: 0.0322 - val_rpn_bbox_loss: 0.3494 - val_mrcnn_class_loss: 0.3134 - val_mrcnn_bbox_loss: 0.5013 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 6/20
# 1024/1024 [==============================] - 214s 209ms/step - loss: 1.1917 - rpn_class_loss: 0.0313 - rpn_bbox_loss: 0.3871 - mrcnn_class_loss: 0.2924 - mrcnn_bbox_loss: 0.4808 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.2204 - val_rpn_class_loss: 0.0272 - val_rpn_bbox_loss: 0.4151 - val_mrcnn_class_loss: 0.3136 - val_mrcnn_bbox_loss: 0.4645 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 7/20
# 1024/1024 [==============================] - 213s 208ms/step - loss: 1.1770 - rpn_class_loss: 0.0299 - rpn_bbox_loss: 0.3903 - mrcnn_class_loss: 0.2831 - mrcnn_bbox_loss: 0.4737 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1527 - val_rpn_class_loss: 0.0331 - val_rpn_bbox_loss: 0.3533 - val_mrcnn_class_loss: 0.3077 - val_mrcnn_bbox_loss: 0.4586 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 8/20
# 1024/1024 [==============================] - 215s 210ms/step - loss: 1.1469 - rpn_class_loss: 0.0287 - rpn_bbox_loss: 0.3618 - mrcnn_class_loss: 0.2862 - mrcnn_bbox_loss: 0.4701 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1869 - val_rpn_class_loss: 0.0290 - val_rpn_bbox_loss: 0.3614 - val_mrcnn_class_loss: 0.3283 - val_mrcnn_bbox_loss: 0.4681 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 9/20
# 1024/1024 [==============================] - 211s 206ms/step - loss: 1.1248 - rpn_class_loss: 0.0283 - rpn_bbox_loss: 0.3589 - mrcnn_class_loss: 0.2830 - mrcnn_bbox_loss: 0.4547 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1693 - val_rpn_class_loss: 0.0262 - val_rpn_bbox_loss: 0.3969 - val_mrcnn_class_loss: 0.2810 - val_mrcnn_bbox_loss: 0.4652 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 10/20
# 1024/1024 [==============================] - 210s 205ms/step - loss: 1.1013 - rpn_class_loss: 0.0272 - rpn_bbox_loss: 0.3627 - mrcnn_class_loss: 0.2686 - mrcnn_bbox_loss: 0.4428 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1179 - val_rpn_class_loss: 0.0290 - val_rpn_bbox_loss: 0.3690 - val_mrcnn_class_loss: 0.2798 - val_mrcnn_bbox_loss: 0.4401 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 11/20
# 1024/1024 [==============================] - 208s 203ms/step - loss: 1.0861 - rpn_class_loss: 0.0252 - rpn_bbox_loss: 0.3579 - mrcnn_class_loss: 0.2631 - mrcnn_bbox_loss: 0.4398 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1764 - val_rpn_class_loss: 0.0267 - val_rpn_bbox_loss: 0.4396 - val_mrcnn_class_loss: 0.2703 - val_mrcnn_bbox_loss: 0.4398 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 12/20
# 1024/1024 [==============================] - 209s 204ms/step - loss: 1.0492 - rpn_class_loss: 0.0253 - rpn_bbox_loss: 0.3309 - mrcnn_class_loss: 0.2601 - mrcnn_bbox_loss: 0.4329 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1082 - val_rpn_class_loss: 0.0234 - val_rpn_bbox_loss: 0.3478 - val_mrcnn_class_loss: 0.2620 - val_mrcnn_bbox_loss: 0.4750 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 13/20
# 1024/1024 [==============================] - 209s 204ms/step - loss: 1.0520 - rpn_class_loss: 0.0241 - rpn_bbox_loss: 0.3387 - mrcnn_class_loss: 0.2615 - mrcnn_bbox_loss: 0.4278 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1013 - val_rpn_class_loss: 0.0281 - val_rpn_bbox_loss: 0.3785 - val_mrcnn_class_loss: 0.2651 - val_mrcnn_bbox_loss: 0.4296 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 14/20
# 1024/1024 [==============================] - 207s 202ms/step - loss: 1.0428 - rpn_class_loss: 0.0241 - rpn_bbox_loss: 0.3411 - mrcnn_class_loss: 0.2540 - mrcnn_bbox_loss: 0.4235 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.2625 - val_rpn_class_loss: 0.0286 - val_rpn_bbox_loss: 0.5761 - val_mrcnn_class_loss: 0.2355 - val_mrcnn_bbox_loss: 0.4223 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 15/20
# 1024/1024 [==============================] - 207s 202ms/step - loss: 1.0237 - rpn_class_loss: 0.0237 - rpn_bbox_loss: 0.3305 - mrcnn_class_loss: 0.2510 - mrcnn_bbox_loss: 0.4184 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0603 - val_rpn_class_loss: 0.0245 - val_rpn_bbox_loss: 0.3163 - val_mrcnn_class_loss: 0.2694 - val_mrcnn_bbox_loss: 0.4502 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 16/20
# 1024/1024 [==============================] - 208s 203ms/step - loss: 0.9830 - rpn_class_loss: 0.0224 - rpn_bbox_loss: 0.3120 - mrcnn_class_loss: 0.2419 - mrcnn_bbox_loss: 0.4066 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1557 - val_rpn_class_loss: 0.0264 - val_rpn_bbox_loss: 0.4506 - val_mrcnn_class_loss: 0.2641 - val_mrcnn_bbox_loss: 0.4147 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 17/20
# 1024/1024 [==============================] - 208s 203ms/step - loss: 0.9839 - rpn_class_loss: 0.0228 - rpn_bbox_loss: 0.3211 - mrcnn_class_loss: 0.2354 - mrcnn_bbox_loss: 0.4046 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1289 - val_rpn_class_loss: 0.0208 - val_rpn_bbox_loss: 0.4233 - val_mrcnn_class_loss: 0.2630 - val_mrcnn_bbox_loss: 0.4219 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 18/20
# 1024/1024 [==============================] - 208s 203ms/step - loss: 0.9733 - rpn_class_loss: 0.0218 - rpn_bbox_loss: 0.3116 - mrcnn_class_loss: 0.2339 - mrcnn_bbox_loss: 0.4059 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0762 - val_rpn_class_loss: 0.0260 - val_rpn_bbox_loss: 0.4029 - val_mrcnn_class_loss: 0.2330 - val_mrcnn_bbox_loss: 0.4143 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 19/20
# 1024/1024 [==============================] - 207s 202ms/step - loss: 0.9528 - rpn_class_loss: 0.0222 - rpn_bbox_loss: 0.3059 - mrcnn_class_loss: 0.2326 - mrcnn_bbox_loss: 0.3921 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1263 - val_rpn_class_loss: 0.0205 - val_rpn_bbox_loss: 0.3857 - val_mrcnn_class_loss: 0.2851 - val_mrcnn_bbox_loss: 0.4350 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 20/20
# 1024/1024 [==============================] - 210s 205ms/step - loss: 0.9464 - rpn_class_loss: 0.0203 - rpn_bbox_loss: 0.2999 - mrcnn_class_loss: 0.2309 - mrcnn_bbox_loss: 0.3953 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1549 - val_rpn_class_loss: 0.0254 - val_rpn_bbox_loss: 0.4779 - val_mrcnn_class_loss: 0.2401 - val_mrcnn_bbox_loss: 0.4115 - val_mrcnn_mask_loss: 0.0000e+00

# %%
#model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)
#model.load_weights(model_path, by_name=True)
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=40, 
            layers='all')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: ../working_copy2/pneumonia20180919T2113/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/40
# 1024/1024 [==============================] - 234s 229ms/step - loss: 1.6545 - rpn_class_loss: 0.0777 - rpn_bbox_loss: 0.5912 - mrcnn_class_loss: 0.3553 - mrcnn_bbox_loss: 0.6303 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.4856 - val_rpn_class_loss: 0.0502 - val_rpn_bbox_loss: 0.4794 - val_mrcnn_class_loss: 0.3467 - val_mrcnn_bbox_loss: 0.6093 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 2/40
# 1024/1024 [==============================] - 217s 212ms/step - loss: 1.3669 - rpn_class_loss: 0.0456 - rpn_bbox_loss: 0.4364 - mrcnn_class_loss: 0.3293 - mrcnn_bbox_loss: 0.5556 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.3584 - val_rpn_class_loss: 0.0383 - val_rpn_bbox_loss: 0.4407 - val_mrcnn_class_loss: 0.3343 - val_mrcnn_bbox_loss: 0.5451 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 3/40
# 1024/1024 [==============================] - 217s 212ms/step - loss: 1.2975 - rpn_class_loss: 0.0375 - rpn_bbox_loss: 0.4244 - mrcnn_class_loss: 0.3122 - mrcnn_bbox_loss: 0.5234 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.4022 - val_rpn_class_loss: 0.0405 - val_rpn_bbox_loss: 0.4893 - val_mrcnn_class_loss: 0.3293 - val_mrcnn_bbox_loss: 0.5432 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 4/40
# 1024/1024 [==============================] - 214s 209ms/step - loss: 1.2629 - rpn_class_loss: 0.0342 - rpn_bbox_loss: 0.4097 - mrcnn_class_loss: 0.3098 - mrcnn_bbox_loss: 0.5091 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.3812 - val_rpn_class_loss: 0.0331 - val_rpn_bbox_loss: 0.5703 - val_mrcnn_class_loss: 0.2732 - val_mrcnn_bbox_loss: 0.5046 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 5/40
# 1024/1024 [==============================] - 214s 209ms/step - loss: 1.2225 - rpn_class_loss: 0.0336 - rpn_bbox_loss: 0.3916 - mrcnn_class_loss: 0.3057 - mrcnn_bbox_loss: 0.4916 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1542 - val_rpn_class_loss: 0.0307 - val_rpn_bbox_loss: 0.3355 - val_mrcnn_class_loss: 0.3066 - val_mrcnn_bbox_loss: 0.4814 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 6/40
# 1024/1024 [==============================] - 213s 208ms/step - loss: 1.1994 - rpn_class_loss: 0.0307 - rpn_bbox_loss: 0.3961 - mrcnn_class_loss: 0.2975 - mrcnn_bbox_loss: 0.4751 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1973 - val_rpn_class_loss: 0.0313 - val_rpn_bbox_loss: 0.4020 - val_mrcnn_class_loss: 0.2699 - val_mrcnn_bbox_loss: 0.4941 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 7/40
# 1024/1024 [==============================] - 215s 209ms/step - loss: 1.1675 - rpn_class_loss: 0.0306 - rpn_bbox_loss: 0.3816 - mrcnn_class_loss: 0.2838 - mrcnn_bbox_loss: 0.4716 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1504 - val_rpn_class_loss: 0.0274 - val_rpn_bbox_loss: 0.3878 - val_mrcnn_class_loss: 0.2579 - val_mrcnn_bbox_loss: 0.4774 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 8/40
# 1024/1024 [==============================] - 212s 207ms/step - loss: 1.1207 - rpn_class_loss: 0.0290 - rpn_bbox_loss: 0.3710 - mrcnn_class_loss: 0.2661 - mrcnn_bbox_loss: 0.4546 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.3384 - val_rpn_class_loss: 0.0346 - val_rpn_bbox_loss: 0.5171 - val_mrcnn_class_loss: 0.2869 - val_mrcnn_bbox_loss: 0.4997 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 9/40
# 1024/1024 [==============================] - 211s 206ms/step - loss: 1.1218 - rpn_class_loss: 0.0285 - rpn_bbox_loss: 0.3717 - mrcnn_class_loss: 0.2734 - mrcnn_bbox_loss: 0.4482 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.2676 - val_rpn_class_loss: 0.0284 - val_rpn_bbox_loss: 0.4653 - val_mrcnn_class_loss: 0.2905 - val_mrcnn_bbox_loss: 0.4833 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 10/40
# 1024/1024 [==============================] - 206s 201ms/step - loss: 1.0959 - rpn_class_loss: 0.0272 - rpn_bbox_loss: 0.3560 - mrcnn_class_loss: 0.2680 - mrcnn_bbox_loss: 0.4448 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1183 - val_rpn_class_loss: 0.0240 - val_rpn_bbox_loss: 0.4222 - val_mrcnn_class_loss: 0.2344 - val_mrcnn_bbox_loss: 0.4376 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 11/40
# 1024/1024 [==============================] - 205s 200ms/step - loss: 1.0950 - rpn_class_loss: 0.0256 - rpn_bbox_loss: 0.3713 - mrcnn_class_loss: 0.2642 - mrcnn_bbox_loss: 0.4339 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.2393 - val_rpn_class_loss: 0.0307 - val_rpn_bbox_loss: 0.4899 - val_mrcnn_class_loss: 0.2832 - val_mrcnn_bbox_loss: 0.4356 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 12/40
# 1024/1024 [==============================] - 205s 200ms/step - loss: 1.0551 - rpn_class_loss: 0.0241 - rpn_bbox_loss: 0.3527 - mrcnn_class_loss: 0.2532 - mrcnn_bbox_loss: 0.4251 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.2226 - val_rpn_class_loss: 0.0317 - val_rpn_bbox_loss: 0.5100 - val_mrcnn_class_loss: 0.2216 - val_mrcnn_bbox_loss: 0.4593 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 13/40
# 1024/1024 [==============================] - 210s 205ms/step - loss: 1.0444 - rpn_class_loss: 0.0248 - rpn_bbox_loss: 0.3460 - mrcnn_class_loss: 0.2526 - mrcnn_bbox_loss: 0.4210 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1667 - val_rpn_class_loss: 0.0304 - val_rpn_bbox_loss: 0.4698 - val_mrcnn_class_loss: 0.2432 - val_mrcnn_bbox_loss: 0.4233 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 14/40
# 1024/1024 [==============================] - 210s 205ms/step - loss: 1.0494 - rpn_class_loss: 0.0248 - rpn_bbox_loss: 0.3492 - mrcnn_class_loss: 0.2565 - mrcnn_bbox_loss: 0.4190 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0979 - val_rpn_class_loss: 0.0229 - val_rpn_bbox_loss: 0.3547 - val_mrcnn_class_loss: 0.2748 - val_mrcnn_bbox_loss: 0.4455 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 15/40
# 1024/1024 [==============================] - 211s 206ms/step - loss: 1.0232 - rpn_class_loss: 0.0233 - rpn_bbox_loss: 0.3377 - mrcnn_class_loss: 0.2449 - mrcnn_bbox_loss: 0.4173 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1507 - val_rpn_class_loss: 0.0257 - val_rpn_bbox_loss: 0.3672 - val_mrcnn_class_loss: 0.3025 - val_mrcnn_bbox_loss: 0.4553 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 16/40
# 1024/1024 [==============================] - 210s 205ms/step - loss: 1.0093 - rpn_class_loss: 0.0229 - rpn_bbox_loss: 0.3430 - mrcnn_class_loss: 0.2431 - mrcnn_bbox_loss: 0.4003 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0644 - val_rpn_class_loss: 0.0238 - val_rpn_bbox_loss: 0.3945 - val_mrcnn_class_loss: 0.2438 - val_mrcnn_bbox_loss: 0.4023 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 17/40
# 1024/1024 [==============================] - 208s 203ms/step - loss: 0.9887 - rpn_class_loss: 0.0224 - rpn_bbox_loss: 0.3167 - mrcnn_class_loss: 0.2449 - mrcnn_bbox_loss: 0.4046 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1894 - val_rpn_class_loss: 0.0241 - val_rpn_bbox_loss: 0.4764 - val_mrcnn_class_loss: 0.2605 - val_mrcnn_bbox_loss: 0.4283 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 18/40
# 1024/1024 [==============================] - 208s 204ms/step - loss: 0.9749 - rpn_class_loss: 0.0219 - rpn_bbox_loss: 0.3230 - mrcnn_class_loss: 0.2375 - mrcnn_bbox_loss: 0.3925 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0111 - val_rpn_class_loss: 0.0184 - val_rpn_bbox_loss: 0.3323 - val_mrcnn_class_loss: 0.2444 - val_mrcnn_bbox_loss: 0.4161 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 19/40
# 1024/1024 [==============================] - 208s 203ms/step - loss: 0.9448 - rpn_class_loss: 0.0213 - rpn_bbox_loss: 0.2965 - mrcnn_class_loss: 0.2345 - mrcnn_bbox_loss: 0.3925 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1360 - val_rpn_class_loss: 0.0209 - val_rpn_bbox_loss: 0.4136 - val_mrcnn_class_loss: 0.2668 - val_mrcnn_bbox_loss: 0.4347 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 20/40
# 1024/1024 [==============================] - 208s 203ms/step - loss: 0.9441 - rpn_class_loss: 0.0211 - rpn_bbox_loss: 0.3042 - mrcnn_class_loss: 0.2276 - mrcnn_bbox_loss: 0.3911 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0847 - val_rpn_class_loss: 0.0197 - val_rpn_bbox_loss: 0.4191 - val_mrcnn_class_loss: 0.2383 - val_mrcnn_bbox_loss: 0.4075 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 21/40
# 1024/1024 [==============================] - 209s 204ms/step - loss: 0.9272 - rpn_class_loss: 0.0207 - rpn_bbox_loss: 0.2974 - mrcnn_class_loss: 0.2249 - mrcnn_bbox_loss: 0.3842 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0688 - val_rpn_class_loss: 0.0229 - val_rpn_bbox_loss: 0.3833 - val_mrcnn_class_loss: 0.2662 - val_mrcnn_bbox_loss: 0.3964 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 22/40
# 1024/1024 [==============================] - 209s 204ms/step - loss: 0.9271 - rpn_class_loss: 0.0203 - rpn_bbox_loss: 0.2958 - mrcnn_class_loss: 0.2267 - mrcnn_bbox_loss: 0.3841 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.2038 - val_rpn_class_loss: 0.0275 - val_rpn_bbox_loss: 0.5514 - val_mrcnn_class_loss: 0.2284 - val_mrcnn_bbox_loss: 0.3966 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 23/40
# 1024/1024 [==============================] - 205s 200ms/step - loss: 0.9112 - rpn_class_loss: 0.0197 - rpn_bbox_loss: 0.2865 - mrcnn_class_loss: 0.2249 - mrcnn_bbox_loss: 0.3801 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1356 - val_rpn_class_loss: 0.0251 - val_rpn_bbox_loss: 0.5364 - val_mrcnn_class_loss: 0.1847 - val_mrcnn_bbox_loss: 0.3894 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 24/40
# 1024/1024 [==============================] - 212s 207ms/step - loss: 0.9197 - rpn_class_loss: 0.0209 - rpn_bbox_loss: 0.2983 - mrcnn_class_loss: 0.2199 - mrcnn_bbox_loss: 0.3806 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1008 - val_rpn_class_loss: 0.0242 - val_rpn_bbox_loss: 0.4187 - val_mrcnn_class_loss: 0.2313 - val_mrcnn_bbox_loss: 0.4266 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 25/40
# 1024/1024 [==============================] - 209s 204ms/step - loss: 0.8987 - rpn_class_loss: 0.0199 - rpn_bbox_loss: 0.2788 - mrcnn_class_loss: 0.2226 - mrcnn_bbox_loss: 0.3774 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0932 - val_rpn_class_loss: 0.0226 - val_rpn_bbox_loss: 0.4548 - val_mrcnn_class_loss: 0.2151 - val_mrcnn_bbox_loss: 0.4007 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 26/40
# 1024/1024 [==============================] - 210s 205ms/step - loss: 0.8816 - rpn_class_loss: 0.0199 - rpn_bbox_loss: 0.2761 - mrcnn_class_loss: 0.2164 - mrcnn_bbox_loss: 0.3692 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1640 - val_rpn_class_loss: 0.0232 - val_rpn_bbox_loss: 0.5292 - val_mrcnn_class_loss: 0.2162 - val_mrcnn_bbox_loss: 0.3954 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 27/40
# 1024/1024 [==============================] - 210s 206ms/step - loss: 0.8567 - rpn_class_loss: 0.0196 - rpn_bbox_loss: 0.2573 - mrcnn_class_loss: 0.2144 - mrcnn_bbox_loss: 0.3654 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0144 - val_rpn_class_loss: 0.0173 - val_rpn_bbox_loss: 0.4102 - val_mrcnn_class_loss: 0.2016 - val_mrcnn_bbox_loss: 0.3853 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 28/40
# 1024/1024 [==============================] - 208s 203ms/step - loss: 0.8376 - rpn_class_loss: 0.0187 - rpn_bbox_loss: 0.2552 - mrcnn_class_loss: 0.2056 - mrcnn_bbox_loss: 0.3580 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0322 - val_rpn_class_loss: 0.0162 - val_rpn_bbox_loss: 0.3897 - val_mrcnn_class_loss: 0.2153 - val_mrcnn_bbox_loss: 0.4110 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 29/40
# 1024/1024 [==============================] - 211s 206ms/step - loss: 0.8264 - rpn_class_loss: 0.0185 - rpn_bbox_loss: 0.2522 - mrcnn_class_loss: 0.2064 - mrcnn_bbox_loss: 0.3494 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0438 - val_rpn_class_loss: 0.0211 - val_rpn_bbox_loss: 0.4157 - val_mrcnn_class_loss: 0.2164 - val_mrcnn_bbox_loss: 0.3905 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 30/40
# 1024/1024 [==============================] - 211s 206ms/step - loss: 0.8185 - rpn_class_loss: 0.0192 - rpn_bbox_loss: 0.2450 - mrcnn_class_loss: 0.1990 - mrcnn_bbox_loss: 0.3553 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0064 - val_rpn_class_loss: 0.0204 - val_rpn_bbox_loss: 0.3823 - val_mrcnn_class_loss: 0.2307 - val_mrcnn_bbox_loss: 0.3731 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 31/40
# 1024/1024 [==============================] - 205s 200ms/step - loss: 0.7778 - rpn_class_loss: 0.0166 - rpn_bbox_loss: 0.2263 - mrcnn_class_loss: 0.1964 - mrcnn_bbox_loss: 0.3385 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 0.9791 - val_rpn_class_loss: 0.0178 - val_rpn_bbox_loss: 0.4007 - val_mrcnn_class_loss: 0.1903 - val_mrcnn_bbox_loss: 0.3702 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 32/40
# 1024/1024 [==============================] - 203s 198ms/step - loss: 0.7701 - rpn_class_loss: 0.0167 - rpn_bbox_loss: 0.2213 - mrcnn_class_loss: 0.1936 - mrcnn_bbox_loss: 0.3385 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.2575 - val_rpn_class_loss: 0.0198 - val_rpn_bbox_loss: 0.5388 - val_mrcnn_class_loss: 0.2782 - val_mrcnn_bbox_loss: 0.4207 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 33/40
# 1024/1024 [==============================] - 205s 200ms/step - loss: 0.7587 - rpn_class_loss: 0.0167 - rpn_bbox_loss: 0.2159 - mrcnn_class_loss: 0.1939 - mrcnn_bbox_loss: 0.3322 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1984 - val_rpn_class_loss: 0.0200 - val_rpn_bbox_loss: 0.4366 - val_mrcnn_class_loss: 0.2825 - val_mrcnn_bbox_loss: 0.4594 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 34/40
# 1024/1024 [==============================] - 208s 203ms/step - loss: 0.7340 - rpn_class_loss: 0.0166 - rpn_bbox_loss: 0.2049 - mrcnn_class_loss: 0.1891 - mrcnn_bbox_loss: 0.3233 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.2947 - val_rpn_class_loss: 0.0254 - val_rpn_bbox_loss: 0.6757 - val_mrcnn_class_loss: 0.2207 - val_mrcnn_bbox_loss: 0.3728 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 35/40
# 1024/1024 [==============================] - 208s 203ms/step - loss: 0.7237 - rpn_class_loss: 0.0159 - rpn_bbox_loss: 0.1992 - mrcnn_class_loss: 0.1879 - mrcnn_bbox_loss: 0.3207 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1281 - val_rpn_class_loss: 0.0223 - val_rpn_bbox_loss: 0.5278 - val_mrcnn_class_loss: 0.2091 - val_mrcnn_bbox_loss: 0.3688 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 36/40
# 1024/1024 [==============================] - 206s 201ms/step - loss: 0.7364 - rpn_class_loss: 0.0166 - rpn_bbox_loss: 0.2032 - mrcnn_class_loss: 0.1937 - mrcnn_bbox_loss: 0.3229 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.4520 - val_rpn_class_loss: 0.0272 - val_rpn_bbox_loss: 0.8167 - val_mrcnn_class_loss: 0.2050 - val_mrcnn_bbox_loss: 0.4030 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 37/40
# 1024/1024 [==============================] - 207s 203ms/step - loss: 0.7324 - rpn_class_loss: 0.0168 - rpn_bbox_loss: 0.2003 - mrcnn_class_loss: 0.1898 - mrcnn_bbox_loss: 0.3255 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0655 - val_rpn_class_loss: 0.0210 - val_rpn_bbox_loss: 0.4340 - val_mrcnn_class_loss: 0.2160 - val_mrcnn_bbox_loss: 0.3945 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 38/40
# 1024/1024 [==============================] - 204s 199ms/step - loss: 0.7110 - rpn_class_loss: 0.0160 - rpn_bbox_loss: 0.1923 - mrcnn_class_loss: 0.1886 - mrcnn_bbox_loss: 0.3141 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.3126 - val_rpn_class_loss: 0.0271 - val_rpn_bbox_loss: 0.7008 - val_mrcnn_class_loss: 0.1958 - val_mrcnn_bbox_loss: 0.3889 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 39/40
# 1024/1024 [==============================] - 206s 201ms/step - loss: 0.6896 - rpn_class_loss: 0.0151 - rpn_bbox_loss: 0.1822 - mrcnn_class_loss: 0.1787 - mrcnn_bbox_loss: 0.3135 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.2453 - val_rpn_class_loss: 0.0228 - val_rpn_bbox_loss: 0.6283 - val_mrcnn_class_loss: 0.1921 - val_mrcnn_bbox_loss: 0.4021 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 40/40
# 1024/1024 [==============================] - 206s 201ms/step - loss: 0.6966 - rpn_class_loss: 0.0152 - rpn_bbox_loss: 0.1900 - mrcnn_class_loss: 0.1817 - mrcnn_bbox_loss: 0.3095 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0412 - val_rpn_class_loss: 0.0191 - val_rpn_bbox_loss: 0.4530 - val_mrcnn_class_loss: 0.1965 - val_mrcnn_bbox_loss: 0.3727 - val_mrcnn_mask_loss: 0.0000e+00

# %%
#model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)
#model.load_weights(model_path, by_name=True)
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=60, 
            layers='all')
# Out:
# Re-starting from epoch 40
#
# Starting at epoch 40. LR=0.001
#
# Checkpoint Path: ../working_copy2/pneumonia20180918T2049/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 41/60
# 500/500 [==============================] - 166s 331ms/step - loss: 0.9512 - rpn_class_loss: 0.0136 - rpn_bbox_loss: 0.3034 - mrcnn_class_loss: 0.2472 - mrcnn_bbox_loss: 0.3869 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.1911 - val_rpn_class_loss: 0.0187 - val_rpn_bbox_loss: 0.5352 - val_mrcnn_class_loss: 0.2303 - val_mrcnn_bbox_loss: 0.4069 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 42/60
# 500/500 [==============================] - 145s 290ms/step - loss: 0.9485 - rpn_class_loss: 0.0139 - rpn_bbox_loss: 0.2967 - mrcnn_class_loss: 0.2468 - mrcnn_bbox_loss: 0.3911 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0259 - val_rpn_class_loss: 0.0135 - val_rpn_bbox_loss: 0.3096 - val_mrcnn_class_loss: 0.2760 - val_mrcnn_bbox_loss: 0.4268 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 43/60
# 500/500 [==============================] - 148s 296ms/step - loss: 0.9622 - rpn_class_loss: 0.0140 - rpn_bbox_loss: 0.3009 - mrcnn_class_loss: 0.2487 - mrcnn_bbox_loss: 0.3986 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0503 - val_rpn_class_loss: 0.0129 - val_rpn_bbox_loss: 0.3648 - val_mrcnn_class_loss: 0.2495 - val_mrcnn_bbox_loss: 0.4230 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 44/60
# 500/500 [==============================] - 146s 292ms/step - loss: 0.9462 - rpn_class_loss: 0.0137 - rpn_bbox_loss: 0.3035 - mrcnn_class_loss: 0.2428 - mrcnn_bbox_loss: 0.3862 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0331 - val_rpn_class_loss: 0.0150 - val_rpn_bbox_loss: 0.4174 - val_mrcnn_class_loss: 0.1914 - val_mrcnn_bbox_loss: 0.4093 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 45/60
# 500/500 [==============================] - 146s 292ms/step - loss: 0.9450 - rpn_class_loss: 0.0144 - rpn_bbox_loss: 0.2977 - mrcnn_class_loss: 0.2388 - mrcnn_bbox_loss: 0.3940 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0634 - val_rpn_class_loss: 0.0135 - val_rpn_bbox_loss: 0.4246 - val_mrcnn_class_loss: 0.2237 - val_mrcnn_bbox_loss: 0.4016 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 46/60
# 500/500 [==============================] - 149s 297ms/step - loss: 0.9413 - rpn_class_loss: 0.0146 - rpn_bbox_loss: 0.3022 - mrcnn_class_loss: 0.2378 - mrcnn_bbox_loss: 0.3867 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 0.9595 - val_rpn_class_loss: 0.0113 - val_rpn_bbox_loss: 0.3293 - val_mrcnn_class_loss: 0.2381 - val_mrcnn_bbox_loss: 0.3808 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 47/60
# 500/500 [==============================] - 147s 293ms/step - loss: 0.9153 - rpn_class_loss: 0.0133 - rpn_bbox_loss: 0.2934 - mrcnn_class_loss: 0.2289 - mrcnn_bbox_loss: 0.3797 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0309 - val_rpn_class_loss: 0.0143 - val_rpn_bbox_loss: 0.3465 - val_mrcnn_class_loss: 0.2386 - val_mrcnn_bbox_loss: 0.4315 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 48/60
# 500/500 [==============================] - 149s 299ms/step - loss: 0.9124 - rpn_class_loss: 0.0130 - rpn_bbox_loss: 0.2866 - mrcnn_class_loss: 0.2293 - mrcnn_bbox_loss: 0.3835 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0033 - val_rpn_class_loss: 0.0130 - val_rpn_bbox_loss: 0.3757 - val_mrcnn_class_loss: 0.2311 - val_mrcnn_bbox_loss: 0.3836 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 49/60
# 500/500 [==============================] - 148s 295ms/step - loss: 0.8932 - rpn_class_loss: 0.0124 - rpn_bbox_loss: 0.2773 - mrcnn_class_loss: 0.2213 - mrcnn_bbox_loss: 0.3823 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0583 - val_rpn_class_loss: 0.0142 - val_rpn_bbox_loss: 0.4674 - val_mrcnn_class_loss: 0.1967 - val_mrcnn_bbox_loss: 0.3799 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 50/60
# 500/500 [==============================] - 147s 295ms/step - loss: 0.9320 - rpn_class_loss: 0.0144 - rpn_bbox_loss: 0.2970 - mrcnn_class_loss: 0.2330 - mrcnn_bbox_loss: 0.3876 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0074 - val_rpn_class_loss: 0.0119 - val_rpn_bbox_loss: 0.3239 - val_mrcnn_class_loss: 0.2548 - val_mrcnn_bbox_loss: 0.4168 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 51/60
# 500/500 [==============================] - 146s 291ms/step - loss: 0.8910 - rpn_class_loss: 0.0134 - rpn_bbox_loss: 0.2758 - mrcnn_class_loss: 0.2240 - mrcnn_bbox_loss: 0.3778 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0741 - val_rpn_class_loss: 0.0157 - val_rpn_bbox_loss: 0.3909 - val_mrcnn_class_loss: 0.2550 - val_mrcnn_bbox_loss: 0.4125 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 52/60
# 500/500 [==============================] - 145s 289ms/step - loss: 0.9028 - rpn_class_loss: 0.0125 - rpn_bbox_loss: 0.2843 - mrcnn_class_loss: 0.2282 - mrcnn_bbox_loss: 0.3778 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0395 - val_rpn_class_loss: 0.0132 - val_rpn_bbox_loss: 0.3604 - val_mrcnn_class_loss: 0.2415 - val_mrcnn_bbox_loss: 0.4244 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 53/60
# 500/500 [==============================] - 147s 294ms/step - loss: 0.9157 - rpn_class_loss: 0.0135 - rpn_bbox_loss: 0.2941 - mrcnn_class_loss: 0.2292 - mrcnn_bbox_loss: 0.3789 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0096 - val_rpn_class_loss: 0.0143 - val_rpn_bbox_loss: 0.3897 - val_mrcnn_class_loss: 0.2331 - val_mrcnn_bbox_loss: 0.3724 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 54/60
# 500/500 [==============================] - 149s 298ms/step - loss: 0.9106 - rpn_class_loss: 0.0133 - rpn_bbox_loss: 0.2869 - mrcnn_class_loss: 0.2273 - mrcnn_bbox_loss: 0.3830 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0159 - val_rpn_class_loss: 0.0135 - val_rpn_bbox_loss: 0.3353 - val_mrcnn_class_loss: 0.2596 - val_mrcnn_bbox_loss: 0.4074 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 55/60
# 500/500 [==============================] - 146s 293ms/step - loss: 0.9003 - rpn_class_loss: 0.0141 - rpn_bbox_loss: 0.2755 - mrcnn_class_loss: 0.2315 - mrcnn_bbox_loss: 0.3791 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0658 - val_rpn_class_loss: 0.0150 - val_rpn_bbox_loss: 0.3537 - val_mrcnn_class_loss: 0.2529 - val_mrcnn_bbox_loss: 0.4442 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 56/60
# 500/500 [==============================] - 148s 296ms/step - loss: 0.8683 - rpn_class_loss: 0.0121 - rpn_bbox_loss: 0.2661 - mrcnn_class_loss: 0.2206 - mrcnn_bbox_loss: 0.3695 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0338 - val_rpn_class_loss: 0.0153 - val_rpn_bbox_loss: 0.3888 - val_mrcnn_class_loss: 0.2216 - val_mrcnn_bbox_loss: 0.4081 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 57/60
# 500/500 [==============================] - 149s 298ms/step - loss: 0.8724 - rpn_class_loss: 0.0123 - rpn_bbox_loss: 0.2680 - mrcnn_class_loss: 0.2237 - mrcnn_bbox_loss: 0.3683 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0733 - val_rpn_class_loss: 0.0146 - val_rpn_bbox_loss: 0.4120 - val_mrcnn_class_loss: 0.2389 - val_mrcnn_bbox_loss: 0.4078 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 58/60
# 500/500 [==============================] - 148s 297ms/step - loss: 0.8812 - rpn_class_loss: 0.0126 - rpn_bbox_loss: 0.2790 - mrcnn_class_loss: 0.2179 - mrcnn_bbox_loss: 0.3716 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0265 - val_rpn_class_loss: 0.0127 - val_rpn_bbox_loss: 0.3212 - val_mrcnn_class_loss: 0.2778 - val_mrcnn_bbox_loss: 0.4148 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 59/60
# 500/500 [==============================] - 149s 298ms/step - loss: 0.8793 - rpn_class_loss: 0.0133 - rpn_bbox_loss: 0.2600 - mrcnn_class_loss: 0.2318 - mrcnn_bbox_loss: 0.3742 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 0.9150 - val_rpn_class_loss: 0.0112 - val_rpn_bbox_loss: 0.3408 - val_mrcnn_class_loss: 0.2028 - val_mrcnn_bbox_loss: 0.3602 - val_mrcnn_mask_loss: 0.0000e+00
# Epoch 60/60
# 500/500 [==============================] - 149s 297ms/step - loss: 0.8539 - rpn_class_loss: 0.0118 - rpn_bbox_loss: 0.2565 - mrcnn_class_loss: 0.2211 - mrcnn_bbox_loss: 0.3645 - mrcnn_mask_loss: 0.0000e+00 - val_loss: 1.0392 - val_rpn_class_loss: 0.0128 - val_rpn_bbox_loss: 0.4004 - val_mrcnn_class_loss: 0.2180 - val_mrcnn_bbox_loss: 0.4079 - val_mrcnn_mask_loss: 0.0000e+00

# %%
# select trained model 
dir_names = next(os.walk(model.model_dir))[1]
key = config.NAME.lower()
dir_names = filter(lambda f: f.startswith(key), dir_names)
dir_names = sorted(dir_names)

if not dir_names:
    import errno
    raise FileNotFoundError(
        errno.ENOENT,
        "Could not find model directory under {}".format(self.model_dir))
    
fps = []
# Pick last directory
for d in dir_names: 
    dir_name = os.path.join(model.model_dir, d)
    # Find the last checkpoint
    checkpoints = next(os.walk(dir_name))[2]
    checkpoints = filter(lambda f: f.startswith("mask_rcnn"), checkpoints)
    checkpoints = sorted(checkpoints)
    if not checkpoints:
        print('No weight files in {}'.format(dir_name))
    else:
        checkpoint = os.path.join(dir_name, checkpoints[-1])
        fps.append(checkpoint)

model_path = sorted(fps)[-1]
print('Found model {}'.format(model_path))
# Out:
# No weight files in ../working_copy2/pneumonia20180916T1814
# No weight files in ../working_copy2/pneumonia20180916T1913
# No weight files in ../working_copy2/pneumonia20180916T1935
# No weight files in ../working_copy2/pneumonia20180916T2110
# No weight files in ../working_copy2/pneumonia20180918T2217
# No weight files in ../working_copy2/pneumonia20180918T2308
# No weight files in ../working_copy2/pneumonia20180918T2313
# No weight files in ../working_copy2/pneumonia20180919T0003
# Found model ../working_copy2/pneumonia20180919T2113/mask_rcnn_pneumonia_0040.h5

# %%
class InferenceConfig(DetectorConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode='inference', 
                          config=inference_config,
                          model_dir=ROOT_DIR)

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  ../working_copy2/pneumonia20180919T2113/mask_rcnn_pneumonia_0040.h5
# Re-starting from epoch 40

# %%
# set color for class
def get_colors_for_class_ids(class_ids):
    colors = []
    for class_id in class_ids:
        if class_id == 1:
            colors.append((.941, .204, .204))
    return colors

# %% [markdown]
# ### How does the predicted box compared to the expected value? Let's use the validation dataset to check.
#
# Note that we trained only one epoch for **demonstration purposes ONLY**. You might be able to improve performance running more epochs.

# %%
# Show few example of ground truth vs. predictions on the validation dataset 
dataset = dataset_val
fig = plt.figure(figsize=(10, 30))

for i in range(6):

    image_id = random.choice(dataset.image_ids)
    
    original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config, 
                               image_id, use_mini_mask=False)
    
    print(original_image.shape)
    plt.subplot(6, 2, 2*i + 1)
    visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                                dataset.class_names,
                                colors=get_colors_for_class_ids(gt_class_id), ax=fig.axes[-1])
    
    plt.subplot(6, 2, 2*i + 2)
    results = model.detect([original_image]) #, verbose=1)
    r = results[0]
    visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                                dataset.class_names, r['scores'], 
                                colors=get_colors_for_class_ids(r['class_ids']), ax=fig.axes[-1])
# Out:
# (256, 256, 3)
#
# *** No instances to display ***
#
# (256, 256, 3)
#
# *** No instances to display ***
#
# (256, 256, 3)
#
# *** No instances to display ***
#
# (256, 256, 3)
#
# *** No instances to display ***
#
# (256, 256, 3)
#
# *** No instances to display ***
#
# (256, 256, 3)
#
# *** No instances to display ***

# %%
# Get filenames of test dataset DICOM images
test_image_fps = get_dicom_fps(test_dicom_dir)

# %% [markdown]
# ### Final steps - Create the submission file

# %%
# Make predictions on test images, write out sample submission 
def predict(image_fps, filepath='submission.csv', min_conf=0.4): 
    
    # assume square image
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    print(resize_factor)
    #resize_factor = ORIG_SIZE 
    with open(filepath, 'w') as file:
        file.write("patientId,PredictionString\n")

        for image_id in tqdm(image_fps): 
            ds = pydicom.read_file(image_id)
            image = ds.pixel_array
            # If grayscale. Convert to RGB for consistency.
            if len(image.shape) != 3 or image.shape[2] != 3:
                image = np.stack((image,) * 3, -1) 
            image, window, scale, padding, crop = utils.resize_image(
                image,
                min_dim=config.IMAGE_MIN_DIM,
                min_scale=config.IMAGE_MIN_SCALE,
                max_dim=config.IMAGE_MAX_DIM,
                mode=config.IMAGE_RESIZE_MODE)

            patient_id = os.path.splitext(os.path.basename(image_id))[0]

            results = model.detect([image])
            r = results[0]

            out_str = ""
            out_str += patient_id 
            out_str += ","
            assert( len(r['rois']) == len(r['class_ids']) == len(r['scores']) )
            if len(r['rois']) == 0: 
                pass
            else: 
                num_instances = len(r['rois'])

                for i in range(num_instances): 
                    if r['scores'][i] > min_conf: 
                        out_str += ' '
                        out_str += str(round(r['scores'][i], 2))
                        out_str += ' '

                        # x1, y1, width, height 
                        x1 = r['rois'][i][1]
                        y1 = r['rois'][i][0]
                        width = r['rois'][i][3] - x1 
                        height = r['rois'][i][2] - y1 
                        bboxes_str = "{} {} {} {}".format(x1*resize_factor, y1*resize_factor, \
                                                           width*resize_factor, height*resize_factor)   
                        #bboxes_str = "{} {} {} {}".format(x1, y1, \
                        #                                   width, height)
                        out_str += bboxes_str

            file.write(out_str+"\n")

# %%
# predict only the first 50 entries ??
submission_fp = os.path.join(ROOT_DIR, 'submission40-1024-steps.csv')
print(submission_fp)
predict(test_image_fps, filepath=submission_fp)
# Out:
#   0%|          | 2/1000 [00:00<01:15, 13.21it/s]
# ../working_copy2/submission40-1024-steps.csv
# 4.0
# 100%|██████████| 1000/1000 [01:01<00:00, 16.16it/s]

# %%
output = pd.read_csv(submission_fp, names=['patientId', 'PredictionString'])
output.head(60)
# Out:
#                                patientId  \
# 0                              patientId
# 1   266afd14-8d94-44b8-951b-9c239ab224a1
# 2   21cca2a5-6cb9-4667-bde6-5fe4ac8d2a29
# 3   108eeb60-7701-4796-86a8-1447fd8a0ff7
# 4   26c94e32-023b-4963-aca3-525ac2752d2c
# 5   1fbb3006-6ce6-47a5-be74-9ddcaf9b3ef0
# 6   11e431ff-c6b8-45f1-9635-a055fbc90111
# 7   2387db99-efe6-4e4b-bbc8-6f725e1b757e
# 8   1d3e4775-9d2c-4e5f-81de-ce29b540a9f7
# 9   2b1e28fe-e10f-4c40-bd0b-7f29f88afd6f
# 10  0f639fad-780e-44f8-ba8d-0c934bdca870
# 11  1e1c3b02-27fa-42a2-b51b-f46378e09fde
# 12  2f55c07d-beb7-4b5f-9e9d-18d4fed5ae27
# 13  11fcbe52-87f7-4074-85ac-153d5f255e35
# 14  13eee970-ca31-44a9-9b8a-83e317f129dc
# 15  2a54c3ee-7d7f-4c32-9b77-87279b8777a7
# 16  c0a4c55a-bd1b-4459-ba2a-8a687c2732e9
# 17  2050fb88-70cb-40db-810d-038337613147
# 18  28f1790b-5643-4db3-9d4d-de30d4784a0c
# 19  1eef9264-e6e3-41ba-b5fa-6a2ab638a7c9
# 20  c110e1ed-fb28-4b3d-b450-e370f13d4293
# 21  21b97415-1275-4483-9705-af9174fc2b4f
# 22  270d287b-5f32-469d-9f88-f4a87f27ef47
# 23  2c1a4681-22eb-441b-9fe4-f3ef4dcc918b
# 24  03774732-81ca-4da0-a35c-ec222c14a4c9
# 25  3132440e-c4bc-4dc5-b7af-ef3e082ed989
# 26  2391484d-edaa-4e8d-a993-1ff779eafce7
# 27  0f65daf5-08f1-439a-8a50-2e64f1a8a5ac
# 28  2cd0cbc4-bf35-49de-963e-8ee3fd08ca75
# 29  0e9d2259-5faa-4000-969c-f4d25d4eed0d
# 30  246bf123-5a0d-4a3d-b4b4-6e442f8a830c
# 31  126de93a-1209-428c-aa3d-790991cd14e5
# 32  1e83e240-c08d-4f0a-8236-d11a3f8d95ac
# 33  0111d61a-8a5d-4dc8-8c00-7365f8a8de3d
# 34  12fd0651-0275-4d15-8868-35ba85ea70f0
# 35  19b1f7ba-bd40-4e8d-813d-da977b2306b3
# 36  055fee13-c09c-4635-b35e-e50b9215d1c3
# 37  23815776-6d93-4835-867a-1b251b10b1d3
# 38  0e245423-3ccd-41ee-84a5-b9f0a20dba71
# 39  2152d0ec-5d28-4b15-bb45-422e110aad20
# 40  2baa8ae3-27e1-4193-b51e-68e2a1cc516a
# 41  2550ee5f-ea6e-4683-8aeb-54ab06e0c318
# 42  3036ca10-8d42-4749-81e2-8ed235a6a567
# 43  0d1b742e-71fb-4eaa-88eb-b70e403ee565
# 44  2a0cf5f5-e589-444e-8be8-1cae28382e34
# 45  232f6bcd-2006-459a-9b30-b51beea28044
# 46  2c7b3f02-3fe4-4d33-88d5-413fcf18b118
# 47  1d247b6c-0687-40bf-839e-fd30e01c585d
# 48  1ae12f84-02bb-426f-84b1-81a6c552ce4e
# 49  21cbfa1b-6faa-4356-b1eb-a180d7d9b4ac
# 50  21273117-1e4c-4f9a-8ed1-f11b7c063060
# 51  1c2707d4-9385-4228-823c-51fb2a956646
# 52  10f8e8da-3c33-4c68-8c10-bba18360b166
# 53  014c6a19-38e2-4e7f-8f14-dd4f0a4582e4
# 54  018951e6-9fb3-4e92-8ce7-e3a018daf93f
# 55  c1718678-44af-407f-829a-fc65bc854094
# 56  0409b97f-7673-42e2-9943-0656c6aaca69
# 57  c1c3ec5d-20ba-42f7-91f9-48032d97ffc9
# 58  254f04d1-d24e-43bc-a00d-8f7140c222fb
# 59  25c7d4f1-d16e-4fba-9155-8f79a396aa81
#
#                                      PredictionString
# 0                                    PredictionString
# 1    0.93 292.0 474.0 162.0 150.0 0.79 646.0 566.0...
# 2    0.94 234.0 576.0 156.0 144.0 0.84 648.0 600.0...
# 3    0.83 760.0 404.0 140.0 202.0 0.77 174.0 392.0...
# 4    0.9 216.0 230.0 240.0 348.0 0.86 632.0 240.0 ...
# 5    0.79 164.0 298.0 228.0 392.0 0.79 528.0 228.0...
# 6    0.82 242.0 480.0 142.0 206.0 0.81 504.0 528.0...
# 7    0.85 270.0 220.0 272.0 376.0 0.77 662.0 226.0...
# 8    0.89 270.0 352.0 132.0 136.0 0.87 616.0 358.0...
# 9    0.91 184.0 580.0 222.0 204.0 0.88 628.0 596.0...
# 10   0.88 640.0 602.0 220.0 266.0 0.85 248.0 404.0...
# 11   0.94 484.0 312.0 318.0 576.0 0.94 76.0 222.0 ...
# 12   0.88 232.0 290.0 218.0 190.0 0.73 618.0 386.0...
# 13   0.95 140.0 438.0 222.0 348.0 0.95 516.0 486.0...
# 14   0.88 574.0 364.0 232.0 450.0 0.86 218.0 492.0...
# 15                       0.75 572.0 228.0 190.0 402.0
# 16   0.91 160.0 474.0 222.0 250.0 0.89 554.0 474.0...
# 17   0.87 220.0 368.0 210.0 290.0 0.84 600.0 394.0...
# 18   0.86 218.0 452.0 224.0 312.0 0.79 600.0 406.0...
# 19   0.87 156.0 574.0 206.0 280.0 0.81 504.0 222.0...
# 20   0.85 268.0 398.0 216.0 256.0 0.74 618.0 422.0...
# 21                       0.91 240.0 482.0 242.0 306.0
# 22   0.85 596.0 406.0 216.0 138.0 0.54 238.0 396.0...
# 23   0.94 178.0 408.0 242.0 250.0 0.83 592.0 256.0...
# 24   0.97 574.0 434.0 198.0 316.0 0.92 214.0 302.0...
# 25   0.91 226.0 486.0 220.0 172.0 0.9 604.0 338.0 ...
# 26   0.88 176.0 480.0 240.0 114.0 0.8 554.0 484.0 ...
# 27   0.85 290.0 212.0 150.0 188.0 0.74 604.0 450.0...
# 28   0.96 158.0 414.0 232.0 258.0 0.87 566.0 246.0...
# 29   0.93 200.0 350.0 212.0 218.0 0.9 608.0 436.0 ...
# 30   0.74 582.0 578.0 262.0 236.0 0.68 186.0 660.0...
# 31   0.94 176.0 604.0 240.0 256.0 0.85 600.0 458.0...
# 32   0.96 268.0 476.0 144.0 210.0 0.91 642.0 418.0...
# 33   0.9 650.0 490.0 220.0 286.0 0.71 302.0 426.0 ...
# 34   0.95 178.0 620.0 174.0 188.0 0.79 618.0 770.0...
# 35   0.97 210.0 412.0 220.0 344.0 0.85 596.0 370.0...
# 36   0.89 626.0 532.0 238.0 364.0 0.55 0.0 304.0 2...
# 37   0.89 138.0 436.0 280.0 224.0 0.79 580.0 528.0...
# 38   0.94 344.0 352.0 204.0 378.0 0.91 630.0 344.0...
# 39   0.91 156.0 262.0 242.0 390.0 0.72 190.0 612.0...
# 40   0.86 210.0 576.0 234.0 370.0 0.75 678.0 676.0...
# 41   0.81 638.0 656.0 224.0 312.0 0.79 244.0 558.0...
# 42   0.93 200.0 380.0 238.0 312.0 0.54 576.0 450.0...
# 43   0.91 216.0 636.0 234.0 190.0 0.57 230.0 514.0...
# 44   0.89 542.0 300.0 290.0 566.0 0.86 162.0 564.0...
# 45   0.9 174.0 514.0 128.0 136.0 0.88 556.0 350.0 ...
# 46                       0.68 636.0 564.0 130.0 196.0
# 47   0.91 236.0 494.0 230.0 278.0 0.88 646.0 468.0...
# 48   0.91 698.0 518.0 174.0 170.0 0.68 198.0 486.0...
# 49   0.77 592.0 358.0 314.0 288.0 0.71 194.0 358.0...
# 50   0.72 210.0 444.0 214.0 102.0 0.69 694.0 448.0...
# 51   0.94 220.0 224.0 234.0 424.0 0.79 618.0 600.0...
# 52   0.79 84.0 460.0 254.0 280.0 0.72 596.0 426.0 ...
# 53   0.88 126.0 470.0 250.0 328.0 0.88 580.0 452.0...
# 54   0.91 616.0 372.0 280.0 308.0 0.91 222.0 424.0...
# 55   0.96 190.0 418.0 180.0 160.0 0.87 528.0 268.0...
# 56   0.78 554.0 304.0 230.0 310.0 0.68 228.0 400.0...
# 57   0.9 580.0 388.0 286.0 396.0 0.89 198.0 424.0 ...
# 58   0.94 514.0 334.0 288.0 592.0 0.93 116.0 286.0...
# 59   0.98 172.0 444.0 214.0 236.0 0.88 584.0 360.0...

# %%
# show a few test image detection example
def visualize(): 
    image_id = random.choice(test_image_fps)
    ds = pydicom.read_file(image_id)
    
    # original image 
    image = ds.pixel_array
    
    # assume square image 
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    
    # If grayscale. Convert to RGB for consistency.
    if len(image.shape) != 3 or image.shape[2] != 3:
        image = np.stack((image,) * 3, -1) 
    resized_image, window, scale, padding, crop = utils.resize_image(
        image,
        min_dim=config.IMAGE_MIN_DIM,
        min_scale=config.IMAGE_MIN_SCALE,
        max_dim=config.IMAGE_MAX_DIM,
        mode=config.IMAGE_RESIZE_MODE)

    patient_id = os.path.splitext(os.path.basename(image_id))[0]
    print(patient_id)

    results = model.detect([resized_image])
    r = results[0]
    for bbox in r['rois']: 
        print(bbox)
        x1 = int(bbox[1] * resize_factor)
        y1 = int(bbox[0] * resize_factor)
        x2 = int(bbox[3] * resize_factor)
        y2 = int(bbox[2]  * resize_factor)
        cv2.rectangle(image, (x1,y1), (x2,y2), (77, 255, 9), 3, 1)
        width = x2 - x1 
        height = y2 - y1 
        print("x {} y {} h {} w {}".format(x1, y1, width, height))
    plt.figure() 
    plt.imshow(image, cmap=plt.cm.gist_gray)

visualize()
visualize()
visualize()
visualize()
# Out:
# 149173ac-662a-4883-834d-43ff97a29b18
# [235 294 331 416]
# x 588 y 470 h 244 w 192
# [208  95 296 193]
# x 190 y 416 h 196 w 176
# [288  59 372 205]
# x 118 y 576 h 292 w 168
# 1ed2b1aa-c8e6-4b76-aaeb-289fecd0095b
# [272 151 348 222]
# x 302 y 544 h 142 w 152
# [294 309 406 450]
# x 618 y 588 h 282 w 224
# [102 131 197 218]
# x 262 y 204 h 174 w 190
# 2744f4b1-f0a3-4f65-be56-2b93eb72f56a
# [302 322 372 386]
# x 644 y 604 h 128 w 140
# [258 134 314 228]
# x 268 y 516 h 188 w 112
# [ 73 146 151 219]
# x 292 y 146 h 146 w 156
# 2152d0ec-5d28-4b15-bb45-422e110aad20
# [147  99 298 198]
# x 198 y 294 h 198 w 302
# [286 332 384 405]
# x 664 y 572 h 146 w 196
# [309 277 390 347]
# x 554 y 618 h 140 w 162

# %%
# remove files to allow committing (hit files limit otherwise)
# !rm -rf /kaggle/working/Mask_RCNN
