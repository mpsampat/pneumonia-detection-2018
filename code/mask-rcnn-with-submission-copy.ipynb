# %% [markdown]
# **Mask-RCNN Sample Starter Model for the RSNA Pneumonia Detection Challenge**
#
# [MD.ai](https://www.md.ai). The dataset for this challenge, created on the MD.ai platform in collaboration with the Radiological Society of North America (RSNA), the Society of Thoracic Radiology (STR), the US National Institutes of Health (NIH), and Kaggle.
# This notebook covers the basics of parsing the competition dataset, training using a detector basd on the [Mask-RCNN algorithm](https://arxiv.org/abs/1703.06870) for object detection and instance segmentation.
# **Note that the Mask-RCNN detector configuration parameters have been selected to reduce training time for demonstration purposes, they are not optimal.
# **
#
# This is based on our deep learning for medical imaging lessons:
#
# - Lesson 1. Classification of chest vs. adominal X-rays using TensorFlow/Keras [Github](https://github.com/mdai/ml-lessons/blob/master/lesson1-xray-images-classification.ipynb) [Annotator](https://public.md.ai/annotator/project/PVq9raBJ)
# - Lesson 2. Lung X-Rays Semantic Segmentation using UNets. [Github](https://github.com/mdai/ml-lessons/blob/master/lesson2-lung-xrays-segmentation.ipynb)
# [Annotator](https://public.md.ai/annotator/project/aGq4k6NW/workspace)
# - Lesson 3. RSNA Pneumonia detection using Kaggle data format [Github](https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-kaggle.ipynb) [Annotator](https://public.md.ai/annotator/project/LxR6zdR2/workspace)
# - Lesson 3. RSNA Pneumonia detection using MD.ai python client library [Github](https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-mdai-client-lib.ipynb) [Annotator](https://public.md.ai/annotator/project/LxR6zdR2/workspace)
#
# *Copyright 2018 MD.ai, Inc.
# Licensed under the Apache License, Version 2.0*

# %%
import os 
import sys
import random
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt
import json
import pydicom
from imgaug import augmenters as iaa
from tqdm import tqdm
import pandas as pd 
import glob

# %% [markdown]
# ### First: Install Kaggle API for download competition data.

# %%
DATA_DIR = '../input'

# Directory to save logs and trained model
ROOT_DIR = '../working_copy_75_epoch'
# !ls ../input
# Out:
# GCP%20Credits%20Request%20Link%20-%20RSNA.txt  stage_1_test_images
# stage_1_detailed_class_info.csv		       stage_1_train_images
# stage_1_detailed_class_info.csv.zip	       stage_1_train_labels.csv
# stage_1_sample_submission.csv		       stage_1_train_labels.csv.zip

# %% [markdown]
# ###  MD.ai Annotator
#
# Additionally, If you are interested in augmenting the existing annotations, you can use the MD.ai annotator to view DICOM images, and create annotatios to be exported.
# MD.ai annotator project URL for the Kaggle dataset: https://public.md.ai/annotator/project/LxR6zdR2/workspace
#
# **Annotator features**
# - The annotator can be used to view DICOM images and create image and exam level annotations.
# - You can apply the annotator to filter by label, adjudicate annotations, and assign annotation tasks to your team.
# - Notebooks can be built directly within the annotator for rapid model development.
# - The data wrangling is abstracted away by the interface and by our MD.ai library.
# - Simplifies image annotation in order to widen the participation in the futrue of medical image deep learning.
#
# The annotator allows you to create initial annotations, build and run models, modify/finetune the annotations based on predicted values, and repeat.
# The MD.ai python client library implements functions to easily download images and annotations and to prepare the datasets used to train the model for classification. See the following example notebook for parsing annotations and training using MD.ai annotator:
# https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-mdai-client-lib.ipynb
# - MD.ai URL: https://www.md.ai
# - MD.ai documentation URL: https://docs.md.ai/

# %% [markdown]
# ### Install Matterport's Mask-RCNN model from github.
# See the [Matterport's implementation of Mask-RCNN](https://github.com/matterport/Mask_RCNN).

# %%
#!git clone https://www.github.com/matterport/Mask_RCNN.git
#os.chdir('Mask_RCNN')
##!python setup.py -q install

# %%
# Import Mask RCNN
sys.path.append(os.path.join("/home/mehul/kaggle/pneumonia-detection-2018", 'Mask_RCNN'))  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train_dicom_dir = os.path.join(DATA_DIR, 'stage_1_train_images')
test_dicom_dir = os.path.join(DATA_DIR, 'stage_1_test_images')

# %% [markdown]
# ### Some setup functions and classes for Mask-RCNN
#
# - dicom_fps is a list of the dicom image path and filenames
# - image_annotions is a dictionary of the annotations keyed by the filenames
# - parsing the dataset returns a list of the image filenames and the annotations dictionary

# %%
def get_dicom_fps(dicom_dir):
    dicom_fps = glob.glob(dicom_dir+'/'+'*.dcm')
    return list(set(dicom_fps))

def parse_dataset(dicom_dir, anns): 
    image_fps = get_dicom_fps(dicom_dir)
    image_annotations = {fp: [] for fp in image_fps}
    for index, row in anns.iterrows(): 
        fp = os.path.join(dicom_dir, row['patientId']+'.dcm')
        image_annotations[fp].append(row)
    return image_fps, image_annotations

# %%
# The following parameters have been selected to reduce running time for demonstration purposes 
# These are not optimal 

class DetectorConfig(Config):
    """Configuration for training pneumonia detection on the RSNA pneumonia dataset.
    Overrides values in the base Config class.
    """
    
    # Give the configuration a recognizable name  
    NAME = 'pneumonia'
    
    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 2
    
    BACKBONE = 'resnet50'
    
    NUM_CLASSES = 2  # background + 1 pneumonia classes
    
    IMAGE_MIN_DIM = 512
    IMAGE_MAX_DIM = 512
    RPN_ANCHOR_SCALES = (32, 64, 128, 256)
    TRAIN_ROIS_PER_IMAGE = 32
    MAX_GT_INSTANCES = 5
    DETECTION_MAX_INSTANCES = 3
    DETECTION_MIN_CONFIDENCE = 0.4
    DETECTION_NMS_THRESHOLD = 0.1

    STEPS_PER_EPOCH = 512
    LOSS_WEIGHTS = {
        "rpn_class_loss": 1.,
        "rpn_bbox_loss": 1.,
        "mrcnn_class_loss": 1.,
        "mrcnn_bbox_loss": 1.,
        "mrcnn_mask_loss": 1.
    }

    
config = DetectorConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        3
# DETECTION_MIN_CONFIDENCE       0.4
# DETECTION_NMS_THRESHOLD        0.1
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  512
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [512 512   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               5
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           pneumonia
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                512
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
class DetectorDataset(utils.Dataset):
    """Dataset class for training pneumonia detection on the RSNA pneumonia dataset.
    """

    def __init__(self, image_fps, image_annotations, orig_height, orig_width):
        super().__init__(self)
        
        # Add classes
        self.add_class('pneumonia', 1, 'Lung Opacity')
        
        # add images 
        for i, fp in enumerate(image_fps):
            annotations = image_annotations[fp]
            self.add_image('pneumonia', image_id=i, path=fp, 
                           annotations=annotations, orig_height=orig_height, orig_width=orig_width)
            
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

    def load_image(self, image_id):
        info = self.image_info[image_id]
        fp = info['path']
        ds = pydicom.read_file(fp)
        image = ds.pixel_array
        # If grayscale. Convert to RGB for consistency.
        if len(image.shape) != 3 or image.shape[2] != 3:
            image = np.stack((image,) * 3, -1)
        return image

    def load_mask(self, image_id):
        info = self.image_info[image_id]
        annotations = info['annotations']
        count = len(annotations)
        if count == 0:
            mask = np.zeros((info['orig_height'], info['orig_width'], 1), dtype=np.uint8)
            class_ids = np.zeros((1,), dtype=np.int32)
        else:
            mask = np.zeros((info['orig_height'], info['orig_width'], count), dtype=np.uint8)
            class_ids = np.zeros((count,), dtype=np.int32)
            for i, a in enumerate(annotations):
                if a['Target'] == 1:
                    x = int(a['x'])
                    y = int(a['y'])
                    w = int(a['width'])
                    h = int(a['height'])
                    mask_instance = mask[:, :, i].copy()
                    cv2.rectangle(mask_instance, (x, y), (x+w, y+h), 255, -1)
                    mask[:, :, i] = mask_instance
                    class_ids[i] = 1
        return mask.astype(np.bool), class_ids.astype(np.int32)

# %% [markdown]
# ### Examine the annotation data, parse the dataset, and view dicom fields

# %%
# training dataset
anns = pd.read_csv(os.path.join(DATA_DIR, 'stage_1_train_labels.csv'))
anns.head()
# Out:
#                               patientId      x      y  width  height  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1

# %%
image_fps, image_annotations = parse_dataset(train_dicom_dir, anns=anns)

# %%
ds = pydicom.read_file(image_fps[0]) # read dicom image from filepath 
image = ds.pixel_array # get image array

# %%
# show dicom fields 
ds
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.8323329.10686.1517874353.485228
# (0008, 0020) Study Date                          DA: '19010101'
# (0008, 0030) Study Time                          TM: '000000.00'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 103e) Series Description                  LO: 'view: PA'
# (0010, 0010) Patient's Name                      PN: '4fc92d65-52c1-498a-8206-f420eec1a030'
# (0010, 0020) Patient ID                          LO: '4fc92d65-52c1-498a-8206-f420eec1a030'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '73'
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 5101) View Position                       CS: 'PA'
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.8323329.10686.1517874353.485227
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.8323329.10686.1517874353.485226
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1024
# (0028, 0011) Columns                             US: 1024
# (0028, 0030) Pixel Spacing                       DS: ['0.14300000000000002', '0.14300000000000002']
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 2110) Lossy Image Compression             CS: '01'
# (0028, 2114) Lossy Image Compression Method      CS: 'ISO_10918_1'
# (7fe0, 0010) Pixel Data                          OB: Array of 153334 bytes

# %%
# Original DICOM image size: 1024 x 1024
ORIG_SIZE = 1024

# %% [markdown]
# ### Split the data into training and validation datasets
# **Note: We have only used only a portion of the images for demonstration purposes. See comments below.**
#
#  - To use all the images do: image_fps_list = list(image_fps)
#  - Or change the number of images from 100 to a custom number

# %%
######################################################################
# Modify this line to use more or fewer images for training/validation. 
# To use all images, do: image_fps_list = list(image_fps)
image_fps_list = list(image_fps) 
#####################################################################

# split dataset into training vs. validation dataset 
# split ratio is set to 0.9 vs. 0.1 (train vs. validation, respectively)
#sorted(image_fps_list)
random.seed(42)
random.shuffle(image_fps_list)

validation_split = 0.1
split_index = int((1 - validation_split) * len(image_fps_list))

image_fps_train = image_fps_list[:split_index]
image_fps_val = image_fps_list[split_index:]

print(len(image_fps_train), len(image_fps_val))
# Out:
# 23115 2569

# %% [markdown]
# ### Create and prepare the training dataset using the DetectorDataset class.

# %%
# prepare the training dataset
dataset_train = DetectorDataset(image_fps_train, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_train.prepare()

# %% [markdown]
# ### Let's look at a sample annotation. We see a bounding box with (x, y) of the the top left corner as well as the width and height.

# %%
# Show annotation(s) for a DICOM image 
test_fp = random.choice(image_fps_train)
image_annotations[test_fp]
# Out:
# [patientId    fd434b64-6bb8-4829-a529-a66464af090c
#  x                                             NaN
#  y                                             NaN
#  width                                         NaN
#  height                                        NaN
#  Target                                          0
#  Name: 28629, dtype: object]

# %%
# prepare the validation dataset
dataset_val = DetectorDataset(image_fps_val, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_val.prepare()

# %% [markdown]
# ### Display a random image with bounding boxes

# %%
# Load and display random samples and their bounding boxes
# Suggestion: Run this a few times to see different examples. 

image_id = random.choice(dataset_train.image_ids)
image_fp = dataset_train.image_reference(image_id)
image = dataset_train.load_image(image_id)
mask, class_ids = dataset_train.load_mask(image_id)

print(image.shape)

plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(image[:, :, 0], cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
masked = np.zeros(image.shape[:2])
for i in range(mask.shape[2]):
    masked += image[:, :, 0] * mask[:, :, i]
plt.imshow(masked, cmap='gray')
plt.axis('off')

print(image_fp)
print(class_ids)
# Out:
# (1024, 1024, 3)
# ../input/stage_1_train_images/db044ffe-7f5f-47f0-82e9-31ecd93e85ac.dcm
# [0]

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)

# %% [markdown]
# ### Image Augmentation. Try finetuning some variables to custom values

# %%
# Image augmentation 
augmentation = iaa.SomeOf((0, 2), [
    iaa.Affine(
        scale={"x": (0.95, 1.05), "y": (0.95, 1.05)},
        translate_percent={"x": (-0.05, 0.05), "y": (-0.05, 0.05)},
        rotate=(-5, 5),
        shear=(-2, 2)
    ),
    iaa.Multiply((0.9, 1.1))
])

# %% [markdown]
# ### Now it's time to train the model. Note that training even a basic model can take a few hours.
#
# Note: the following model is for demonstration purpose only. We have limited the training to one epoch, and have set nominal values for the Detector Configuration to reduce run-time.
#
# - dataset_train and dataset_val are derived from DetectorDataset
# - DetectorDataset loads images from image filenames and  masks from the annotation data
# - model is Mask-RCNN

# %%
'''
NUM_EPOCHS = 50

# Train Mask-RCNN Model 
import warnings 
warnings.filterwarnings("ignore")
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=25, 
            layers='heads',
            augmentation=augmentation)

model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE/10, 
            epochs=50, 
            layers='all',
            augmentation=augmentation)

model.train(dataset_train, dataset_val,
                     learning_rate=config.LEARNING_RATE/100,
                     epochs=75,
                     layers='all',
                     augmentation=augmentation)
'''
# Out:
# '\nNUM_EPOCHS = 50\n\n# Train Mask-RCNN Model \nimport warnings \nwarnings.filterwarnings("ignore")\nmodel.train(dataset_train, dataset_val, \n            learning_rate=config.LEARNING_RATE, \n            epochs=25, \n            layers=\'heads\',\n            augmentation=augmentation)\n\nmodel.train(dataset_train, dataset_val, \n            learning_rate=config.LEARNING_RATE/10, \n            epochs=50, \n            layers=\'all\',\n            augmentation=augmentation)\n\nmodel.train(dataset_train, dataset_val,\n                     learning_rate=config.LEARNING_RATE/100,\n                     epochs=75,\n                     layers=\'all\',\n                     augmentation=augmentation)\n'

# %%
import warnings 
# Model weights to start training with
init_with = "imagenet"  # imagenet, last, or some pretrained model
if init_with == "imagenet":
    weights_path = model.get_imagenet_weights()
    model.load_weights(weights_path, by_name=True)

warnings.filterwarnings("ignore")
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=25, 
            layers='all')

warnings.filterwarnings("ignore")
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE/2, 
            epochs=50, 
            layers='all')

warnings.filterwarnings("ignore")
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE/4, 
            epochs=75, 
            layers='all')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: ../working_copy_75_epoch/pneumonia20180930T0128/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/25
# 512/512 [==============================] - 309s 603ms/step - loss: 1.8825 - rpn_class_loss: 0.0613 - rpn_bbox_loss: 0.4525 - mrcnn_class_loss: 0.2786 - mrcnn_bbox_loss: 0.5571 - mrcnn_mask_loss: 0.5330 - val_loss: 1.5909 - val_rpn_class_loss: 0.0231 - val_rpn_bbox_loss: 0.3488 - val_mrcnn_class_loss: 0.2551 - val_mrcnn_bbox_loss: 0.4943 - val_mrcnn_mask_loss: 0.4696
# Epoch 2/25
# 512/512 [==============================] - 202s 395ms/step - loss: 1.5718 - rpn_class_loss: 0.0212 - rpn_bbox_loss: 0.3675 - mrcnn_class_loss: 0.2566 - mrcnn_bbox_loss: 0.4783 - mrcnn_mask_loss: 0.4481 - val_loss: 1.4884 - val_rpn_class_loss: 0.0181 - val_rpn_bbox_loss: 0.3278 - val_mrcnn_class_loss: 0.2489 - val_mrcnn_bbox_loss: 0.4489 - val_mrcnn_mask_loss: 0.4447
# Epoch 3/25
# 512/512 [==============================] - 206s 403ms/step - loss: 1.4924 - rpn_class_loss: 0.0171 - rpn_bbox_loss: 0.3389 - mrcnn_class_loss: 0.2605 - mrcnn_bbox_loss: 0.4488 - mrcnn_mask_loss: 0.4270 - val_loss: 1.4894 - val_rpn_class_loss: 0.0150 - val_rpn_bbox_loss: 0.3571 - val_mrcnn_class_loss: 0.2338 - val_mrcnn_bbox_loss: 0.4571 - val_mrcnn_mask_loss: 0.4263
# Epoch 4/25
# 512/512 [==============================] - 200s 391ms/step - loss: 1.4455 - rpn_class_loss: 0.0146 - rpn_bbox_loss: 0.3348 - mrcnn_class_loss: 0.2442 - mrcnn_bbox_loss: 0.4373 - mrcnn_mask_loss: 0.4147 - val_loss: 1.3424 - val_rpn_class_loss: 0.0116 - val_rpn_bbox_loss: 0.3207 - val_mrcnn_class_loss: 0.2161 - val_mrcnn_bbox_loss: 0.3857 - val_mrcnn_mask_loss: 0.4083
# Epoch 5/25
# 512/512 [==============================] - 197s 386ms/step - loss: 1.4105 - rpn_class_loss: 0.0147 - rpn_bbox_loss: 0.3247 - mrcnn_class_loss: 0.2458 - mrcnn_bbox_loss: 0.4172 - mrcnn_mask_loss: 0.4081 - val_loss: 1.3984 - val_rpn_class_loss: 0.0145 - val_rpn_bbox_loss: 0.3257 - val_mrcnn_class_loss: 0.2486 - val_mrcnn_bbox_loss: 0.4163 - val_mrcnn_mask_loss: 0.3932
# Epoch 6/25
# 512/512 [==============================] - 190s 370ms/step - loss: 1.3727 - rpn_class_loss: 0.0129 - rpn_bbox_loss: 0.3086 - mrcnn_class_loss: 0.2474 - mrcnn_bbox_loss: 0.4050 - mrcnn_mask_loss: 0.3989 - val_loss: 1.3454 - val_rpn_class_loss: 0.0121 - val_rpn_bbox_loss: 0.2853 - val_mrcnn_class_loss: 0.2229 - val_mrcnn_bbox_loss: 0.4086 - val_mrcnn_mask_loss: 0.4165
# Epoch 7/25
# 512/512 [==============================] - 191s 373ms/step - loss: 1.3869 - rpn_class_loss: 0.0129 - rpn_bbox_loss: 0.3165 - mrcnn_class_loss: 0.2481 - mrcnn_bbox_loss: 0.4108 - mrcnn_mask_loss: 0.3986 - val_loss: 1.3748 - val_rpn_class_loss: 0.0130 - val_rpn_bbox_loss: 0.2928 - val_mrcnn_class_loss: 0.2631 - val_mrcnn_bbox_loss: 0.4130 - val_mrcnn_mask_loss: 0.3929
# Epoch 8/25
# 512/512 [==============================] - 190s 371ms/step - loss: 1.3194 - rpn_class_loss: 0.0117 - rpn_bbox_loss: 0.3036 - mrcnn_class_loss: 0.2252 - mrcnn_bbox_loss: 0.3855 - mrcnn_mask_loss: 0.3934 - val_loss: 1.3462 - val_rpn_class_loss: 0.0118 - val_rpn_bbox_loss: 0.2820 - val_mrcnn_class_loss: 0.2551 - val_mrcnn_bbox_loss: 0.4067 - val_mrcnn_mask_loss: 0.3905
# Epoch 9/25
# 512/512 [==============================] - 188s 367ms/step - loss: 1.3329 - rpn_class_loss: 0.0116 - rpn_bbox_loss: 0.3087 - mrcnn_class_loss: 0.2240 - mrcnn_bbox_loss: 0.3951 - mrcnn_mask_loss: 0.3934 - val_loss: 1.2220 - val_rpn_class_loss: 0.0092 - val_rpn_bbox_loss: 0.2512 - val_mrcnn_class_loss: 0.2345 - val_mrcnn_bbox_loss: 0.3602 - val_mrcnn_mask_loss: 0.3668
# Epoch 10/25
# 512/512 [==============================] - 188s 367ms/step - loss: 1.2977 - rpn_class_loss: 0.0110 - rpn_bbox_loss: 0.3091 - mrcnn_class_loss: 0.2049 - mrcnn_bbox_loss: 0.3818 - mrcnn_mask_loss: 0.3909 - val_loss: 1.3208 - val_rpn_class_loss: 0.0117 - val_rpn_bbox_loss: 0.2790 - val_mrcnn_class_loss: 0.2308 - val_mrcnn_bbox_loss: 0.3999 - val_mrcnn_mask_loss: 0.3994
# Epoch 11/25
# 512/512 [==============================] - 191s 373ms/step - loss: 1.2805 - rpn_class_loss: 0.0111 - rpn_bbox_loss: 0.3051 - mrcnn_class_loss: 0.2056 - mrcnn_bbox_loss: 0.3732 - mrcnn_mask_loss: 0.3855 - val_loss: 1.2550 - val_rpn_class_loss: 0.0090 - val_rpn_bbox_loss: 0.2854 - val_mrcnn_class_loss: 0.1889 - val_mrcnn_bbox_loss: 0.3839 - val_mrcnn_mask_loss: 0.3878
# Epoch 12/25
# 512/512 [==============================] - 191s 373ms/step - loss: 1.2744 - rpn_class_loss: 0.0111 - rpn_bbox_loss: 0.3180 - mrcnn_class_loss: 0.1989 - mrcnn_bbox_loss: 0.3636 - mrcnn_mask_loss: 0.3828 - val_loss: 1.2657 - val_rpn_class_loss: 0.0106 - val_rpn_bbox_loss: 0.2379 - val_mrcnn_class_loss: 0.2303 - val_mrcnn_bbox_loss: 0.4004 - val_mrcnn_mask_loss: 0.3865
# Epoch 13/25
# 512/512 [==============================] - 190s 370ms/step - loss: 1.2615 - rpn_class_loss: 0.0103 - rpn_bbox_loss: 0.2923 - mrcnn_class_loss: 0.1963 - mrcnn_bbox_loss: 0.3736 - mrcnn_mask_loss: 0.3890 - val_loss: 1.2937 - val_rpn_class_loss: 0.0117 - val_rpn_bbox_loss: 0.3745 - val_mrcnn_class_loss: 0.1607 - val_mrcnn_bbox_loss: 0.3657 - val_mrcnn_mask_loss: 0.3811
# Epoch 14/25
# 512/512 [==============================] - 199s 388ms/step - loss: 1.2409 - rpn_class_loss: 0.0106 - rpn_bbox_loss: 0.2978 - mrcnn_class_loss: 0.1839 - mrcnn_bbox_loss: 0.3640 - mrcnn_mask_loss: 0.3846 - val_loss: 1.3277 - val_rpn_class_loss: 0.0114 - val_rpn_bbox_loss: 0.2930 - val_mrcnn_class_loss: 0.2299 - val_mrcnn_bbox_loss: 0.3997 - val_mrcnn_mask_loss: 0.3937
# Epoch 15/25
# 512/512 [==============================] - 190s 370ms/step - loss: 1.2586 - rpn_class_loss: 0.0109 - rpn_bbox_loss: 0.2904 - mrcnn_class_loss: 0.2089 - mrcnn_bbox_loss: 0.3646 - mrcnn_mask_loss: 0.3838 - val_loss: 1.2270 - val_rpn_class_loss: 0.0087 - val_rpn_bbox_loss: 0.2665 - val_mrcnn_class_loss: 0.1819 - val_mrcnn_bbox_loss: 0.3740 - val_mrcnn_mask_loss: 0.3959
# Epoch 16/25
# 512/512 [==============================] - 193s 376ms/step - loss: 1.2180 - rpn_class_loss: 0.0101 - rpn_bbox_loss: 0.2895 - mrcnn_class_loss: 0.1821 - mrcnn_bbox_loss: 0.3548 - mrcnn_mask_loss: 0.3815 - val_loss: 1.1982 - val_rpn_class_loss: 0.0086 - val_rpn_bbox_loss: 0.2536 - val_mrcnn_class_loss: 0.1907 - val_mrcnn_bbox_loss: 0.3680 - val_mrcnn_mask_loss: 0.3773
# Epoch 17/25
# 512/512 [==============================] - 194s 379ms/step - loss: 1.1823 - rpn_class_loss: 0.0092 - rpn_bbox_loss: 0.2759 - mrcnn_class_loss: 0.1729 - mrcnn_bbox_loss: 0.3481 - mrcnn_mask_loss: 0.3763 - val_loss: 1.2373 - val_rpn_class_loss: 0.0108 - val_rpn_bbox_loss: 0.2932 - val_mrcnn_class_loss: 0.1641 - val_mrcnn_bbox_loss: 0.3808 - val_mrcnn_mask_loss: 0.3884
# Epoch 18/25
# 512/512 [==============================] - 195s 381ms/step - loss: 1.2135 - rpn_class_loss: 0.0099 - rpn_bbox_loss: 0.2687 - mrcnn_class_loss: 0.1947 - mrcnn_bbox_loss: 0.3605 - mrcnn_mask_loss: 0.3796 - val_loss: 1.3001 - val_rpn_class_loss: 0.0093 - val_rpn_bbox_loss: 0.3501 - val_mrcnn_class_loss: 0.1989 - val_mrcnn_bbox_loss: 0.3609 - val_mrcnn_mask_loss: 0.3808
# Epoch 19/25
# 512/512 [==============================] - 185s 362ms/step - loss: 1.2087 - rpn_class_loss: 0.0093 - rpn_bbox_loss: 0.2703 - mrcnn_class_loss: 0.1938 - mrcnn_bbox_loss: 0.3568 - mrcnn_mask_loss: 0.3785 - val_loss: 1.2241 - val_rpn_class_loss: 0.0071 - val_rpn_bbox_loss: 0.2744 - val_mrcnn_class_loss: 0.1926 - val_mrcnn_bbox_loss: 0.3689 - val_mrcnn_mask_loss: 0.3811
# Epoch 20/25
# 512/512 [==============================] - 190s 371ms/step - loss: 1.1940 - rpn_class_loss: 0.0097 - rpn_bbox_loss: 0.2766 - mrcnn_class_loss: 0.1871 - mrcnn_bbox_loss: 0.3482 - mrcnn_mask_loss: 0.3724 - val_loss: 1.2698 - val_rpn_class_loss: 0.0105 - val_rpn_bbox_loss: 0.3123 - val_mrcnn_class_loss: 0.1779 - val_mrcnn_bbox_loss: 0.3827 - val_mrcnn_mask_loss: 0.3865
# Epoch 21/25
# 512/512 [==============================] - 192s 375ms/step - loss: 1.1946 - rpn_class_loss: 0.0098 - rpn_bbox_loss: 0.2789 - mrcnn_class_loss: 0.1798 - mrcnn_bbox_loss: 0.3505 - mrcnn_mask_loss: 0.3757 - val_loss: 1.2131 - val_rpn_class_loss: 0.0079 - val_rpn_bbox_loss: 0.3204 - val_mrcnn_class_loss: 0.1575 - val_mrcnn_bbox_loss: 0.3374 - val_mrcnn_mask_loss: 0.3900
# Epoch 22/25
# 512/512 [==============================] - 191s 372ms/step - loss: 1.1967 - rpn_class_loss: 0.0097 - rpn_bbox_loss: 0.2711 - mrcnn_class_loss: 0.1887 - mrcnn_bbox_loss: 0.3497 - mrcnn_mask_loss: 0.3774 - val_loss: 1.2164 - val_rpn_class_loss: 0.0094 - val_rpn_bbox_loss: 0.2803 - val_mrcnn_class_loss: 0.1800 - val_mrcnn_bbox_loss: 0.3671 - val_mrcnn_mask_loss: 0.3796
# Epoch 23/25
# 512/512 [==============================] - 188s 368ms/step - loss: 1.1825 - rpn_class_loss: 0.0091 - rpn_bbox_loss: 0.2622 - mrcnn_class_loss: 0.1902 - mrcnn_bbox_loss: 0.3467 - mrcnn_mask_loss: 0.3743 - val_loss: 1.2674 - val_rpn_class_loss: 0.0088 - val_rpn_bbox_loss: 0.2468 - val_mrcnn_class_loss: 0.2423 - val_mrcnn_bbox_loss: 0.3855 - val_mrcnn_mask_loss: 0.3840
# Epoch 24/25
# 512/512 [==============================] - 188s 367ms/step - loss: 1.1484 - rpn_class_loss: 0.0083 - rpn_bbox_loss: 0.2528 - mrcnn_class_loss: 0.1815 - mrcnn_bbox_loss: 0.3364 - mrcnn_mask_loss: 0.3694 - val_loss: 1.2513 - val_rpn_class_loss: 0.0098 - val_rpn_bbox_loss: 0.3005 - val_mrcnn_class_loss: 0.1884 - val_mrcnn_bbox_loss: 0.3679 - val_mrcnn_mask_loss: 0.3848
# Epoch 25/25
# 512/512 [==============================] - 192s 376ms/step - loss: 1.1410 - rpn_class_loss: 0.0091 - rpn_bbox_loss: 0.2646 - mrcnn_class_loss: 0.1659 - mrcnn_bbox_loss: 0.3302 - mrcnn_mask_loss: 0.3711 - val_loss: 1.2489 - val_rpn_class_loss: 0.0096 - val_rpn_bbox_loss: 0.3052 - val_mrcnn_class_loss: 0.1775 - val_mrcnn_bbox_loss: 0.3842 - val_mrcnn_mask_loss: 0.3724
#
# Starting at epoch 25. LR=0.0005
#
# Checkpoint Path: ../working_copy_75_epoch/pneumonia20180930T0128/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 26/50
# 512/512 [==============================] - 246s 480ms/step - loss: 1.0705 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.2147 - mrcnn_class_loss: 0.1699 - mrcnn_bbox_loss: 0.3142 - mrcnn_mask_loss: 0.3643 - val_loss: 1.2317 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 0.3138 - val_mrcnn_class_loss: 0.1791 - val_mrcnn_bbox_loss: 0.3496 - val_mrcnn_mask_loss: 0.3815
# Epoch 27/50
# 512/512 [==============================] - 183s 357ms/step - loss: 1.0480 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.2106 - mrcnn_class_loss: 0.1617 - mrcnn_bbox_loss: 0.3084 - mrcnn_mask_loss: 0.3604 - val_loss: 1.2303 - val_rpn_class_loss: 0.0072 - val_rpn_bbox_loss: 0.3242 - val_mrcnn_class_loss: 0.1662 - val_mrcnn_bbox_loss: 0.3499 - val_mrcnn_mask_loss: 0.3828
# Epoch 28/50
# 512/512 [==============================] - 186s 363ms/step - loss: 1.0558 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.2165 - mrcnn_class_loss: 0.1649 - mrcnn_bbox_loss: 0.3087 - mrcnn_mask_loss: 0.3583 - val_loss: 1.2729 - val_rpn_class_loss: 0.0085 - val_rpn_bbox_loss: 0.3395 - val_mrcnn_class_loss: 0.1626 - val_mrcnn_bbox_loss: 0.3791 - val_mrcnn_mask_loss: 0.3831
# Epoch 29/50
# 512/512 [==============================] - 186s 363ms/step - loss: 1.0651 - rpn_class_loss: 0.0082 - rpn_bbox_loss: 0.2264 - mrcnn_class_loss: 0.1492 - mrcnn_bbox_loss: 0.3152 - mrcnn_mask_loss: 0.3660 - val_loss: 1.2129 - val_rpn_class_loss: 0.0083 - val_rpn_bbox_loss: 0.3188 - val_mrcnn_class_loss: 0.1437 - val_mrcnn_bbox_loss: 0.3552 - val_mrcnn_mask_loss: 0.3869
# Epoch 30/50
# 512/512 [==============================] - 189s 369ms/step - loss: 1.0403 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.2220 - mrcnn_class_loss: 0.1427 - mrcnn_bbox_loss: 0.3058 - mrcnn_mask_loss: 0.3629 - val_loss: 1.2173 - val_rpn_class_loss: 0.0091 - val_rpn_bbox_loss: 0.2998 - val_mrcnn_class_loss: 0.1444 - val_mrcnn_bbox_loss: 0.3739 - val_mrcnn_mask_loss: 0.3901
# Epoch 31/50
# 512/512 [==============================] - 184s 360ms/step - loss: 1.0511 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.2195 - mrcnn_class_loss: 0.1547 - mrcnn_bbox_loss: 0.3061 - mrcnn_mask_loss: 0.3634 - val_loss: 1.2142 - val_rpn_class_loss: 0.0081 - val_rpn_bbox_loss: 0.2833 - val_mrcnn_class_loss: 0.2006 - val_mrcnn_bbox_loss: 0.3462 - val_mrcnn_mask_loss: 0.3760
# Epoch 32/50
# 512/512 [==============================] - 182s 355ms/step - loss: 1.0295 - rpn_class_loss: 0.0075 - rpn_bbox_loss: 0.2133 - mrcnn_class_loss: 0.1542 - mrcnn_bbox_loss: 0.2976 - mrcnn_mask_loss: 0.3568 - val_loss: 1.1402 - val_rpn_class_loss: 0.0061 - val_rpn_bbox_loss: 0.2354 - val_mrcnn_class_loss: 0.1817 - val_mrcnn_bbox_loss: 0.3505 - val_mrcnn_mask_loss: 0.3665
# Epoch 33/50
# 512/512 [==============================] - 183s 357ms/step - loss: 1.0143 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.1980 - mrcnn_class_loss: 0.1466 - mrcnn_bbox_loss: 0.3045 - mrcnn_mask_loss: 0.3588 - val_loss: 1.2497 - val_rpn_class_loss: 0.0101 - val_rpn_bbox_loss: 0.3365 - val_mrcnn_class_loss: 0.1378 - val_mrcnn_bbox_loss: 0.3779 - val_mrcnn_mask_loss: 0.3874
# Epoch 34/50
# 512/512 [==============================] - 183s 358ms/step - loss: 1.0172 - rpn_class_loss: 0.0067 - rpn_bbox_loss: 0.2003 - mrcnn_class_loss: 0.1493 - mrcnn_bbox_loss: 0.3001 - mrcnn_mask_loss: 0.3607 - val_loss: 1.3205 - val_rpn_class_loss: 0.0095 - val_rpn_bbox_loss: 0.3743 - val_mrcnn_class_loss: 0.1533 - val_mrcnn_bbox_loss: 0.3864 - val_mrcnn_mask_loss: 0.3971
# Epoch 35/50
# 512/512 [==============================] - 182s 356ms/step - loss: 1.0173 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.2026 - mrcnn_class_loss: 0.1566 - mrcnn_bbox_loss: 0.2907 - mrcnn_mask_loss: 0.3600 - val_loss: 1.2579 - val_rpn_class_loss: 0.0095 - val_rpn_bbox_loss: 0.2984 - val_mrcnn_class_loss: 0.1974 - val_mrcnn_bbox_loss: 0.3600 - val_mrcnn_mask_loss: 0.3926
# Epoch 36/50
# 512/512 [==============================] - 184s 360ms/step - loss: 1.0059 - rpn_class_loss: 0.0067 - rpn_bbox_loss: 0.2021 - mrcnn_class_loss: 0.1497 - mrcnn_bbox_loss: 0.2896 - mrcnn_mask_loss: 0.3578 - val_loss: 1.2195 - val_rpn_class_loss: 0.0074 - val_rpn_bbox_loss: 0.3118 - val_mrcnn_class_loss: 0.1676 - val_mrcnn_bbox_loss: 0.3581 - val_mrcnn_mask_loss: 0.3745
# Epoch 37/50
# 512/512 [==============================] - 181s 353ms/step - loss: 0.9996 - rpn_class_loss: 0.0068 - rpn_bbox_loss: 0.2001 - mrcnn_class_loss: 0.1428 - mrcnn_bbox_loss: 0.2886 - mrcnn_mask_loss: 0.3612 - val_loss: 1.1296 - val_rpn_class_loss: 0.0068 - val_rpn_bbox_loss: 0.2816 - val_mrcnn_class_loss: 0.1413 - val_mrcnn_bbox_loss: 0.3283 - val_mrcnn_mask_loss: 0.3716
# Epoch 38/50
# 512/512 [==============================] - 183s 357ms/step - loss: 1.0268 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.2047 - mrcnn_class_loss: 0.1521 - mrcnn_bbox_loss: 0.3020 - mrcnn_mask_loss: 0.3606 - val_loss: 1.1751 - val_rpn_class_loss: 0.0074 - val_rpn_bbox_loss: 0.2912 - val_mrcnn_class_loss: 0.1667 - val_mrcnn_bbox_loss: 0.3353 - val_mrcnn_mask_loss: 0.3745
# Epoch 39/50
# 512/512 [==============================] - 178s 348ms/step - loss: 0.9970 - rpn_class_loss: 0.0067 - rpn_bbox_loss: 0.1963 - mrcnn_class_loss: 0.1529 - mrcnn_bbox_loss: 0.2850 - mrcnn_mask_loss: 0.3561 - val_loss: 1.2088 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 0.3202 - val_mrcnn_class_loss: 0.1506 - val_mrcnn_bbox_loss: 0.3538 - val_mrcnn_mask_loss: 0.3765
# Epoch 40/50
# 512/512 [==============================] - 184s 359ms/step - loss: 1.0145 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.1946 - mrcnn_class_loss: 0.1556 - mrcnn_bbox_loss: 0.2942 - mrcnn_mask_loss: 0.3637 - val_loss: 1.1974 - val_rpn_class_loss: 0.0081 - val_rpn_bbox_loss: 0.2987 - val_mrcnn_class_loss: 0.1708 - val_mrcnn_bbox_loss: 0.3417 - val_mrcnn_mask_loss: 0.3781
# Epoch 41/50
# 512/512 [==============================] - 182s 355ms/step - loss: 0.9708 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.1850 - mrcnn_class_loss: 0.1367 - mrcnn_bbox_loss: 0.2863 - mrcnn_mask_loss: 0.3564 - val_loss: 1.2078 - val_rpn_class_loss: 0.0087 - val_rpn_bbox_loss: 0.2792 - val_mrcnn_class_loss: 0.1753 - val_mrcnn_bbox_loss: 0.3689 - val_mrcnn_mask_loss: 0.3757
# Epoch 42/50
# 512/512 [==============================] - 187s 366ms/step - loss: 0.9551 - rpn_class_loss: 0.0061 - rpn_bbox_loss: 0.1811 - mrcnn_class_loss: 0.1300 - mrcnn_bbox_loss: 0.2826 - mrcnn_mask_loss: 0.3554 - val_loss: 1.3336 - val_rpn_class_loss: 0.0115 - val_rpn_bbox_loss: 0.3356 - val_mrcnn_class_loss: 0.1685 - val_mrcnn_bbox_loss: 0.4000 - val_mrcnn_mask_loss: 0.4180
# Epoch 43/50
# 512/512 [==============================] - 183s 358ms/step - loss: 0.9768 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.1907 - mrcnn_class_loss: 0.1361 - mrcnn_bbox_loss: 0.2864 - mrcnn_mask_loss: 0.3571 - val_loss: 1.1605 - val_rpn_class_loss: 0.0066 - val_rpn_bbox_loss: 0.2796 - val_mrcnn_class_loss: 0.1484 - val_mrcnn_bbox_loss: 0.3451 - val_mrcnn_mask_loss: 0.3806
# Epoch 44/50
# 512/512 [==============================] - 185s 362ms/step - loss: 0.9652 - rpn_class_loss: 0.0072 - rpn_bbox_loss: 0.1855 - mrcnn_class_loss: 0.1287 - mrcnn_bbox_loss: 0.2871 - mrcnn_mask_loss: 0.3567 - val_loss: 1.2934 - val_rpn_class_loss: 0.0081 - val_rpn_bbox_loss: 0.3493 - val_mrcnn_class_loss: 0.1680 - val_mrcnn_bbox_loss: 0.3718 - val_mrcnn_mask_loss: 0.3962
# Epoch 45/50
# 512/512 [==============================] - 183s 357ms/step - loss: 0.9197 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.1715 - mrcnn_class_loss: 0.1236 - mrcnn_bbox_loss: 0.2708 - mrcnn_mask_loss: 0.3482 - val_loss: 1.2467 - val_rpn_class_loss: 0.0105 - val_rpn_bbox_loss: 0.3084 - val_mrcnn_class_loss: 0.2105 - val_mrcnn_bbox_loss: 0.3364 - val_mrcnn_mask_loss: 0.3808
# Epoch 46/50
# 512/512 [==============================] - 184s 360ms/step - loss: 0.9098 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.1649 - mrcnn_class_loss: 0.1291 - mrcnn_bbox_loss: 0.2656 - mrcnn_mask_loss: 0.3448 - val_loss: 1.4272 - val_rpn_class_loss: 0.0146 - val_rpn_bbox_loss: 0.4853 - val_mrcnn_class_loss: 0.1331 - val_mrcnn_bbox_loss: 0.3694 - val_mrcnn_mask_loss: 0.4248
# Epoch 47/50
# 512/512 [==============================] - 181s 354ms/step - loss: 0.9346 - rpn_class_loss: 0.0061 - rpn_bbox_loss: 0.1692 - mrcnn_class_loss: 0.1387 - mrcnn_bbox_loss: 0.2710 - mrcnn_mask_loss: 0.3496 - val_loss: 1.3808 - val_rpn_class_loss: 0.0114 - val_rpn_bbox_loss: 0.4271 - val_mrcnn_class_loss: 0.1555 - val_mrcnn_bbox_loss: 0.3793 - val_mrcnn_mask_loss: 0.4076
# Epoch 48/50
# 512/512 [==============================] - 183s 357ms/step - loss: 0.9120 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.1648 - mrcnn_class_loss: 0.1297 - mrcnn_bbox_loss: 0.2649 - mrcnn_mask_loss: 0.3472 - val_loss: 1.2930 - val_rpn_class_loss: 0.0096 - val_rpn_bbox_loss: 0.3927 - val_mrcnn_class_loss: 0.1467 - val_mrcnn_bbox_loss: 0.3502 - val_mrcnn_mask_loss: 0.3939
# Epoch 49/50
# 512/512 [==============================] - 181s 354ms/step - loss: 0.9090 - rpn_class_loss: 0.0062 - rpn_bbox_loss: 0.1716 - mrcnn_class_loss: 0.1253 - mrcnn_bbox_loss: 0.2607 - mrcnn_mask_loss: 0.3452 - val_loss: 1.2964 - val_rpn_class_loss: 0.0106 - val_rpn_bbox_loss: 0.3621 - val_mrcnn_class_loss: 0.1552 - val_mrcnn_bbox_loss: 0.3656 - val_mrcnn_mask_loss: 0.4029
# Epoch 50/50
# 512/512 [==============================] - 184s 359ms/step - loss: 0.9125 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.1606 - mrcnn_class_loss: 0.1295 - mrcnn_bbox_loss: 0.2664 - mrcnn_mask_loss: 0.3501 - val_loss: 1.3769 - val_rpn_class_loss: 0.0094 - val_rpn_bbox_loss: 0.4155 - val_mrcnn_class_loss: 0.1617 - val_mrcnn_bbox_loss: 0.3842 - val_mrcnn_mask_loss: 0.4060
#
# Starting at epoch 50. LR=0.00025
#
# Checkpoint Path: ../working_copy_75_epoch/pneumonia20180930T0128/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 51/75
# 512/512 [==============================] - 233s 456ms/step - loss: 0.8372 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.1365 - mrcnn_class_loss: 0.1116 - mrcnn_bbox_loss: 0.2409 - mrcnn_mask_loss: 0.3430 - val_loss: 1.3787 - val_rpn_class_loss: 0.0117 - val_rpn_bbox_loss: 0.4391 - val_mrcnn_class_loss: 0.1627 - val_mrcnn_bbox_loss: 0.3599 - val_mrcnn_mask_loss: 0.4053
# Epoch 52/75
# 512/512 [==============================] - 182s 356ms/step - loss: 0.8360 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.1425 - mrcnn_class_loss: 0.1109 - mrcnn_bbox_loss: 0.2396 - mrcnn_mask_loss: 0.3379 - val_loss: 1.2479 - val_rpn_class_loss: 0.0074 - val_rpn_bbox_loss: 0.3663 - val_mrcnn_class_loss: 0.1323 - val_mrcnn_bbox_loss: 0.3503 - val_mrcnn_mask_loss: 0.3916
# Epoch 53/75
# 512/512 [==============================] - 181s 353ms/step - loss: 0.8508 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.1526 - mrcnn_class_loss: 0.1149 - mrcnn_bbox_loss: 0.2398 - mrcnn_mask_loss: 0.3379 - val_loss: 1.2319 - val_rpn_class_loss: 0.0101 - val_rpn_bbox_loss: 0.2769 - val_mrcnn_class_loss: 0.2156 - val_mrcnn_bbox_loss: 0.3533 - val_mrcnn_mask_loss: 0.3761
# Epoch 54/75
# 512/512 [==============================] - 182s 356ms/step - loss: 0.8086 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.1295 - mrcnn_class_loss: 0.1071 - mrcnn_bbox_loss: 0.2323 - mrcnn_mask_loss: 0.3354 - val_loss: 1.1345 - val_rpn_class_loss: 0.0075 - val_rpn_bbox_loss: 0.3331 - val_mrcnn_class_loss: 0.1267 - val_mrcnn_bbox_loss: 0.3103 - val_mrcnn_mask_loss: 0.3568
# Epoch 55/75
# 512/512 [==============================] - 179s 349ms/step - loss: 0.8196 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.1364 - mrcnn_class_loss: 0.1109 - mrcnn_bbox_loss: 0.2329 - mrcnn_mask_loss: 0.3340 - val_loss: 1.3140 - val_rpn_class_loss: 0.0074 - val_rpn_bbox_loss: 0.3414 - val_mrcnn_class_loss: 0.1752 - val_mrcnn_bbox_loss: 0.3784 - val_mrcnn_mask_loss: 0.4115
# Epoch 56/75
# 512/512 [==============================] - 183s 357ms/step - loss: 0.8178 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.1270 - mrcnn_class_loss: 0.1145 - mrcnn_bbox_loss: 0.2328 - mrcnn_mask_loss: 0.3382 - val_loss: 1.3499 - val_rpn_class_loss: 0.0104 - val_rpn_bbox_loss: 0.4298 - val_mrcnn_class_loss: 0.1638 - val_mrcnn_bbox_loss: 0.3416 - val_mrcnn_mask_loss: 0.4043
# Epoch 57/75
# 512/512 [==============================] - 177s 346ms/step - loss: 0.7970 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.1324 - mrcnn_class_loss: 0.1045 - mrcnn_bbox_loss: 0.2263 - mrcnn_mask_loss: 0.3292 - val_loss: 1.4694 - val_rpn_class_loss: 0.0112 - val_rpn_bbox_loss: 0.4930 - val_mrcnn_class_loss: 0.1326 - val_mrcnn_bbox_loss: 0.4016 - val_mrcnn_mask_loss: 0.4310
# Epoch 58/75
# 512/512 [==============================] - 178s 348ms/step - loss: 0.8063 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.1298 - mrcnn_class_loss: 0.1042 - mrcnn_bbox_loss: 0.2277 - mrcnn_mask_loss: 0.3395 - val_loss: 1.2320 - val_rpn_class_loss: 0.0092 - val_rpn_bbox_loss: 0.3456 - val_mrcnn_class_loss: 0.1445 - val_mrcnn_bbox_loss: 0.3512 - val_mrcnn_mask_loss: 0.3815
# Epoch 59/75
# 512/512 [==============================] - 181s 353ms/step - loss: 0.7898 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.1207 - mrcnn_class_loss: 0.1058 - mrcnn_bbox_loss: 0.2244 - mrcnn_mask_loss: 0.3338 - val_loss: 1.1383 - val_rpn_class_loss: 0.0087 - val_rpn_bbox_loss: 0.3590 - val_mrcnn_class_loss: 0.1253 - val_mrcnn_bbox_loss: 0.2868 - val_mrcnn_mask_loss: 0.3586
# Epoch 60/75
# 512/512 [==============================] - 180s 352ms/step - loss: 0.7769 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.1274 - mrcnn_class_loss: 0.0992 - mrcnn_bbox_loss: 0.2172 - mrcnn_mask_loss: 0.3284 - val_loss: 1.4584 - val_rpn_class_loss: 0.0115 - val_rpn_bbox_loss: 0.4587 - val_mrcnn_class_loss: 0.1560 - val_mrcnn_bbox_loss: 0.3890 - val_mrcnn_mask_loss: 0.4432
# Epoch 61/75
# 512/512 [==============================] - 178s 347ms/step - loss: 0.7883 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.1237 - mrcnn_class_loss: 0.1034 - mrcnn_bbox_loss: 0.2251 - mrcnn_mask_loss: 0.3316 - val_loss: 1.3350 - val_rpn_class_loss: 0.0090 - val_rpn_bbox_loss: 0.4053 - val_mrcnn_class_loss: 0.1530 - val_mrcnn_bbox_loss: 0.3727 - val_mrcnn_mask_loss: 0.3950
# Epoch 62/75
# 512/512 [==============================] - 178s 348ms/step - loss: 0.7786 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.1218 - mrcnn_class_loss: 0.1059 - mrcnn_bbox_loss: 0.2172 - mrcnn_mask_loss: 0.3292 - val_loss: 1.3228 - val_rpn_class_loss: 0.0084 - val_rpn_bbox_loss: 0.3778 - val_mrcnn_class_loss: 0.1397 - val_mrcnn_bbox_loss: 0.3759 - val_mrcnn_mask_loss: 0.4209
# Epoch 63/75
# 512/512 [==============================] - 179s 350ms/step - loss: 0.7741 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.1220 - mrcnn_class_loss: 0.1041 - mrcnn_bbox_loss: 0.2158 - mrcnn_mask_loss: 0.3278 - val_loss: 1.3053 - val_rpn_class_loss: 0.0103 - val_rpn_bbox_loss: 0.3912 - val_mrcnn_class_loss: 0.1207 - val_mrcnn_bbox_loss: 0.3791 - val_mrcnn_mask_loss: 0.4040
# Epoch 64/75
# 512/512 [==============================] - 178s 347ms/step - loss: 0.7662 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.1165 - mrcnn_class_loss: 0.1033 - mrcnn_bbox_loss: 0.2157 - mrcnn_mask_loss: 0.3262 - val_loss: 1.2295 - val_rpn_class_loss: 0.0074 - val_rpn_bbox_loss: 0.3553 - val_mrcnn_class_loss: 0.1433 - val_mrcnn_bbox_loss: 0.3378 - val_mrcnn_mask_loss: 0.3857
# Epoch 65/75
# 512/512 [==============================] - 178s 347ms/step - loss: 0.7725 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.1231 - mrcnn_class_loss: 0.1037 - mrcnn_bbox_loss: 0.2110 - mrcnn_mask_loss: 0.3300 - val_loss: 1.3595 - val_rpn_class_loss: 0.0085 - val_rpn_bbox_loss: 0.3849 - val_mrcnn_class_loss: 0.1683 - val_mrcnn_bbox_loss: 0.3797 - val_mrcnn_mask_loss: 0.4181
# Epoch 66/75
# 512/512 [==============================] - 180s 352ms/step - loss: 0.7653 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.1206 - mrcnn_class_loss: 0.0972 - mrcnn_bbox_loss: 0.2129 - mrcnn_mask_loss: 0.3302 - val_loss: 1.4028 - val_rpn_class_loss: 0.0121 - val_rpn_bbox_loss: 0.4402 - val_mrcnn_class_loss: 0.1405 - val_mrcnn_bbox_loss: 0.3924 - val_mrcnn_mask_loss: 0.4176
# Epoch 67/75
# 512/512 [==============================] - 179s 350ms/step - loss: 0.7566 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.1202 - mrcnn_class_loss: 0.0948 - mrcnn_bbox_loss: 0.2117 - mrcnn_mask_loss: 0.3253 - val_loss: 1.3866 - val_rpn_class_loss: 0.0091 - val_rpn_bbox_loss: 0.3902 - val_mrcnn_class_loss: 0.1610 - val_mrcnn_bbox_loss: 0.3935 - val_mrcnn_mask_loss: 0.4327
# Epoch 68/75
# 512/512 [==============================] - 180s 351ms/step - loss: 0.7579 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.1153 - mrcnn_class_loss: 0.1017 - mrcnn_bbox_loss: 0.2115 - mrcnn_mask_loss: 0.3248 - val_loss: 1.4346 - val_rpn_class_loss: 0.0114 - val_rpn_bbox_loss: 0.4360 - val_mrcnn_class_loss: 0.1916 - val_mrcnn_bbox_loss: 0.3636 - val_mrcnn_mask_loss: 0.4320
# Epoch 69/75
# 512/512 [==============================] - 181s 353ms/step - loss: 0.7498 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.1157 - mrcnn_class_loss: 0.1010 - mrcnn_bbox_loss: 0.2052 - mrcnn_mask_loss: 0.3235 - val_loss: 1.3532 - val_rpn_class_loss: 0.0088 - val_rpn_bbox_loss: 0.4176 - val_mrcnn_class_loss: 0.1600 - val_mrcnn_bbox_loss: 0.3696 - val_mrcnn_mask_loss: 0.3973
# Epoch 70/75
# 512/512 [==============================] - 179s 350ms/step - loss: 0.7513 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.1242 - mrcnn_class_loss: 0.0984 - mrcnn_bbox_loss: 0.2009 - mrcnn_mask_loss: 0.3230 - val_loss: 1.4160 - val_rpn_class_loss: 0.0106 - val_rpn_bbox_loss: 0.4167 - val_mrcnn_class_loss: 0.1560 - val_mrcnn_bbox_loss: 0.4009 - val_mrcnn_mask_loss: 0.4319
# Epoch 71/75
# 512/512 [==============================] - 179s 350ms/step - loss: 0.7164 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.1107 - mrcnn_class_loss: 0.0932 - mrcnn_bbox_loss: 0.1910 - mrcnn_mask_loss: 0.3177 - val_loss: 1.3212 - val_rpn_class_loss: 0.0097 - val_rpn_bbox_loss: 0.4109 - val_mrcnn_class_loss: 0.1189 - val_mrcnn_bbox_loss: 0.3628 - val_mrcnn_mask_loss: 0.4189
# Epoch 72/75
# 512/512 [==============================] - 176s 343ms/step - loss: 0.7177 - rpn_class_loss: 0.0041 - rpn_bbox_loss: 0.1070 - mrcnn_class_loss: 0.0957 - mrcnn_bbox_loss: 0.1959 - mrcnn_mask_loss: 0.3151 - val_loss: 1.4148 - val_rpn_class_loss: 0.0114 - val_rpn_bbox_loss: 0.4261 - val_mrcnn_class_loss: 0.2026 - val_mrcnn_bbox_loss: 0.3450 - val_mrcnn_mask_loss: 0.4297
# Epoch 73/75
# 512/512 [==============================] - 179s 350ms/step - loss: 0.7005 - rpn_class_loss: 0.0036 - rpn_bbox_loss: 0.1072 - mrcnn_class_loss: 0.0903 - mrcnn_bbox_loss: 0.1866 - mrcnn_mask_loss: 0.3128 - val_loss: 1.3363 - val_rpn_class_loss: 0.0081 - val_rpn_bbox_loss: 0.3551 - val_mrcnn_class_loss: 0.1822 - val_mrcnn_bbox_loss: 0.3681 - val_mrcnn_mask_loss: 0.4228
# Epoch 74/75
# 512/512 [==============================] - 175s 342ms/step - loss: 0.7328 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.1129 - mrcnn_class_loss: 0.0951 - mrcnn_bbox_loss: 0.1988 - mrcnn_mask_loss: 0.3219 - val_loss: 1.4882 - val_rpn_class_loss: 0.0106 - val_rpn_bbox_loss: 0.4495 - val_mrcnn_class_loss: 0.1909 - val_mrcnn_bbox_loss: 0.3904 - val_mrcnn_mask_loss: 0.4467
# Epoch 75/75
# 512/512 [==============================] - 178s 347ms/step - loss: 0.6998 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.1036 - mrcnn_class_loss: 0.0889 - mrcnn_bbox_loss: 0.1899 - mrcnn_mask_loss: 0.3135 - val_loss: 1.2931 - val_rpn_class_loss: 0.0104 - val_rpn_bbox_loss: 0.3949 - val_mrcnn_class_loss: 0.1455 - val_mrcnn_bbox_loss: 0.3383 - val_mrcnn_mask_loss: 0.4039

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)

model.load_weights(model_path, by_name=True)
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE/10, 
            epochs=40, 
            layers='all')

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)

model.load_weights(model_path, by_name=True)
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE/10, 
            epochs=30, 
            layers='all')

# %%
#model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)
#model.load_weights(model_path, by_name=True)
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=60, 
            layers='all')

# %%
# select trained model 
dir_names = next(os.walk(model.model_dir))[1]
key = config.NAME.lower()
dir_names = filter(lambda f: f.startswith(key), dir_names)
dir_names = sorted(dir_names)

if not dir_names:
    import errno
    raise FileNotFoundError(
        errno.ENOENT,
        "Could not find model directory under {}".format(self.model_dir))
    
fps = []
# Pick last directory
for d in dir_names: 
    dir_name = os.path.join(model.model_dir, d)
    # Find the last checkpoint
    checkpoints = next(os.walk(dir_name))[2]
    checkpoints = filter(lambda f: f.startswith("mask_rcnn"), checkpoints)
    checkpoints = sorted(checkpoints)
    if not checkpoints:
        print('No weight files in {}'.format(dir_name))
    else:
        checkpoint = os.path.join(dir_name, checkpoints[-1])
        fps.append(checkpoint)

model_path = sorted(fps)[-1]
print('Found model {}'.format(model_path))
# Out:
# Found model ../working_copy_75_epoch/pneumonia20180930T0128/mask_rcnn_pneumonia_0075.h5

# %%
class InferenceConfig(DetectorConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode='inference', 
                          config=inference_config,
                          model_dir=ROOT_DIR)

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  ../working_copy_75_epoch/pneumonia20180930T0128/mask_rcnn_pneumonia_0075.h5
# Re-starting from epoch 75

# %%
# set color for class
def get_colors_for_class_ids(class_ids):
    colors = []
    for class_id in class_ids:
        if class_id == 1:
            colors.append((.941, .204, .204))
    return colors

# %% [markdown]
# ### How does the predicted box compared to the expected value? Let's use the validation dataset to check.
#
# Note that we trained only one epoch for **demonstration purposes ONLY**. You might be able to improve performance running more epochs.

# %%
# Show few example of ground truth vs. predictions on the validation dataset 
dataset = dataset_val
fig = plt.figure(figsize=(10, 30))

for i in range(6):

    image_id = random.choice(dataset.image_ids)
    
    original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config, 
                               image_id, use_mini_mask=False)
    
    print(original_image.shape)
    plt.subplot(6, 2, 2*i + 1)
    visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                                dataset.class_names,
                                colors=get_colors_for_class_ids(gt_class_id), ax=fig.axes[-1])
    
    plt.subplot(6, 2, 2*i + 2)
    results = model.detect([original_image]) #, verbose=1)
    r = results[0]
    visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                                dataset.class_names, r['scores'], 
                                colors=get_colors_for_class_ids(r['class_ids']), ax=fig.axes[-1])
# Out:
# (512, 512, 3)
#
# *** No instances to display ***
#
# (512, 512, 3)
# (512, 512, 3)
#
# *** No instances to display ***
#
# (512, 512, 3)
# (512, 512, 3)
#
# *** No instances to display ***
#
# (512, 512, 3)
#
# *** No instances to display ***

# %%
# Get filenames of test dataset DICOM images
test_image_fps = get_dicom_fps(test_dicom_dir)

# %% [markdown]
# ### Final steps - Create the submission file

# %%
# Make predictions on test images, write out sample submission 
def predict(image_fps, filepath='submission.csv', min_conf=0.975): 
    
    # assume square image
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    print(resize_factor)
    #resize_factor = ORIG_SIZE 
    with open(filepath, 'w') as file:
        file.write("patientId,PredictionString\n")

        for image_id in tqdm(image_fps): 
            ds = pydicom.read_file(image_id)
            image = ds.pixel_array
            # If grayscale. Convert to RGB for consistency.
            if len(image.shape) != 3 or image.shape[2] != 3:
                image = np.stack((image,) * 3, -1) 
            image, window, scale, padding, crop = utils.resize_image(
                image,
                min_dim=config.IMAGE_MIN_DIM,
                min_scale=config.IMAGE_MIN_SCALE,
                max_dim=config.IMAGE_MAX_DIM,
                mode=config.IMAGE_RESIZE_MODE)

            patient_id = os.path.splitext(os.path.basename(image_id))[0]

            results = model.detect([image])
            r = results[0]

            out_str = ""
            out_str += patient_id 
            out_str += ","
            assert( len(r['rois']) == len(r['class_ids']) == len(r['scores']) )
            if len(r['rois']) == 0: 
                pass
            else: 
                num_instances = len(r['rois'])

                for i in range(num_instances): 
                    if r['scores'][i] > min_conf: 
                        out_str += ' '
                        out_str += str(round(r['scores'][i], 2))
                        out_str += ' '

                        # x1, y1, width, height 
                        x1 = r['rois'][i][1]
                        y1 = r['rois'][i][0]
                        width = r['rois'][i][3] - x1 
                        height = r['rois'][i][2] - y1 
                        bboxes_str = "{} {} {} {}".format(x1*resize_factor, y1*resize_factor, \
                                                           width*resize_factor, height*resize_factor)   
                        #bboxes_str = "{} {} {} {}".format(x1, y1, \
                        #                                   width, height)
                        out_str += bboxes_str

            file.write(out_str+"\n")

# %%
# predict only the first 50 entries ??
submission_fp = os.path.join(ROOT_DIR, 'submission-75-epoch-512-steps-0.975-512-size-salamander.csv')
print(submission_fp)
predict(test_image_fps, filepath=submission_fp)
# Out:
#   0%|▏                                                                                                                                                              | 1/1000 [00:00<02:20,  7.11it/s]
# ../working_copy_75_epoch/submission-75-epoch-512-steps-0.975-512-size-salamander.csv
# 2.0
#  66%|████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                    | 665/1000 [01:51<00:42,  7.94it/s]

# %%
output = pd.read_csv(submission_fp, names=['patientId', 'PredictionString'])
output.head(60)

# %%
# show a few test image detection example
def visualize(): 
    image_id = random.choice(test_image_fps)
    ds = pydicom.read_file(image_id)
    
    # original image 
    image = ds.pixel_array
    
    # assume square image 
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    
    # If grayscale. Convert to RGB for consistency.
    if len(image.shape) != 3 or image.shape[2] != 3:
        image = np.stack((image,) * 3, -1) 
    resized_image, window, scale, padding, crop = utils.resize_image(
        image,
        min_dim=config.IMAGE_MIN_DIM,
        min_scale=config.IMAGE_MIN_SCALE,
        max_dim=config.IMAGE_MAX_DIM,
        mode=config.IMAGE_RESIZE_MODE)

    patient_id = os.path.splitext(os.path.basename(image_id))[0]
    print(patient_id)

    results = model.detect([resized_image])
    r = results[0]
    for bbox in r['rois']: 
        print(bbox)
        x1 = int(bbox[1] * resize_factor)
        y1 = int(bbox[0] * resize_factor)
        x2 = int(bbox[3] * resize_factor)
        y2 = int(bbox[2]  * resize_factor)
        cv2.rectangle(image, (x1,y1), (x2,y2), (77, 255, 9), 3, 1)
        width = x2 - x1 
        height = y2 - y1 
        print("x {} y {} h {} w {}".format(x1, y1, width, height))
    plt.figure() 
    plt.imshow(image, cmap=plt.cm.gist_gray)

visualize()
visualize()
visualize()
visualize()

# %%
# remove files to allow committing (hit files limit otherwise)
# !rm -rf /kaggle/working/Mask_RCNN
