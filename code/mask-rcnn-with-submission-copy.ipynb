# %% [markdown]
# **Mask-RCNN Sample Starter Model for the RSNA Pneumonia Detection Challenge**
#
# [MD.ai](https://www.md.ai). The dataset for this challenge, created on the MD.ai platform in collaboration with the Radiological Society of North America (RSNA), the Society of Thoracic Radiology (STR), the US National Institutes of Health (NIH), and Kaggle.
# This notebook covers the basics of parsing the competition dataset, training using a detector basd on the [Mask-RCNN algorithm](https://arxiv.org/abs/1703.06870) for object detection and instance segmentation.
# **Note that the Mask-RCNN detector configuration parameters have been selected to reduce training time for demonstration purposes, they are not optimal.
# **
#
# This is based on our deep learning for medical imaging lessons:
#
# - Lesson 1. Classification of chest vs. adominal X-rays using TensorFlow/Keras [Github](https://github.com/mdai/ml-lessons/blob/master/lesson1-xray-images-classification.ipynb) [Annotator](https://public.md.ai/annotator/project/PVq9raBJ)
# - Lesson 2. Lung X-Rays Semantic Segmentation using UNets. [Github](https://github.com/mdai/ml-lessons/blob/master/lesson2-lung-xrays-segmentation.ipynb)
# [Annotator](https://public.md.ai/annotator/project/aGq4k6NW/workspace)
# - Lesson 3. RSNA Pneumonia detection using Kaggle data format [Github](https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-kaggle.ipynb) [Annotator](https://public.md.ai/annotator/project/LxR6zdR2/workspace)
# - Lesson 3. RSNA Pneumonia detection using MD.ai python client library [Github](https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-mdai-client-lib.ipynb) [Annotator](https://public.md.ai/annotator/project/LxR6zdR2/workspace)
#
# *Copyright 2018 MD.ai, Inc.
# Licensed under the Apache License, Version 2.0*

# %%
import os 
import sys
import random
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt
import json
import pydicom
from imgaug import augmenters as iaa
from tqdm import tqdm
import pandas as pd 
import glob

# %% [markdown]
# ### First: Install Kaggle API for download competition data.

# %%
DATA_DIR = '../input'

# Directory to save logs and trained model
ROOT_DIR = '../working_copy6'
# !ls ../input
# Out:
# GCP%20Credits%20Request%20Link%20-%20RSNA.txt  stage_1_test_images.zip
# stage_1_detailed_class_info.csv		       stage_1_train_images
# stage_1_detailed_class_info.csv.zip	       stage_1_train_images.zip
# stage_1_sample_submission.csv		       stage_1_train_labels.csv
# stage_1_test_images			       stage_1_train_labels.csv.zip

# %% [markdown]
# ###  MD.ai Annotator
#
# Additionally, If you are interested in augmenting the existing annotations, you can use the MD.ai annotator to view DICOM images, and create annotatios to be exported.
# MD.ai annotator project URL for the Kaggle dataset: https://public.md.ai/annotator/project/LxR6zdR2/workspace
#
# **Annotator features**
# - The annotator can be used to view DICOM images and create image and exam level annotations.
# - You can apply the annotator to filter by label, adjudicate annotations, and assign annotation tasks to your team.
# - Notebooks can be built directly within the annotator for rapid model development.
# - The data wrangling is abstracted away by the interface and by our MD.ai library.
# - Simplifies image annotation in order to widen the participation in the futrue of medical image deep learning.
#
# The annotator allows you to create initial annotations, build and run models, modify/finetune the annotations based on predicted values, and repeat.
# The MD.ai python client library implements functions to easily download images and annotations and to prepare the datasets used to train the model for classification. See the following example notebook for parsing annotations and training using MD.ai annotator:
# https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-mdai-client-lib.ipynb
# - MD.ai URL: https://www.md.ai
# - MD.ai documentation URL: https://docs.md.ai/

# %% [markdown]
# ### Install Matterport's Mask-RCNN model from github.
# See the [Matterport's implementation of Mask-RCNN](https://github.com/matterport/Mask_RCNN).

# %%
#!git clone https://www.github.com/matterport/Mask_RCNN.git
#os.chdir('Mask_RCNN')
##!python setup.py -q install

# %%
# Import Mask RCNN
sys.path.append(os.path.join("/home/mehul/kaggle/pneumonia-detection-2018", 'Mask_RCNN'))  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train_dicom_dir = os.path.join(DATA_DIR, 'stage_1_train_images')
test_dicom_dir = os.path.join(DATA_DIR, 'stage_1_test_images')

# %% [markdown]
# ### Some setup functions and classes for Mask-RCNN
#
# - dicom_fps is a list of the dicom image path and filenames
# - image_annotions is a dictionary of the annotations keyed by the filenames
# - parsing the dataset returns a list of the image filenames and the annotations dictionary

# %%
def get_dicom_fps(dicom_dir):
    dicom_fps = glob.glob(dicom_dir+'/'+'*.dcm')
    return list(set(dicom_fps))

def parse_dataset(dicom_dir, anns): 
    image_fps = get_dicom_fps(dicom_dir)
    image_annotations = {fp: [] for fp in image_fps}
    for index, row in anns.iterrows(): 
        fp = os.path.join(dicom_dir, row['patientId']+'.dcm')
        image_annotations[fp].append(row)
    return image_fps, image_annotations

# %%
# The following parameters have been selected to reduce running time for demonstration purposes 
# These are not optimal 

class DetectorConfig(Config):
    """Configuration for training pneumonia detection on the RSNA pneumonia dataset.
    Overrides values in the base Config class.
    """
    
    # Give the configuration a recognizable name  
    NAME = 'pneumonia'
    
    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 2
    
    BACKBONE = 'resnet50'
    
    NUM_CLASSES = 2  # background + 1 pneumonia classes
    
    IMAGE_MIN_DIM = 512
    IMAGE_MAX_DIM = 512
    RPN_ANCHOR_SCALES = (32, 64, 128, 256)
    TRAIN_ROIS_PER_IMAGE = 32
    MAX_GT_INSTANCES = 5
    DETECTION_MAX_INSTANCES = 3
    DETECTION_MIN_CONFIDENCE = 0.4
    DETECTION_NMS_THRESHOLD = 0.1

    STEPS_PER_EPOCH = 512
    LOSS_WEIGHTS = {
        "rpn_class_loss": 1.,
        "rpn_bbox_loss": 1.,
        "mrcnn_class_loss": 1.,
        "mrcnn_bbox_loss": 1.,
        "mrcnn_mask_loss": 1.
    }

    
config = DetectorConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        3
# DETECTION_MIN_CONFIDENCE       0.4
# DETECTION_NMS_THRESHOLD        0.1
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  512
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [512 512   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               5
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           pneumonia
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                512
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
class DetectorDataset(utils.Dataset):
    """Dataset class for training pneumonia detection on the RSNA pneumonia dataset.
    """

    def __init__(self, image_fps, image_annotations, orig_height, orig_width):
        super().__init__(self)
        
        # Add classes
        self.add_class('pneumonia', 1, 'Lung Opacity')
        
        # add images 
        for i, fp in enumerate(image_fps):
            annotations = image_annotations[fp]
            self.add_image('pneumonia', image_id=i, path=fp, 
                           annotations=annotations, orig_height=orig_height, orig_width=orig_width)
            
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

    def load_image(self, image_id):
        info = self.image_info[image_id]
        fp = info['path']
        ds = pydicom.read_file(fp)
        image = ds.pixel_array
        # If grayscale. Convert to RGB for consistency.
        if len(image.shape) != 3 or image.shape[2] != 3:
            image = np.stack((image,) * 3, -1)
        return image

    def load_mask(self, image_id):
        info = self.image_info[image_id]
        annotations = info['annotations']
        count = len(annotations)
        if count == 0:
            mask = np.zeros((info['orig_height'], info['orig_width'], 1), dtype=np.uint8)
            class_ids = np.zeros((1,), dtype=np.int32)
        else:
            mask = np.zeros((info['orig_height'], info['orig_width'], count), dtype=np.uint8)
            class_ids = np.zeros((count,), dtype=np.int32)
            for i, a in enumerate(annotations):
                if a['Target'] == 1:
                    x = int(a['x'])
                    y = int(a['y'])
                    w = int(a['width'])
                    h = int(a['height'])
                    mask_instance = mask[:, :, i].copy()
                    cv2.rectangle(mask_instance, (x, y), (x+w, y+h), 255, -1)
                    mask[:, :, i] = mask_instance
                    class_ids[i] = 1
        return mask.astype(np.bool), class_ids.astype(np.int32)

# %% [markdown]
# ### Examine the annotation data, parse the dataset, and view dicom fields

# %%
# training dataset
anns = pd.read_csv(os.path.join(DATA_DIR, 'stage_1_train_labels.csv'))
anns.head()
# Out:
#                               patientId      x      y  width  height  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1

# %%
image_fps, image_annotations = parse_dataset(train_dicom_dir, anns=anns)

# %%
ds = pydicom.read_file(image_fps[0]) # read dicom image from filepath 
image = ds.pixel_array # get image array

# %%
# show dicom fields 
ds
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.8323329.19644.1517874419.44857
# (0008, 0020) Study Date                          DA: '19010101'
# (0008, 0030) Study Time                          TM: '000000.00'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 103e) Series Description                  LO: 'view: AP'
# (0010, 0010) Patient's Name                      PN: '3ed75b04-2a32-44a8-9297-0e58441f0e8c'
# (0010, 0020) Patient ID                          LO: '3ed75b04-2a32-44a8-9297-0e58441f0e8c'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1010) Patient's Age                       AS: '65'
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 5101) View Position                       CS: 'AP'
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.8323329.19644.1517874419.44856
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.8323329.19644.1517874419.44855
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1024
# (0028, 0011) Columns                             US: 1024
# (0028, 0030) Pixel Spacing                       DS: ['0.139', '0.139']
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 2110) Lossy Image Compression             CS: '01'
# (0028, 2114) Lossy Image Compression Method      CS: 'ISO_10918_1'
# (7fe0, 0010) Pixel Data                          OB: Array of 150502 bytes

# %%
# Original DICOM image size: 1024 x 1024
ORIG_SIZE = 1024

# %% [markdown]
# ### Split the data into training and validation datasets
# **Note: We have only used only a portion of the images for demonstration purposes. See comments below.**
#
#  - To use all the images do: image_fps_list = list(image_fps)
#  - Or change the number of images from 100 to a custom number

# %%
######################################################################
# Modify this line to use more or fewer images for training/validation. 
# To use all images, do: image_fps_list = list(image_fps)
image_fps_list = list(image_fps) 
#####################################################################

# split dataset into training vs. validation dataset 
# split ratio is set to 0.9 vs. 0.1 (train vs. validation, respectively)
#sorted(image_fps_list)
random.seed(42)
random.shuffle(image_fps_list)

validation_split = 0.1
split_index = int((1 - validation_split) * len(image_fps_list))

image_fps_train = image_fps_list[:split_index]
image_fps_val = image_fps_list[split_index:]

print(len(image_fps_train), len(image_fps_val))
# Out:
# 23115 2569

# %% [markdown]
# ### Create and prepare the training dataset using the DetectorDataset class.

# %%
# prepare the training dataset
dataset_train = DetectorDataset(image_fps_train, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_train.prepare()

# %% [markdown]
# ### Let's look at a sample annotation. We see a bounding box with (x, y) of the the top left corner as well as the width and height.

# %%
# Show annotation(s) for a DICOM image 
test_fp = random.choice(image_fps_train)
image_annotations[test_fp]
# Out:
# [patientId    06f188cb-3b24-41c8-beb2-9058d235e2a3
#  x                                             NaN
#  y                                             NaN
#  width                                         NaN
#  height                                        NaN
#  Target                                          0
#  Name: 340, dtype: object]

# %%
# prepare the validation dataset
dataset_val = DetectorDataset(image_fps_val, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_val.prepare()

# %% [markdown]
# ### Display a random image with bounding boxes

# %%
# Load and display random samples and their bounding boxes
# Suggestion: Run this a few times to see different examples. 

image_id = random.choice(dataset_train.image_ids)
image_fp = dataset_train.image_reference(image_id)
image = dataset_train.load_image(image_id)
mask, class_ids = dataset_train.load_mask(image_id)

print(image.shape)

plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(image[:, :, 0], cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
masked = np.zeros(image.shape[:2])
for i in range(mask.shape[2]):
    masked += image[:, :, 0] * mask[:, :, i]
plt.imshow(masked, cmap='gray')
plt.axis('off')

print(image_fp)
print(class_ids)
# Out:
# (1024, 1024, 3)
# ../input/stage_1_train_images/dba66bd1-9e64-46d8-b85e-68ed1e47e0d4.dcm
# [0]

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)

# %% [markdown]
# ### Image Augmentation. Try finetuning some variables to custom values

# %%
# Image augmentation 
augmentation = iaa.SomeOf((0, 2), [
    iaa.Affine(
        scale={"x": (0.95, 1.05), "y": (0.95, 1.05)},
        translate_percent={"x": (-0.05, 0.05), "y": (-0.05, 0.05)},
        rotate=(-5, 5),
        shear=(-2, 2)
    ),
    iaa.Multiply((0.9, 1.1))
])

# %% [markdown]
# ### Now it's time to train the model. Note that training even a basic model can take a few hours.
#
# Note: the following model is for demonstration purpose only. We have limited the training to one epoch, and have set nominal values for the Detector Configuration to reduce run-time.
#
# - dataset_train and dataset_val are derived from DetectorDataset
# - DetectorDataset loads images from image filenames and  masks from the annotation data
# - model is Mask-RCNN

# %%
'''
NUM_EPOCHS = 50

# Train Mask-RCNN Model 
import warnings 
warnings.filterwarnings("ignore")
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=25, 
            layers='heads',
            augmentation=augmentation)

model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE/10, 
            epochs=50, 
            layers='all',
            augmentation=augmentation)

model.train(dataset_train, dataset_val,
                     learning_rate=config.LEARNING_RATE/100,
                     epochs=75,
                     layers='all',
                     augmentation=augmentation)
'''
# Out:
# '\nNUM_EPOCHS = 50\n\n# Train Mask-RCNN Model \nimport warnings \nwarnings.filterwarnings("ignore")\nmodel.train(dataset_train, dataset_val, \n            learning_rate=config.LEARNING_RATE, \n            epochs=25, \n            layers=\'heads\',\n            augmentation=augmentation)\n\nmodel.train(dataset_train, dataset_val, \n            learning_rate=config.LEARNING_RATE/10, \n            epochs=50, \n            layers=\'all\',\n            augmentation=augmentation)\n\nmodel.train(dataset_train, dataset_val,\n                     learning_rate=config.LEARNING_RATE/100,\n                     epochs=75,\n                     layers=\'all\',\n                     augmentation=augmentation)\n'

# %%
import warnings 
# Model weights to start training with
init_with = "imagenet"  # imagenet, last, or some pretrained model
if init_with == "imagenet":
    weights_path = model.get_imagenet_weights()
    model.load_weights(weights_path, by_name=True)

warnings.filterwarnings("ignore")
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=20, 
            layers='all')

warnings.filterwarnings("ignore")
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE/2, 
            epochs=40, 
            layers='all')

warnings.filterwarnings("ignore")
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE/4, 
            epochs=60, 
            layers='all')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: ../working_copy6/pneumonia20180929T1844/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/20
# 512/512 [==============================] - 244s 476ms/step - loss: 1.5274 - rpn_class_loss: 0.0187 - rpn_bbox_loss: 0.3728 - mrcnn_class_loss: 0.2661 - mrcnn_bbox_loss: 0.4486 - mrcnn_mask_loss: 0.4213 - val_loss: 1.4502 - val_rpn_class_loss: 0.0169 - val_rpn_bbox_loss: 0.3169 - val_mrcnn_class_loss: 0.2565 - val_mrcnn_bbox_loss: 0.4547 - val_mrcnn_mask_loss: 0.4051
# Epoch 2/20
# 512/512 [==============================] - 185s 362ms/step - loss: 1.3808 - rpn_class_loss: 0.0133 - rpn_bbox_loss: 0.3192 - mrcnn_class_loss: 0.2383 - mrcnn_bbox_loss: 0.4081 - mrcnn_mask_loss: 0.4019 - val_loss: 1.3819 - val_rpn_class_loss: 0.0152 - val_rpn_bbox_loss: 0.3080 - val_mrcnn_class_loss: 0.2415 - val_mrcnn_bbox_loss: 0.4095 - val_mrcnn_mask_loss: 0.4077
# Epoch 3/20
# 512/512 [==============================] - 188s 368ms/step - loss: 1.3729 - rpn_class_loss: 0.0137 - rpn_bbox_loss: 0.3233 - mrcnn_class_loss: 0.2329 - mrcnn_bbox_loss: 0.4071 - mrcnn_mask_loss: 0.3958 - val_loss: 1.3942 - val_rpn_class_loss: 0.0101 - val_rpn_bbox_loss: 0.3026 - val_mrcnn_class_loss: 0.2595 - val_mrcnn_bbox_loss: 0.4215 - val_mrcnn_mask_loss: 0.4004
# Epoch 4/20
# 512/512 [==============================] - 184s 360ms/step - loss: 1.3581 - rpn_class_loss: 0.0129 - rpn_bbox_loss: 0.3257 - mrcnn_class_loss: 0.2297 - mrcnn_bbox_loss: 0.3962 - mrcnn_mask_loss: 0.3936 - val_loss: 1.3597 - val_rpn_class_loss: 0.0105 - val_rpn_bbox_loss: 0.2908 - val_mrcnn_class_loss: 0.2440 - val_mrcnn_bbox_loss: 0.4057 - val_mrcnn_mask_loss: 0.4087
# Epoch 5/20
# 512/512 [==============================] - 185s 362ms/step - loss: 1.3347 - rpn_class_loss: 0.0120 - rpn_bbox_loss: 0.3137 - mrcnn_class_loss: 0.2185 - mrcnn_bbox_loss: 0.3961 - mrcnn_mask_loss: 0.3944 - val_loss: 1.3897 - val_rpn_class_loss: 0.0125 - val_rpn_bbox_loss: 0.3758 - val_mrcnn_class_loss: 0.1985 - val_mrcnn_bbox_loss: 0.4092 - val_mrcnn_mask_loss: 0.3937
# Epoch 6/20
# 512/512 [==============================] - 185s 361ms/step - loss: 1.3265 - rpn_class_loss: 0.0117 - rpn_bbox_loss: 0.3172 - mrcnn_class_loss: 0.2191 - mrcnn_bbox_loss: 0.3867 - mrcnn_mask_loss: 0.3919 - val_loss: 1.3737 - val_rpn_class_loss: 0.0137 - val_rpn_bbox_loss: 0.3065 - val_mrcnn_class_loss: 0.2555 - val_mrcnn_bbox_loss: 0.4156 - val_mrcnn_mask_loss: 0.3824
# Epoch 7/20
# 512/512 [==============================] - 182s 355ms/step - loss: 1.2948 - rpn_class_loss: 0.0114 - rpn_bbox_loss: 0.3074 - mrcnn_class_loss: 0.2110 - mrcnn_bbox_loss: 0.3769 - mrcnn_mask_loss: 0.3881 - val_loss: 1.4134 - val_rpn_class_loss: 0.0131 - val_rpn_bbox_loss: 0.3389 - val_mrcnn_class_loss: 0.2246 - val_mrcnn_bbox_loss: 0.4227 - val_mrcnn_mask_loss: 0.4141
# Epoch 8/20
# 512/512 [==============================] - 182s 355ms/step - loss: 1.2843 - rpn_class_loss: 0.0116 - rpn_bbox_loss: 0.2971 - mrcnn_class_loss: 0.2122 - mrcnn_bbox_loss: 0.3776 - mrcnn_mask_loss: 0.3859 - val_loss: 1.5333 - val_rpn_class_loss: 0.0169 - val_rpn_bbox_loss: 0.5266 - val_mrcnn_class_loss: 0.1936 - val_mrcnn_bbox_loss: 0.3922 - val_mrcnn_mask_loss: 0.4039
# Epoch 9/20
# 512/512 [==============================] - 179s 349ms/step - loss: 1.2939 - rpn_class_loss: 0.0102 - rpn_bbox_loss: 0.3042 - mrcnn_class_loss: 0.2163 - mrcnn_bbox_loss: 0.3748 - mrcnn_mask_loss: 0.3883 - val_loss: 1.3643 - val_rpn_class_loss: 0.0098 - val_rpn_bbox_loss: 0.3806 - val_mrcnn_class_loss: 0.1827 - val_mrcnn_bbox_loss: 0.3865 - val_mrcnn_mask_loss: 0.4047
# Epoch 10/20
# 512/512 [==============================] - 187s 366ms/step - loss: 1.2624 - rpn_class_loss: 0.0110 - rpn_bbox_loss: 0.3052 - mrcnn_class_loss: 0.1943 - mrcnn_bbox_loss: 0.3686 - mrcnn_mask_loss: 0.3832 - val_loss: 1.2173 - val_rpn_class_loss: 0.0090 - val_rpn_bbox_loss: 0.2796 - val_mrcnn_class_loss: 0.1965 - val_mrcnn_bbox_loss: 0.3551 - val_mrcnn_mask_loss: 0.3772
# Epoch 11/20
# 512/512 [==============================] - 180s 352ms/step - loss: 1.2652 - rpn_class_loss: 0.0111 - rpn_bbox_loss: 0.2946 - mrcnn_class_loss: 0.2097 - mrcnn_bbox_loss: 0.3686 - mrcnn_mask_loss: 0.3813 - val_loss: 1.2737 - val_rpn_class_loss: 0.0108 - val_rpn_bbox_loss: 0.3232 - val_mrcnn_class_loss: 0.2051 - val_mrcnn_bbox_loss: 0.3628 - val_mrcnn_mask_loss: 0.3719
# Epoch 12/20
# 512/512 [==============================] - 178s 348ms/step - loss: 1.2510 - rpn_class_loss: 0.0106 - rpn_bbox_loss: 0.2959 - mrcnn_class_loss: 0.2098 - mrcnn_bbox_loss: 0.3562 - mrcnn_mask_loss: 0.3786 - val_loss: 1.2574 - val_rpn_class_loss: 0.0099 - val_rpn_bbox_loss: 0.2653 - val_mrcnn_class_loss: 0.2191 - val_mrcnn_bbox_loss: 0.3706 - val_mrcnn_mask_loss: 0.3924
# Epoch 13/20
# 512/512 [==============================] - 180s 352ms/step - loss: 1.2429 - rpn_class_loss: 0.0098 - rpn_bbox_loss: 0.3026 - mrcnn_class_loss: 0.1917 - mrcnn_bbox_loss: 0.3586 - mrcnn_mask_loss: 0.3803 - val_loss: 1.1996 - val_rpn_class_loss: 0.0090 - val_rpn_bbox_loss: 0.2716 - val_mrcnn_class_loss: 0.1929 - val_mrcnn_bbox_loss: 0.3486 - val_mrcnn_mask_loss: 0.3774
# Epoch 14/20
# 512/512 [==============================] - 181s 353ms/step - loss: 1.2236 - rpn_class_loss: 0.0098 - rpn_bbox_loss: 0.2841 - mrcnn_class_loss: 0.1936 - mrcnn_bbox_loss: 0.3548 - mrcnn_mask_loss: 0.3813 - val_loss: 1.3168 - val_rpn_class_loss: 0.0110 - val_rpn_bbox_loss: 0.3091 - val_mrcnn_class_loss: 0.2361 - val_mrcnn_bbox_loss: 0.3825 - val_mrcnn_mask_loss: 0.3781
# Epoch 15/20
# 512/512 [==============================] - 177s 346ms/step - loss: 1.2003 - rpn_class_loss: 0.0097 - rpn_bbox_loss: 0.2681 - mrcnn_class_loss: 0.1904 - mrcnn_bbox_loss: 0.3512 - mrcnn_mask_loss: 0.3808 - val_loss: 1.3422 - val_rpn_class_loss: 0.0133 - val_rpn_bbox_loss: 0.4038 - val_mrcnn_class_loss: 0.1810 - val_mrcnn_bbox_loss: 0.3608 - val_mrcnn_mask_loss: 0.3834
# Epoch 16/20
# 512/512 [==============================] - 183s 357ms/step - loss: 1.1995 - rpn_class_loss: 0.0092 - rpn_bbox_loss: 0.2795 - mrcnn_class_loss: 0.1869 - mrcnn_bbox_loss: 0.3488 - mrcnn_mask_loss: 0.3751 - val_loss: 1.3814 - val_rpn_class_loss: 0.0116 - val_rpn_bbox_loss: 0.4504 - val_mrcnn_class_loss: 0.1629 - val_mrcnn_bbox_loss: 0.3694 - val_mrcnn_mask_loss: 0.3871
# Epoch 17/20
# 512/512 [==============================] - 178s 348ms/step - loss: 1.1800 - rpn_class_loss: 0.0094 - rpn_bbox_loss: 0.2710 - mrcnn_class_loss: 0.1776 - mrcnn_bbox_loss: 0.3479 - mrcnn_mask_loss: 0.3741 - val_loss: 1.2074 - val_rpn_class_loss: 0.0126 - val_rpn_bbox_loss: 0.2792 - val_mrcnn_class_loss: 0.1934 - val_mrcnn_bbox_loss: 0.3497 - val_mrcnn_mask_loss: 0.3725
# Epoch 18/20
# 512/512 [==============================] - 180s 351ms/step - loss: 1.1703 - rpn_class_loss: 0.0089 - rpn_bbox_loss: 0.2784 - mrcnn_class_loss: 0.1751 - mrcnn_bbox_loss: 0.3343 - mrcnn_mask_loss: 0.3737 - val_loss: 1.2392 - val_rpn_class_loss: 0.0102 - val_rpn_bbox_loss: 0.2678 - val_mrcnn_class_loss: 0.2128 - val_mrcnn_bbox_loss: 0.3776 - val_mrcnn_mask_loss: 0.3708
# Epoch 19/20
# 512/512 [==============================] - 179s 350ms/step - loss: 1.1918 - rpn_class_loss: 0.0094 - rpn_bbox_loss: 0.2790 - mrcnn_class_loss: 0.1789 - mrcnn_bbox_loss: 0.3495 - mrcnn_mask_loss: 0.3749 - val_loss: 1.3219 - val_rpn_class_loss: 0.0112 - val_rpn_bbox_loss: 0.3841 - val_mrcnn_class_loss: 0.1847 - val_mrcnn_bbox_loss: 0.3758 - val_mrcnn_mask_loss: 0.3661
# Epoch 20/20
# 512/512 [==============================] - 183s 358ms/step - loss: 1.1499 - rpn_class_loss: 0.0092 - rpn_bbox_loss: 0.2649 - mrcnn_class_loss: 0.1721 - mrcnn_bbox_loss: 0.3353 - mrcnn_mask_loss: 0.3684 - val_loss: 1.2552 - val_rpn_class_loss: 0.0101 - val_rpn_bbox_loss: 0.2629 - val_mrcnn_class_loss: 0.2117 - val_mrcnn_bbox_loss: 0.3838 - val_mrcnn_mask_loss: 0.3867
#
# Starting at epoch 20. LR=0.0005
#
# Checkpoint Path: ../working_copy6/pneumonia20180929T1844/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 21/40
# 512/512 [==============================] - 231s 451ms/step - loss: 1.0943 - rpn_class_loss: 0.0084 - rpn_bbox_loss: 0.2377 - mrcnn_class_loss: 0.1650 - mrcnn_bbox_loss: 0.3186 - mrcnn_mask_loss: 0.3645 - val_loss: 1.3177 - val_rpn_class_loss: 0.0097 - val_rpn_bbox_loss: 0.3574 - val_mrcnn_class_loss: 0.1783 - val_mrcnn_bbox_loss: 0.3742 - val_mrcnn_mask_loss: 0.3981
# Epoch 22/40
# 512/512 [==============================] - 176s 344ms/step - loss: 1.0869 - rpn_class_loss: 0.0079 - rpn_bbox_loss: 0.2385 - mrcnn_class_loss: 0.1591 - mrcnn_bbox_loss: 0.3162 - mrcnn_mask_loss: 0.3652 - val_loss: 1.2633 - val_rpn_class_loss: 0.0075 - val_rpn_bbox_loss: 0.3860 - val_mrcnn_class_loss: 0.1570 - val_mrcnn_bbox_loss: 0.3401 - val_mrcnn_mask_loss: 0.3727
# Epoch 23/40
# 512/512 [==============================] - 176s 343ms/step - loss: 1.0703 - rpn_class_loss: 0.0079 - rpn_bbox_loss: 0.2331 - mrcnn_class_loss: 0.1505 - mrcnn_bbox_loss: 0.3110 - mrcnn_mask_loss: 0.3678 - val_loss: 1.2914 - val_rpn_class_loss: 0.0080 - val_rpn_bbox_loss: 0.3393 - val_mrcnn_class_loss: 0.1646 - val_mrcnn_bbox_loss: 0.3862 - val_mrcnn_mask_loss: 0.3934
# Epoch 24/40
# 512/512 [==============================] - 174s 340ms/step - loss: 1.0669 - rpn_class_loss: 0.0067 - rpn_bbox_loss: 0.2205 - mrcnn_class_loss: 0.1566 - mrcnn_bbox_loss: 0.3145 - mrcnn_mask_loss: 0.3687 - val_loss: 1.2817 - val_rpn_class_loss: 0.0100 - val_rpn_bbox_loss: 0.3611 - val_mrcnn_class_loss: 0.1429 - val_mrcnn_bbox_loss: 0.3665 - val_mrcnn_mask_loss: 0.4013
# Epoch 25/40
# 512/512 [==============================] - 177s 346ms/step - loss: 1.0698 - rpn_class_loss: 0.0076 - rpn_bbox_loss: 0.2341 - mrcnn_class_loss: 0.1493 - mrcnn_bbox_loss: 0.3129 - mrcnn_mask_loss: 0.3658 - val_loss: 1.2742 - val_rpn_class_loss: 0.0087 - val_rpn_bbox_loss: 0.3858 - val_mrcnn_class_loss: 0.1308 - val_mrcnn_bbox_loss: 0.3584 - val_mrcnn_mask_loss: 0.3904
# Epoch 26/40
# 512/512 [==============================] - 178s 349ms/step - loss: 1.0656 - rpn_class_loss: 0.0075 - rpn_bbox_loss: 0.2395 - mrcnn_class_loss: 0.1430 - mrcnn_bbox_loss: 0.3119 - mrcnn_mask_loss: 0.3638 - val_loss: 1.1610 - val_rpn_class_loss: 0.0076 - val_rpn_bbox_loss: 0.3025 - val_mrcnn_class_loss: 0.1331 - val_mrcnn_bbox_loss: 0.3401 - val_mrcnn_mask_loss: 0.3777
# Epoch 27/40
# 512/512 [==============================] - 177s 345ms/step - loss: 1.0377 - rpn_class_loss: 0.0076 - rpn_bbox_loss: 0.2185 - mrcnn_class_loss: 0.1431 - mrcnn_bbox_loss: 0.3046 - mrcnn_mask_loss: 0.3639 - val_loss: 1.1943 - val_rpn_class_loss: 0.0088 - val_rpn_bbox_loss: 0.3279 - val_mrcnn_class_loss: 0.1416 - val_mrcnn_bbox_loss: 0.3380 - val_mrcnn_mask_loss: 0.3780
# Epoch 28/40
# 512/512 [==============================] - 175s 342ms/step - loss: 1.0568 - rpn_class_loss: 0.0078 - rpn_bbox_loss: 0.2179 - mrcnn_class_loss: 0.1508 - mrcnn_bbox_loss: 0.3116 - mrcnn_mask_loss: 0.3686 - val_loss: 1.2775 - val_rpn_class_loss: 0.0130 - val_rpn_bbox_loss: 0.3716 - val_mrcnn_class_loss: 0.1511 - val_mrcnn_bbox_loss: 0.3563 - val_mrcnn_mask_loss: 0.3855
# Epoch 29/40
# 512/512 [==============================] - 176s 344ms/step - loss: 1.0135 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.2035 - mrcnn_class_loss: 0.1447 - mrcnn_bbox_loss: 0.2980 - mrcnn_mask_loss: 0.3600 - val_loss: 1.2136 - val_rpn_class_loss: 0.0078 - val_rpn_bbox_loss: 0.3073 - val_mrcnn_class_loss: 0.1588 - val_mrcnn_bbox_loss: 0.3574 - val_mrcnn_mask_loss: 0.3824
# Epoch 30/40
# 512/512 [==============================] - 177s 345ms/step - loss: 1.0225 - rpn_class_loss: 0.0072 - rpn_bbox_loss: 0.2101 - mrcnn_class_loss: 0.1436 - mrcnn_bbox_loss: 0.2965 - mrcnn_mask_loss: 0.3650 - val_loss: 1.2389 - val_rpn_class_loss: 0.0065 - val_rpn_bbox_loss: 0.3340 - val_mrcnn_class_loss: 0.1463 - val_mrcnn_bbox_loss: 0.3726 - val_mrcnn_mask_loss: 0.3795
# Epoch 31/40
# 512/512 [==============================] - 178s 348ms/step - loss: 1.0007 - rpn_class_loss: 0.0069 - rpn_bbox_loss: 0.1994 - mrcnn_class_loss: 0.1343 - mrcnn_bbox_loss: 0.2993 - mrcnn_mask_loss: 0.3608 - val_loss: 1.2220 - val_rpn_class_loss: 0.0096 - val_rpn_bbox_loss: 0.3085 - val_mrcnn_class_loss: 0.1858 - val_mrcnn_bbox_loss: 0.3432 - val_mrcnn_mask_loss: 0.3749
# Epoch 32/40
# 512/512 [==============================] - 176s 343ms/step - loss: 1.0270 - rpn_class_loss: 0.0071 - rpn_bbox_loss: 0.2092 - mrcnn_class_loss: 0.1482 - mrcnn_bbox_loss: 0.3008 - mrcnn_mask_loss: 0.3618 - val_loss: 1.2699 - val_rpn_class_loss: 0.0097 - val_rpn_bbox_loss: 0.3871 - val_mrcnn_class_loss: 0.1435 - val_mrcnn_bbox_loss: 0.3506 - val_mrcnn_mask_loss: 0.3790
# Epoch 33/40
# 512/512 [==============================] - 175s 342ms/step - loss: 0.9827 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.1977 - mrcnn_class_loss: 0.1360 - mrcnn_bbox_loss: 0.2882 - mrcnn_mask_loss: 0.3549 - val_loss: 1.1613 - val_rpn_class_loss: 0.0078 - val_rpn_bbox_loss: 0.2887 - val_mrcnn_class_loss: 0.1542 - val_mrcnn_bbox_loss: 0.3412 - val_mrcnn_mask_loss: 0.3693
# Epoch 34/40
# 512/512 [==============================] - 178s 348ms/step - loss: 1.0161 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.2051 - mrcnn_class_loss: 0.1409 - mrcnn_bbox_loss: 0.3018 - mrcnn_mask_loss: 0.3613 - val_loss: 1.1910 - val_rpn_class_loss: 0.0074 - val_rpn_bbox_loss: 0.3220 - val_mrcnn_class_loss: 0.1524 - val_mrcnn_bbox_loss: 0.3352 - val_mrcnn_mask_loss: 0.3739
# Epoch 35/40
# 512/512 [==============================] - 177s 345ms/step - loss: 0.9994 - rpn_class_loss: 0.0071 - rpn_bbox_loss: 0.1961 - mrcnn_class_loss: 0.1394 - mrcnn_bbox_loss: 0.2957 - mrcnn_mask_loss: 0.3612 - val_loss: 1.3775 - val_rpn_class_loss: 0.0131 - val_rpn_bbox_loss: 0.3900 - val_mrcnn_class_loss: 0.1972 - val_mrcnn_bbox_loss: 0.3832 - val_mrcnn_mask_loss: 0.3939
# Epoch 36/40
# 512/512 [==============================] - 177s 345ms/step - loss: 0.9841 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.1821 - mrcnn_class_loss: 0.1393 - mrcnn_bbox_loss: 0.2945 - mrcnn_mask_loss: 0.3617 - val_loss: 1.3144 - val_rpn_class_loss: 0.0119 - val_rpn_bbox_loss: 0.3949 - val_mrcnn_class_loss: 0.1557 - val_mrcnn_bbox_loss: 0.3637 - val_mrcnn_mask_loss: 0.3882
# Epoch 37/40
# 512/512 [==============================] - 174s 341ms/step - loss: 0.9854 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.1936 - mrcnn_class_loss: 0.1371 - mrcnn_bbox_loss: 0.2901 - mrcnn_mask_loss: 0.3579 - val_loss: 1.3434 - val_rpn_class_loss: 0.0106 - val_rpn_bbox_loss: 0.3813 - val_mrcnn_class_loss: 0.1666 - val_mrcnn_bbox_loss: 0.3946 - val_mrcnn_mask_loss: 0.3903
# Epoch 38/40
# 512/512 [==============================] - 174s 340ms/step - loss: 0.9541 - rpn_class_loss: 0.0063 - rpn_bbox_loss: 0.1823 - mrcnn_class_loss: 0.1334 - mrcnn_bbox_loss: 0.2782 - mrcnn_mask_loss: 0.3539 - val_loss: 1.3267 - val_rpn_class_loss: 0.0091 - val_rpn_bbox_loss: 0.3795 - val_mrcnn_class_loss: 0.1556 - val_mrcnn_bbox_loss: 0.3817 - val_mrcnn_mask_loss: 0.4008
# Epoch 39/40
# 512/512 [==============================] - 173s 338ms/step - loss: 0.9823 - rpn_class_loss: 0.0064 - rpn_bbox_loss: 0.1878 - mrcnn_class_loss: 0.1384 - mrcnn_bbox_loss: 0.2893 - mrcnn_mask_loss: 0.3603 - val_loss: 1.1932 - val_rpn_class_loss: 0.0072 - val_rpn_bbox_loss: 0.3192 - val_mrcnn_class_loss: 0.1485 - val_mrcnn_bbox_loss: 0.3582 - val_mrcnn_mask_loss: 0.3602
# Epoch 40/40
# 512/512 [==============================] - 176s 344ms/step - loss: 0.9753 - rpn_class_loss: 0.0066 - rpn_bbox_loss: 0.1891 - mrcnn_class_loss: 0.1424 - mrcnn_bbox_loss: 0.2826 - mrcnn_mask_loss: 0.3546 - val_loss: 1.3591 - val_rpn_class_loss: 0.0134 - val_rpn_bbox_loss: 0.4648 - val_mrcnn_class_loss: 0.1438 - val_mrcnn_bbox_loss: 0.3540 - val_mrcnn_mask_loss: 0.3831
#
# Starting at epoch 40. LR=0.00025
#
# Checkpoint Path: ../working_copy6/pneumonia20180929T1844/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 41/60
# 512/512 [==============================] - 227s 443ms/step - loss: 0.9195 - rpn_class_loss: 0.0059 - rpn_bbox_loss: 0.1761 - mrcnn_class_loss: 0.1221 - mrcnn_bbox_loss: 0.2657 - mrcnn_mask_loss: 0.3497 - val_loss: 1.2093 - val_rpn_class_loss: 0.0069 - val_rpn_bbox_loss: 0.2906 - val_mrcnn_class_loss: 0.1550 - val_mrcnn_bbox_loss: 0.3730 - val_mrcnn_mask_loss: 0.3838
# Epoch 42/60
# 512/512 [==============================] - 174s 339ms/step - loss: 0.8910 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.1490 - mrcnn_class_loss: 0.1227 - mrcnn_bbox_loss: 0.2630 - mrcnn_mask_loss: 0.3504 - val_loss: 1.2001 - val_rpn_class_loss: 0.0092 - val_rpn_bbox_loss: 0.3146 - val_mrcnn_class_loss: 0.1496 - val_mrcnn_bbox_loss: 0.3498 - val_mrcnn_mask_loss: 0.3768
# Epoch 43/60
# 512/512 [==============================] - 176s 343ms/step - loss: 0.8750 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.1531 - mrcnn_class_loss: 0.1178 - mrcnn_bbox_loss: 0.2530 - mrcnn_mask_loss: 0.3457 - val_loss: 1.3472 - val_rpn_class_loss: 0.0092 - val_rpn_bbox_loss: 0.4432 - val_mrcnn_class_loss: 0.1478 - val_mrcnn_bbox_loss: 0.3579 - val_mrcnn_mask_loss: 0.3892
# Epoch 44/60
# 512/512 [==============================] - 175s 342ms/step - loss: 0.8784 - rpn_class_loss: 0.0060 - rpn_bbox_loss: 0.1574 - mrcnn_class_loss: 0.1181 - mrcnn_bbox_loss: 0.2529 - mrcnn_mask_loss: 0.3441 - val_loss: 1.3798 - val_rpn_class_loss: 0.0110 - val_rpn_bbox_loss: 0.5394 - val_mrcnn_class_loss: 0.1138 - val_mrcnn_bbox_loss: 0.3391 - val_mrcnn_mask_loss: 0.3764
# Epoch 45/60
# 512/512 [==============================] - 175s 341ms/step - loss: 0.8640 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.1479 - mrcnn_class_loss: 0.1184 - mrcnn_bbox_loss: 0.2497 - mrcnn_mask_loss: 0.3429 - val_loss: 1.4453 - val_rpn_class_loss: 0.0127 - val_rpn_bbox_loss: 0.4868 - val_mrcnn_class_loss: 0.1695 - val_mrcnn_bbox_loss: 0.3727 - val_mrcnn_mask_loss: 0.4037
# Epoch 46/60
# 512/512 [==============================] - 170s 332ms/step - loss: 0.8665 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.1518 - mrcnn_class_loss: 0.1159 - mrcnn_bbox_loss: 0.2475 - mrcnn_mask_loss: 0.3463 - val_loss: 1.4122 - val_rpn_class_loss: 0.0135 - val_rpn_bbox_loss: 0.4774 - val_mrcnn_class_loss: 0.1476 - val_mrcnn_bbox_loss: 0.3782 - val_mrcnn_mask_loss: 0.3955
# Epoch 47/60
# 512/512 [==============================] - 172s 335ms/step - loss: 0.8769 - rpn_class_loss: 0.0058 - rpn_bbox_loss: 0.1549 - mrcnn_class_loss: 0.1218 - mrcnn_bbox_loss: 0.2491 - mrcnn_mask_loss: 0.3452 - val_loss: 1.2562 - val_rpn_class_loss: 0.0096 - val_rpn_bbox_loss: 0.3221 - val_mrcnn_class_loss: 0.1751 - val_mrcnn_bbox_loss: 0.3679 - val_mrcnn_mask_loss: 0.3815
# Epoch 48/60
# 512/512 [==============================] - 170s 332ms/step - loss: 0.8775 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.1603 - mrcnn_class_loss: 0.1161 - mrcnn_bbox_loss: 0.2524 - mrcnn_mask_loss: 0.3433 - val_loss: 1.3790 - val_rpn_class_loss: 0.0092 - val_rpn_bbox_loss: 0.4325 - val_mrcnn_class_loss: 0.1631 - val_mrcnn_bbox_loss: 0.3860 - val_mrcnn_mask_loss: 0.3882
# Epoch 49/60
# 512/512 [==============================] - 173s 338ms/step - loss: 0.8403 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.1411 - mrcnn_class_loss: 0.1112 - mrcnn_bbox_loss: 0.2419 - mrcnn_mask_loss: 0.3409 - val_loss: 1.3048 - val_rpn_class_loss: 0.0094 - val_rpn_bbox_loss: 0.3900 - val_mrcnn_class_loss: 0.1450 - val_mrcnn_bbox_loss: 0.3741 - val_mrcnn_mask_loss: 0.3864
# Epoch 50/60
# 512/512 [==============================] - 176s 344ms/step - loss: 0.8438 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.1414 - mrcnn_class_loss: 0.1114 - mrcnn_bbox_loss: 0.2419 - mrcnn_mask_loss: 0.3438 - val_loss: 1.2944 - val_rpn_class_loss: 0.0100 - val_rpn_bbox_loss: 0.4014 - val_mrcnn_class_loss: 0.1474 - val_mrcnn_bbox_loss: 0.3539 - val_mrcnn_mask_loss: 0.3817
# Epoch 51/60
# 512/512 [==============================] - 175s 342ms/step - loss: 0.8322 - rpn_class_loss: 0.0052 - rpn_bbox_loss: 0.1455 - mrcnn_class_loss: 0.1062 - mrcnn_bbox_loss: 0.2372 - mrcnn_mask_loss: 0.3380 - val_loss: 1.2370 - val_rpn_class_loss: 0.0083 - val_rpn_bbox_loss: 0.3536 - val_mrcnn_class_loss: 0.1220 - val_mrcnn_bbox_loss: 0.3531 - val_mrcnn_mask_loss: 0.3999
# Epoch 52/60
# 512/512 [==============================] - 172s 336ms/step - loss: 0.8400 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.1354 - mrcnn_class_loss: 0.1077 - mrcnn_bbox_loss: 0.2471 - mrcnn_mask_loss: 0.3449 - val_loss: 1.2050 - val_rpn_class_loss: 0.0056 - val_rpn_bbox_loss: 0.2939 - val_mrcnn_class_loss: 0.1491 - val_mrcnn_bbox_loss: 0.3712 - val_mrcnn_mask_loss: 0.3852
# Epoch 53/60
# 512/512 [==============================] - 173s 339ms/step - loss: 0.8153 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.1329 - mrcnn_class_loss: 0.1032 - mrcnn_bbox_loss: 0.2357 - mrcnn_mask_loss: 0.3385 - val_loss: 1.4809 - val_rpn_class_loss: 0.0165 - val_rpn_bbox_loss: 0.5041 - val_mrcnn_class_loss: 0.1689 - val_mrcnn_bbox_loss: 0.3781 - val_mrcnn_mask_loss: 0.4134
# Epoch 54/60
# 512/512 [==============================] - 175s 341ms/step - loss: 0.8249 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.1351 - mrcnn_class_loss: 0.1098 - mrcnn_bbox_loss: 0.2368 - mrcnn_mask_loss: 0.3382 - val_loss: 1.3899 - val_rpn_class_loss: 0.0115 - val_rpn_bbox_loss: 0.4848 - val_mrcnn_class_loss: 0.1529 - val_mrcnn_bbox_loss: 0.3588 - val_mrcnn_mask_loss: 0.3819
# Epoch 55/60
# 512/512 [==============================] - 173s 338ms/step - loss: 0.8280 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.1468 - mrcnn_class_loss: 0.1048 - mrcnn_bbox_loss: 0.2332 - mrcnn_mask_loss: 0.3381 - val_loss: 1.3481 - val_rpn_class_loss: 0.0087 - val_rpn_bbox_loss: 0.4330 - val_mrcnn_class_loss: 0.1267 - val_mrcnn_bbox_loss: 0.3795 - val_mrcnn_mask_loss: 0.4002
# Epoch 56/60
# 512/512 [==============================] - 174s 339ms/step - loss: 0.8143 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.1325 - mrcnn_class_loss: 0.1045 - mrcnn_bbox_loss: 0.2338 - mrcnn_mask_loss: 0.3386 - val_loss: 1.5447 - val_rpn_class_loss: 0.0169 - val_rpn_bbox_loss: 0.6060 - val_mrcnn_class_loss: 0.1425 - val_mrcnn_bbox_loss: 0.3632 - val_mrcnn_mask_loss: 0.4160
# Epoch 57/60
# 512/512 [==============================] - 177s 346ms/step - loss: 0.8097 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.1389 - mrcnn_class_loss: 0.1020 - mrcnn_bbox_loss: 0.2288 - mrcnn_mask_loss: 0.3348 - val_loss: 1.3922 - val_rpn_class_loss: 0.0124 - val_rpn_bbox_loss: 0.4928 - val_mrcnn_class_loss: 0.1516 - val_mrcnn_bbox_loss: 0.3503 - val_mrcnn_mask_loss: 0.3851
# Epoch 58/60
# 512/512 [==============================] - 176s 344ms/step - loss: 0.8026 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.1314 - mrcnn_class_loss: 0.1020 - mrcnn_bbox_loss: 0.2278 - mrcnn_mask_loss: 0.3365 - val_loss: 1.3639 - val_rpn_class_loss: 0.0158 - val_rpn_bbox_loss: 0.4876 - val_mrcnn_class_loss: 0.1269 - val_mrcnn_bbox_loss: 0.3478 - val_mrcnn_mask_loss: 0.3858
# Epoch 59/60
# 512/512 [==============================] - 176s 343ms/step - loss: 0.7834 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.1254 - mrcnn_class_loss: 0.0989 - mrcnn_bbox_loss: 0.2233 - mrcnn_mask_loss: 0.3313 - val_loss: 1.3864 - val_rpn_class_loss: 0.0111 - val_rpn_bbox_loss: 0.4954 - val_mrcnn_class_loss: 0.1345 - val_mrcnn_bbox_loss: 0.3506 - val_mrcnn_mask_loss: 0.3948
# Epoch 60/60
# 512/512 [==============================] - 178s 347ms/step - loss: 0.7954 - rpn_class_loss: 0.0043 - rpn_bbox_loss: 0.1262 - mrcnn_class_loss: 0.1026 - mrcnn_bbox_loss: 0.2259 - mrcnn_mask_loss: 0.3364 - val_loss: 1.3602 - val_rpn_class_loss: 0.0087 - val_rpn_bbox_loss: 0.3971 - val_mrcnn_class_loss: 0.1396 - val_mrcnn_bbox_loss: 0.3861 - val_mrcnn_mask_loss: 0.4287

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)

model.load_weights(model_path, by_name=True)
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE/10, 
            epochs=40, 
            layers='all')

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)

model.load_weights(model_path, by_name=True)
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE/10, 
            epochs=30, 
            layers='all')

# %%
#model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)
#model.load_weights(model_path, by_name=True)
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=60, 
            layers='all')

# %%
# select trained model 
dir_names = next(os.walk(model.model_dir))[1]
key = config.NAME.lower()
dir_names = filter(lambda f: f.startswith(key), dir_names)
dir_names = sorted(dir_names)

if not dir_names:
    import errno
    raise FileNotFoundError(
        errno.ENOENT,
        "Could not find model directory under {}".format(self.model_dir))
    
fps = []
# Pick last directory
for d in dir_names: 
    dir_name = os.path.join(model.model_dir, d)
    # Find the last checkpoint
    checkpoints = next(os.walk(dir_name))[2]
    checkpoints = filter(lambda f: f.startswith("mask_rcnn"), checkpoints)
    checkpoints = sorted(checkpoints)
    if not checkpoints:
        print('No weight files in {}'.format(dir_name))
    else:
        checkpoint = os.path.join(dir_name, checkpoints[-1])
        fps.append(checkpoint)

model_path = sorted(fps)[-1]
print('Found model {}'.format(model_path))
# Out:
# Found model ../working_copy6/pneumonia20180929T1844/mask_rcnn_pneumonia_0042.h5

# %%
class InferenceConfig(DetectorConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode='inference', 
                          config=inference_config,
                          model_dir=ROOT_DIR)

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  ../working_copy6/pneumonia20180929T1844/mask_rcnn_pneumonia_0042.h5
# Re-starting from epoch 42

# %%
# set color for class
def get_colors_for_class_ids(class_ids):
    colors = []
    for class_id in class_ids:
        if class_id == 1:
            colors.append((.941, .204, .204))
    return colors

# %% [markdown]
# ### How does the predicted box compared to the expected value? Let's use the validation dataset to check.
#
# Note that we trained only one epoch for **demonstration purposes ONLY**. You might be able to improve performance running more epochs.

# %%
# Show few example of ground truth vs. predictions on the validation dataset 
dataset = dataset_val
fig = plt.figure(figsize=(10, 30))

for i in range(6):

    image_id = random.choice(dataset.image_ids)
    
    original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config, 
                               image_id, use_mini_mask=False)
    
    print(original_image.shape)
    plt.subplot(6, 2, 2*i + 1)
    visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                                dataset.class_names,
                                colors=get_colors_for_class_ids(gt_class_id), ax=fig.axes[-1])
    
    plt.subplot(6, 2, 2*i + 2)
    results = model.detect([original_image]) #, verbose=1)
    r = results[0]
    visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                                dataset.class_names, r['scores'], 
                                colors=get_colors_for_class_ids(r['class_ids']), ax=fig.axes[-1])
# Out:
# (512, 512, 3)
#
# *** No instances to display ***
#
# (512, 512, 3)
#
# *** No instances to display ***
#
# (512, 512, 3)
#
# *** No instances to display ***
#
# (512, 512, 3)
#
# *** No instances to display ***
#
# (512, 512, 3)
#
# *** No instances to display ***
#
# (512, 512, 3)

# %%
# Get filenames of test dataset DICOM images
test_image_fps = get_dicom_fps(test_dicom_dir)

# %% [markdown]
# ### Final steps - Create the submission file

# %%
# Make predictions on test images, write out sample submission 
def predict(image_fps, filepath='submission.csv', min_conf=0.975): 
    
    # assume square image
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    print(resize_factor)
    #resize_factor = ORIG_SIZE 
    with open(filepath, 'w') as file:
        file.write("patientId,PredictionString\n")

        for image_id in tqdm(image_fps): 
            ds = pydicom.read_file(image_id)
            image = ds.pixel_array
            # If grayscale. Convert to RGB for consistency.
            if len(image.shape) != 3 or image.shape[2] != 3:
                image = np.stack((image,) * 3, -1) 
            image, window, scale, padding, crop = utils.resize_image(
                image,
                min_dim=config.IMAGE_MIN_DIM,
                min_scale=config.IMAGE_MIN_SCALE,
                max_dim=config.IMAGE_MAX_DIM,
                mode=config.IMAGE_RESIZE_MODE)

            patient_id = os.path.splitext(os.path.basename(image_id))[0]

            results = model.detect([image])
            r = results[0]

            out_str = ""
            out_str += patient_id 
            out_str += ","
            assert( len(r['rois']) == len(r['class_ids']) == len(r['scores']) )
            if len(r['rois']) == 0: 
                pass
            else: 
                num_instances = len(r['rois'])

                for i in range(num_instances): 
                    if r['scores'][i] > min_conf: 
                        out_str += ' '
                        out_str += str(round(r['scores'][i], 2))
                        out_str += ' '

                        # x1, y1, width, height 
                        x1 = r['rois'][i][1]
                        y1 = r['rois'][i][0]
                        width = r['rois'][i][3] - x1 
                        height = r['rois'][i][2] - y1 
                        bboxes_str = "{} {} {} {}".format(x1*resize_factor, y1*resize_factor, \
                                                           width*resize_factor, height*resize_factor)   
                        #bboxes_str = "{} {} {} {}".format(x1, y1, \
                        #                                   width, height)
                        out_str += bboxes_str

            file.write(out_str+"\n")

# %%
# predict only the first 50 entries ??
submission_fp = os.path.join(ROOT_DIR, 'submission-42epoch-512-steps-0.975-512-size-salamander.csv')
print(submission_fp)
predict(test_image_fps, filepath=submission_fp)
# Out:
#   0%|                                                                                                                                                                       | 0/1000 [00:00<?, ?it/s]
# ../working_copy6/submission-42epoch-512-steps-0.975-512-size-salamander.csv
# 2.0
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [02:22<00:00,  7.20it/s]

# %%
output = pd.read_csv(submission_fp, names=['patientId', 'PredictionString'])
output.head(60)

# %%
# show a few test image detection example
def visualize(): 
    image_id = random.choice(test_image_fps)
    ds = pydicom.read_file(image_id)
    
    # original image 
    image = ds.pixel_array
    
    # assume square image 
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    
    # If grayscale. Convert to RGB for consistency.
    if len(image.shape) != 3 or image.shape[2] != 3:
        image = np.stack((image,) * 3, -1) 
    resized_image, window, scale, padding, crop = utils.resize_image(
        image,
        min_dim=config.IMAGE_MIN_DIM,
        min_scale=config.IMAGE_MIN_SCALE,
        max_dim=config.IMAGE_MAX_DIM,
        mode=config.IMAGE_RESIZE_MODE)

    patient_id = os.path.splitext(os.path.basename(image_id))[0]
    print(patient_id)

    results = model.detect([resized_image])
    r = results[0]
    for bbox in r['rois']: 
        print(bbox)
        x1 = int(bbox[1] * resize_factor)
        y1 = int(bbox[0] * resize_factor)
        x2 = int(bbox[3] * resize_factor)
        y2 = int(bbox[2]  * resize_factor)
        cv2.rectangle(image, (x1,y1), (x2,y2), (77, 255, 9), 3, 1)
        width = x2 - x1 
        height = y2 - y1 
        print("x {} y {} h {} w {}".format(x1, y1, width, height))
    plt.figure() 
    plt.imshow(image, cmap=plt.cm.gist_gray)

visualize()
visualize()
visualize()
visualize()

# %%
# remove files to allow committing (hit files limit otherwise)
# !rm -rf /kaggle/working/Mask_RCNN
