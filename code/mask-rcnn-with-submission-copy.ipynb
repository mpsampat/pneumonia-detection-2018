# %% [markdown]
# **Mask-RCNN Sample Starter Model for the RSNA Pneumonia Detection Challenge**
#
# [MD.ai](https://www.md.ai). The dataset for this challenge, created on the MD.ai platform in collaboration with the Radiological Society of North America (RSNA), the Society of Thoracic Radiology (STR), the US National Institutes of Health (NIH), and Kaggle.
# This notebook covers the basics of parsing the competition dataset, training using a detector basd on the [Mask-RCNN algorithm](https://arxiv.org/abs/1703.06870) for object detection and instance segmentation.
# **Note that the Mask-RCNN detector configuration parameters have been selected to reduce training time for demonstration purposes, they are not optimal.
# **
#
# This is based on our deep learning for medical imaging lessons:
#
# - Lesson 1. Classification of chest vs. adominal X-rays using TensorFlow/Keras [Github](https://github.com/mdai/ml-lessons/blob/master/lesson1-xray-images-classification.ipynb) [Annotator](https://public.md.ai/annotator/project/PVq9raBJ)
# - Lesson 2. Lung X-Rays Semantic Segmentation using UNets. [Github](https://github.com/mdai/ml-lessons/blob/master/lesson2-lung-xrays-segmentation.ipynb)
# [Annotator](https://public.md.ai/annotator/project/aGq4k6NW/workspace)
# - Lesson 3. RSNA Pneumonia detection using Kaggle data format [Github](https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-kaggle.ipynb) [Annotator](https://public.md.ai/annotator/project/LxR6zdR2/workspace)
# - Lesson 3. RSNA Pneumonia detection using MD.ai python client library [Github](https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-mdai-client-lib.ipynb) [Annotator](https://public.md.ai/annotator/project/LxR6zdR2/workspace)
#
# *Copyright 2018 MD.ai, Inc.
# Licensed under the Apache License, Version 2.0*

# %%
import os 
import sys
import random
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt
import json
import pydicom
from imgaug import augmenters as iaa
from tqdm import tqdm
import pandas as pd 
import glob

# %% [markdown]
# ### First: Install Kaggle API for download competition data.

# %%
DATA_DIR = '../input'

# Directory to save logs and trained model
ROOT_DIR = '../working_copy3'
# !ls ../input
# Out:
# GCP%20Credits%20Request%20Link%20-%20RSNA.txt  stage_1_test_images.zip
# stage_1_detailed_class_info.csv		       stage_1_train_images
# stage_1_detailed_class_info.csv.zip	       stage_1_train_images.zip
# stage_1_sample_submission.csv		       stage_1_train_labels.csv
# stage_1_test_images			       stage_1_train_labels.csv.zip

# %% [markdown]
# ###  MD.ai Annotator
#
# Additionally, If you are interested in augmenting the existing annotations, you can use the MD.ai annotator to view DICOM images, and create annotatios to be exported.
# MD.ai annotator project URL for the Kaggle dataset: https://public.md.ai/annotator/project/LxR6zdR2/workspace
#
# **Annotator features**
# - The annotator can be used to view DICOM images and create image and exam level annotations.
# - You can apply the annotator to filter by label, adjudicate annotations, and assign annotation tasks to your team.
# - Notebooks can be built directly within the annotator for rapid model development.
# - The data wrangling is abstracted away by the interface and by our MD.ai library.
# - Simplifies image annotation in order to widen the participation in the futrue of medical image deep learning.
#
# The annotator allows you to create initial annotations, build and run models, modify/finetune the annotations based on predicted values, and repeat.
# The MD.ai python client library implements functions to easily download images and annotations and to prepare the datasets used to train the model for classification. See the following example notebook for parsing annotations and training using MD.ai annotator:
# https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-mdai-client-lib.ipynb
# - MD.ai URL: https://www.md.ai
# - MD.ai documentation URL: https://docs.md.ai/

# %% [markdown]
# ### Install Matterport's Mask-RCNN model from github.
# See the [Matterport's implementation of Mask-RCNN](https://github.com/matterport/Mask_RCNN).

# %%
#!git clone https://www.github.com/matterport/Mask_RCNN.git
#os.chdir('Mask_RCNN')
##!python setup.py -q install

# %%
# Import Mask RCNN
sys.path.append(os.path.join("/home/mehul/kaggle/pneumonia-detection-2018", 'Mask_RCNN'))  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train_dicom_dir = os.path.join(DATA_DIR, 'stage_1_train_images')
test_dicom_dir = os.path.join(DATA_DIR, 'stage_1_test_images')

# %% [markdown]
# ### Some setup functions and classes for Mask-RCNN
#
# - dicom_fps is a list of the dicom image path and filenames
# - image_annotions is a dictionary of the annotations keyed by the filenames
# - parsing the dataset returns a list of the image filenames and the annotations dictionary

# %%
def get_dicom_fps(dicom_dir):
    dicom_fps = glob.glob(dicom_dir+'/'+'*.dcm')
    return list(set(dicom_fps))

def parse_dataset(dicom_dir, anns): 
    image_fps = get_dicom_fps(dicom_dir)
    image_annotations = {fp: [] for fp in image_fps}
    for index, row in anns.iterrows(): 
        fp = os.path.join(dicom_dir, row['patientId']+'.dcm')
        image_annotations[fp].append(row)
    return image_fps, image_annotations

# %%
# The following parameters have been selected to reduce running time for demonstration purposes 
# These are not optimal 

class DetectorConfig(Config):
    """Configuration for training pneumonia detection on the RSNA pneumonia dataset.
    Overrides values in the base Config class.
    """
    
    # Give the configuration a recognizable name  
    NAME = 'pneumonia'
    
    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 2
    
    BACKBONE = 'resnet50'
    
    NUM_CLASSES = 2  # background + 1 pneumonia classes
    
    IMAGE_MIN_DIM = 512
    IMAGE_MAX_DIM = 512
    RPN_ANCHOR_SCALES = (32, 64, 128, 256)
    TRAIN_ROIS_PER_IMAGE = 32
    MAX_GT_INSTANCES = 5
    DETECTION_MAX_INSTANCES = 3
    DETECTION_MIN_CONFIDENCE = 0.4
    DETECTION_NMS_THRESHOLD = 0.1

    STEPS_PER_EPOCH = 1024
    LOSS_WEIGHTS = {
        "rpn_class_loss": 1.,
        "rpn_bbox_loss": 1.,
        "mrcnn_class_loss": 1.,
        "mrcnn_bbox_loss": 1.,
        "mrcnn_mask_loss": 1.
    }

    
config = DetectorConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        3
# DETECTION_MIN_CONFIDENCE       0.4
# DETECTION_NMS_THRESHOLD        0.1
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  512
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [512 512   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               5
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           pneumonia
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1024
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
class DetectorDataset(utils.Dataset):
    """Dataset class for training pneumonia detection on the RSNA pneumonia dataset.
    """

    def __init__(self, image_fps, image_annotations, orig_height, orig_width):
        super().__init__(self)
        
        # Add classes
        self.add_class('pneumonia', 1, 'Lung Opacity')
        
        # add images 
        for i, fp in enumerate(image_fps):
            annotations = image_annotations[fp]
            self.add_image('pneumonia', image_id=i, path=fp, 
                           annotations=annotations, orig_height=orig_height, orig_width=orig_width)
            
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

    def load_image(self, image_id):
        info = self.image_info[image_id]
        fp = info['path']
        ds = pydicom.read_file(fp)
        image = ds.pixel_array
        # If grayscale. Convert to RGB for consistency.
        if len(image.shape) != 3 or image.shape[2] != 3:
            image = np.stack((image,) * 3, -1)
        return image

    def load_mask(self, image_id):
        info = self.image_info[image_id]
        annotations = info['annotations']
        count = len(annotations)
        if count == 0:
            mask = np.zeros((info['orig_height'], info['orig_width'], 1), dtype=np.uint8)
            class_ids = np.zeros((1,), dtype=np.int32)
        else:
            mask = np.zeros((info['orig_height'], info['orig_width'], count), dtype=np.uint8)
            class_ids = np.zeros((count,), dtype=np.int32)
            for i, a in enumerate(annotations):
                if a['Target'] == 1:
                    x = int(a['x'])
                    y = int(a['y'])
                    w = int(a['width'])
                    h = int(a['height'])
                    mask_instance = mask[:, :, i].copy()
                    cv2.rectangle(mask_instance, (x, y), (x+w, y+h), 255, -1)
                    mask[:, :, i] = mask_instance
                    class_ids[i] = 1
        return mask.astype(np.bool), class_ids.astype(np.int32)

# %% [markdown]
# ### Examine the annotation data, parse the dataset, and view dicom fields

# %%
# training dataset
anns = pd.read_csv(os.path.join(DATA_DIR, 'stage_1_train_labels.csv'))
anns.head()
# Out:
#                               patientId      x      y  width  height  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1

# %%
image_fps, image_annotations = parse_dataset(train_dicom_dir, anns=anns)

# %%
ds = pydicom.read_file(image_fps[0]) # read dicom image from filepath 
image = ds.pixel_array # get image array

# %%
# show dicom fields 
ds
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.8323329.14475.1517874379.649611
# (0008, 0020) Study Date                          DA: '19010101'
# (0008, 0030) Study Time                          TM: '000000.00'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 103e) Series Description                  LO: 'view: PA'
# (0010, 0010) Patient's Name                      PN: 'ce1a6d80-31c1-4efe-8ad7-f8a60ffa8aec'
# (0010, 0020) Patient ID                          LO: 'ce1a6d80-31c1-4efe-8ad7-f8a60ffa8aec'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1010) Patient's Age                       AS: '44'
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 5101) View Position                       CS: 'PA'
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.8323329.14475.1517874379.649610
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.8323329.14475.1517874379.649609
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1024
# (0028, 0011) Columns                             US: 1024
# (0028, 0030) Pixel Spacing                       DS: ['0.139', '0.139']
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 2110) Lossy Image Compression             CS: '01'
# (0028, 2114) Lossy Image Compression Method      CS: 'ISO_10918_1'
# (7fe0, 0010) Pixel Data                          OB: Array of 143340 bytes

# %%
# Original DICOM image size: 1024 x 1024
ORIG_SIZE = 1024

# %% [markdown]
# ### Split the data into training and validation datasets
# **Note: We have only used only a portion of the images for demonstration purposes. See comments below.**
#
#  - To use all the images do: image_fps_list = list(image_fps)
#  - Or change the number of images from 100 to a custom number

# %%
######################################################################
# Modify this line to use more or fewer images for training/validation. 
# To use all images, do: image_fps_list = list(image_fps)
image_fps_list = list(image_fps) 
#####################################################################

# split dataset into training vs. validation dataset 
# split ratio is set to 0.9 vs. 0.1 (train vs. validation, respectively)
#sorted(image_fps_list)
random.seed(42)
random.shuffle(image_fps_list)

validation_split = 0.1
split_index = int((1 - validation_split) * len(image_fps_list))

image_fps_train = image_fps_list[:split_index]
image_fps_val = image_fps_list[split_index:]

print(len(image_fps_train), len(image_fps_val))
# Out:
# 23115 2569

# %% [markdown]
# ### Create and prepare the training dataset using the DetectorDataset class.

# %%
# prepare the training dataset
dataset_train = DetectorDataset(image_fps_train, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_train.prepare()

# %% [markdown]
# ### Let's look at a sample annotation. We see a bounding box with (x, y) of the the top left corner as well as the width and height.

# %%
# Show annotation(s) for a DICOM image 
test_fp = random.choice(image_fps_train)
image_annotations[test_fp]
# Out:
# [patientId    a7f54a7d-8dda-4fd9-8e1b-e1e762a34da7
#  x                                             NaN
#  y                                             NaN
#  width                                         NaN
#  height                                        NaN
#  Target                                          0
#  Name: 17612, dtype: object]

# %%
# prepare the validation dataset
dataset_val = DetectorDataset(image_fps_val, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_val.prepare()

# %% [markdown]
# ### Display a random image with bounding boxes

# %%
# Load and display random samples and their bounding boxes
# Suggestion: Run this a few times to see different examples. 

image_id = random.choice(dataset_train.image_ids)
image_fp = dataset_train.image_reference(image_id)
image = dataset_train.load_image(image_id)
mask, class_ids = dataset_train.load_mask(image_id)

print(image.shape)

plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(image[:, :, 0], cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
masked = np.zeros(image.shape[:2])
for i in range(mask.shape[2]):
    masked += image[:, :, 0] * mask[:, :, i]
plt.imshow(masked, cmap='gray')
plt.axis('off')

print(image_fp)
print(class_ids)
# Out:
# (1024, 1024, 3)
# ../input/stage_1_train_images/3e68ba7b-58ae-4415-a4e0-1698e03c4489.dcm
# [1 1]

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)

# %% [markdown]
# ### Image Augmentation. Try finetuning some variables to custom values

# %%
# Image augmentation 
augmentation = iaa.SomeOf((0, 2), [
    iaa.Affine(
        scale={"x": (0.95, 1.05), "y": (0.95, 1.05)},
        translate_percent={"x": (-0.05, 0.05), "y": (-0.05, 0.05)},
        rotate=(-5, 5),
        shear=(-2, 2)
    ),
    iaa.Multiply((0.9, 1.1))
])

# %% [markdown]
# ### Now it's time to train the model. Note that training even a basic model can take a few hours.
#
# Note: the following model is for demonstration purpose only. We have limited the training to one epoch, and have set nominal values for the Detector Configuration to reduce run-time.
#
# - dataset_train and dataset_val are derived from DetectorDataset
# - DetectorDataset loads images from image filenames and  masks from the annotation data
# - model is Mask-RCNN

# %%
'''
NUM_EPOCHS = 50

# Train Mask-RCNN Model 
import warnings 
warnings.filterwarnings("ignore")
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=25, 
            layers='heads',
            augmentation=augmentation)

model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE/10, 
            epochs=50, 
            layers='all',
            augmentation=augmentation)

model.train(dataset_train, dataset_val,
                     learning_rate=config.LEARNING_RATE/100,
                     epochs=75,
                     layers='all',
                     augmentation=augmentation)
'''
# Out:
# '\nNUM_EPOCHS = 50\n\n# Train Mask-RCNN Model \nimport warnings \nwarnings.filterwarnings("ignore")\nmodel.train(dataset_train, dataset_val, \n            learning_rate=config.LEARNING_RATE, \n            epochs=25, \n            layers=\'heads\',\n            augmentation=augmentation)\n\nmodel.train(dataset_train, dataset_val, \n            learning_rate=config.LEARNING_RATE/10, \n            epochs=50, \n            layers=\'all\',\n            augmentation=augmentation)\n\nmodel.train(dataset_train, dataset_val,\n                     learning_rate=config.LEARNING_RATE/100,\n                     epochs=75,\n                     layers=\'all\',\n                     augmentation=augmentation)\n'

# %%
import warnings 
# Model weights to start training with
init_with = "imagenet"  # imagenet, last, or some pretrained model
if init_with == "imagenet":
    weights_path = model.get_imagenet_weights()
    model.load_weights(weights_path, by_name=True)

warnings.filterwarnings("ignore")
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=20, 
            layers='all')

warnings.filterwarnings("ignore")
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE/10, 
            epochs=40, 
            layers='all')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: ../working_copy3/pneumonia20180926T2105/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/20
# 1024/1024 [==============================] - 471s 460ms/step - loss: 1.7311 - rpn_class_loss: 0.0472 - rpn_bbox_loss: 0.3998 - mrcnn_class_loss: 0.2798 - mrcnn_bbox_loss: 0.5174 - mrcnn_mask_loss: 0.4869 - val_loss: 1.4843 - val_rpn_class_loss: 0.0162 - val_rpn_bbox_loss: 0.3173 - val_mrcnn_class_loss: 0.2855 - val_mrcnn_bbox_loss: 0.4463 - val_mrcnn_mask_loss: 0.4191
# Epoch 2/20
# 1024/1024 [==============================] - 355s 347ms/step - loss: 1.4698 - rpn_class_loss: 0.0159 - rpn_bbox_loss: 0.3428 - mrcnn_class_loss: 0.2542 - mrcnn_bbox_loss: 0.4346 - mrcnn_mask_loss: 0.4222 - val_loss: 1.5138 - val_rpn_class_loss: 0.0150 - val_rpn_bbox_loss: 0.3763 - val_mrcnn_class_loss: 0.2432 - val_mrcnn_bbox_loss: 0.4773 - val_mrcnn_mask_loss: 0.4020
# Epoch 3/20
# 1024/1024 [==============================] - 354s 345ms/step - loss: 1.3791 - rpn_class_loss: 0.0131 - rpn_bbox_loss: 0.3283 - mrcnn_class_loss: 0.2248 - mrcnn_bbox_loss: 0.4072 - mrcnn_mask_loss: 0.4057 - val_loss: 1.4372 - val_rpn_class_loss: 0.0144 - val_rpn_bbox_loss: 0.4832 - val_mrcnn_class_loss: 0.1617 - val_mrcnn_bbox_loss: 0.3805 - val_mrcnn_mask_loss: 0.3972
# Epoch 4/20
# 1024/1024 [==============================] - 356s 347ms/step - loss: 1.3596 - rpn_class_loss: 0.0127 - rpn_bbox_loss: 0.3235 - mrcnn_class_loss: 0.2265 - mrcnn_bbox_loss: 0.3989 - mrcnn_mask_loss: 0.3979 - val_loss: 1.4467 - val_rpn_class_loss: 0.0131 - val_rpn_bbox_loss: 0.3712 - val_mrcnn_class_loss: 0.2432 - val_mrcnn_bbox_loss: 0.4173 - val_mrcnn_mask_loss: 0.4018
# Epoch 5/20
# 1024/1024 [==============================] - 355s 347ms/step - loss: 1.3137 - rpn_class_loss: 0.0115 - rpn_bbox_loss: 0.3116 - mrcnn_class_loss: 0.2118 - mrcnn_bbox_loss: 0.3853 - mrcnn_mask_loss: 0.3935 - val_loss: 1.3027 - val_rpn_class_loss: 0.0115 - val_rpn_bbox_loss: 0.3651 - val_mrcnn_class_loss: 0.1655 - val_mrcnn_bbox_loss: 0.3714 - val_mrcnn_mask_loss: 0.3892
# Epoch 6/20
# 1024/1024 [==============================] - 347s 339ms/step - loss: 1.2788 - rpn_class_loss: 0.0108 - rpn_bbox_loss: 0.2988 - mrcnn_class_loss: 0.2063 - mrcnn_bbox_loss: 0.3748 - mrcnn_mask_loss: 0.3880 - val_loss: 1.3058 - val_rpn_class_loss: 0.0113 - val_rpn_bbox_loss: 0.4028 - val_mrcnn_class_loss: 0.1557 - val_mrcnn_bbox_loss: 0.3542 - val_mrcnn_mask_loss: 0.3818
# Epoch 7/20
# 1024/1024 [==============================] - 351s 343ms/step - loss: 1.2452 - rpn_class_loss: 0.0100 - rpn_bbox_loss: 0.2939 - mrcnn_class_loss: 0.1901 - mrcnn_bbox_loss: 0.3675 - mrcnn_mask_loss: 0.3836 - val_loss: 1.2571 - val_rpn_class_loss: 0.0116 - val_rpn_bbox_loss: 0.2741 - val_mrcnn_class_loss: 0.2198 - val_mrcnn_bbox_loss: 0.3701 - val_mrcnn_mask_loss: 0.3815
# Epoch 8/20
# 1024/1024 [==============================] - 349s 341ms/step - loss: 1.2300 - rpn_class_loss: 0.0099 - rpn_bbox_loss: 0.2865 - mrcnn_class_loss: 0.1859 - mrcnn_bbox_loss: 0.3627 - mrcnn_mask_loss: 0.3850 - val_loss: 1.2238 - val_rpn_class_loss: 0.0099 - val_rpn_bbox_loss: 0.2845 - val_mrcnn_class_loss: 0.1925 - val_mrcnn_bbox_loss: 0.3498 - val_mrcnn_mask_loss: 0.3871
# Epoch 9/20
# 1024/1024 [==============================] - 342s 334ms/step - loss: 1.2080 - rpn_class_loss: 0.0094 - rpn_bbox_loss: 0.2867 - mrcnn_class_loss: 0.1751 - mrcnn_bbox_loss: 0.3546 - mrcnn_mask_loss: 0.3823 - val_loss: 1.2130 - val_rpn_class_loss: 0.0092 - val_rpn_bbox_loss: 0.3093 - val_mrcnn_class_loss: 0.1698 - val_mrcnn_bbox_loss: 0.3478 - val_mrcnn_mask_loss: 0.3769
# Epoch 10/20
# 1024/1024 [==============================] - 349s 341ms/step - loss: 1.2008 - rpn_class_loss: 0.0100 - rpn_bbox_loss: 0.2750 - mrcnn_class_loss: 0.1813 - mrcnn_bbox_loss: 0.3543 - mrcnn_mask_loss: 0.3802 - val_loss: 1.2514 - val_rpn_class_loss: 0.0104 - val_rpn_bbox_loss: 0.3434 - val_mrcnn_class_loss: 0.1581 - val_mrcnn_bbox_loss: 0.3601 - val_mrcnn_mask_loss: 0.3794
# Epoch 11/20
# 1024/1024 [==============================] - 345s 337ms/step - loss: 1.1966 - rpn_class_loss: 0.0096 - rpn_bbox_loss: 0.2865 - mrcnn_class_loss: 0.1735 - mrcnn_bbox_loss: 0.3486 - mrcnn_mask_loss: 0.3783 - val_loss: 1.1438 - val_rpn_class_loss: 0.0076 - val_rpn_bbox_loss: 0.2557 - val_mrcnn_class_loss: 0.1689 - val_mrcnn_bbox_loss: 0.3386 - val_mrcnn_mask_loss: 0.3731
# Epoch 12/20
# 1024/1024 [==============================] - 352s 344ms/step - loss: 1.1510 - rpn_class_loss: 0.0092 - rpn_bbox_loss: 0.2607 - mrcnn_class_loss: 0.1702 - mrcnn_bbox_loss: 0.3398 - mrcnn_mask_loss: 0.3711 - val_loss: 1.3126 - val_rpn_class_loss: 0.0104 - val_rpn_bbox_loss: 0.3022 - val_mrcnn_class_loss: 0.2225 - val_mrcnn_bbox_loss: 0.3841 - val_mrcnn_mask_loss: 0.3933
# Epoch 13/20
# 1024/1024 [==============================] - 350s 342ms/step - loss: 1.1500 - rpn_class_loss: 0.0087 - rpn_bbox_loss: 0.2742 - mrcnn_class_loss: 0.1606 - mrcnn_bbox_loss: 0.3347 - mrcnn_mask_loss: 0.3718 - val_loss: 1.2262 - val_rpn_class_loss: 0.0106 - val_rpn_bbox_loss: 0.3282 - val_mrcnn_class_loss: 0.1533 - val_mrcnn_bbox_loss: 0.3523 - val_mrcnn_mask_loss: 0.3819
# Epoch 14/20
# 1024/1024 [==============================] - 341s 333ms/step - loss: 1.1291 - rpn_class_loss: 0.0084 - rpn_bbox_loss: 0.2530 - mrcnn_class_loss: 0.1601 - mrcnn_bbox_loss: 0.3350 - mrcnn_mask_loss: 0.3726 - val_loss: 1.1378 - val_rpn_class_loss: 0.0073 - val_rpn_bbox_loss: 0.2424 - val_mrcnn_class_loss: 0.1769 - val_mrcnn_bbox_loss: 0.3480 - val_mrcnn_mask_loss: 0.3633
# Epoch 15/20
# 1024/1024 [==============================] - 340s 332ms/step - loss: 1.1233 - rpn_class_loss: 0.0079 - rpn_bbox_loss: 0.2507 - mrcnn_class_loss: 0.1694 - mrcnn_bbox_loss: 0.3284 - mrcnn_mask_loss: 0.3668 - val_loss: 1.2161 - val_rpn_class_loss: 0.0077 - val_rpn_bbox_loss: 0.2777 - val_mrcnn_class_loss: 0.1731 - val_mrcnn_bbox_loss: 0.3665 - val_mrcnn_mask_loss: 0.3912
# Epoch 16/20
# 1024/1024 [==============================] - 345s 337ms/step - loss: 1.1091 - rpn_class_loss: 0.0083 - rpn_bbox_loss: 0.2483 - mrcnn_class_loss: 0.1589 - mrcnn_bbox_loss: 0.3244 - mrcnn_mask_loss: 0.3692 - val_loss: 1.2826 - val_rpn_class_loss: 0.0101 - val_rpn_bbox_loss: 0.4033 - val_mrcnn_class_loss: 0.1573 - val_mrcnn_bbox_loss: 0.3405 - val_mrcnn_mask_loss: 0.3713
# Epoch 17/20
# 1024/1024 [==============================] - 351s 342ms/step - loss: 1.0785 - rpn_class_loss: 0.0079 - rpn_bbox_loss: 0.2373 - mrcnn_class_loss: 0.1464 - mrcnn_bbox_loss: 0.3201 - mrcnn_mask_loss: 0.3667 - val_loss: 1.4306 - val_rpn_class_loss: 0.0124 - val_rpn_bbox_loss: 0.5080 - val_mrcnn_class_loss: 0.1265 - val_mrcnn_bbox_loss: 0.3827 - val_mrcnn_mask_loss: 0.4009
# Epoch 18/20
# 1024/1024 [==============================] - 347s 339ms/step - loss: 1.0628 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.2288 - mrcnn_class_loss: 0.1428 - mrcnn_bbox_loss: 0.3176 - mrcnn_mask_loss: 0.3663 - val_loss: 1.4058 - val_rpn_class_loss: 0.0133 - val_rpn_bbox_loss: 0.5066 - val_mrcnn_class_loss: 0.1525 - val_mrcnn_bbox_loss: 0.3536 - val_mrcnn_mask_loss: 0.3799
# Epoch 19/20
# 1024/1024 [==============================] - 339s 331ms/step - loss: 1.0533 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.2232 - mrcnn_class_loss: 0.1468 - mrcnn_bbox_loss: 0.3152 - mrcnn_mask_loss: 0.3608 - val_loss: 1.1790 - val_rpn_class_loss: 0.0079 - val_rpn_bbox_loss: 0.3014 - val_mrcnn_class_loss: 0.1513 - val_mrcnn_bbox_loss: 0.3469 - val_mrcnn_mask_loss: 0.3715
# Epoch 20/20
# 1024/1024 [==============================] - 344s 336ms/step - loss: 1.0467 - rpn_class_loss: 0.0074 - rpn_bbox_loss: 0.2205 - mrcnn_class_loss: 0.1418 - mrcnn_bbox_loss: 0.3123 - mrcnn_mask_loss: 0.3647 - val_loss: 1.2426 - val_rpn_class_loss: 0.0110 - val_rpn_bbox_loss: 0.3379 - val_mrcnn_class_loss: 0.1838 - val_mrcnn_bbox_loss: 0.3426 - val_mrcnn_mask_loss: 0.3673
#
# Starting at epoch 20. LR=0.0001
#
# Checkpoint Path: ../working_copy3/pneumonia20180926T2105/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 21/40
# 1024/1024 [==============================] - 396s 387ms/step - loss: 0.9249 - rpn_class_loss: 0.0062 - rpn_bbox_loss: 0.1760 - mrcnn_class_loss: 0.1190 - mrcnn_bbox_loss: 0.2726 - mrcnn_mask_loss: 0.3511 - val_loss: 1.1609 - val_rpn_class_loss: 0.0064 - val_rpn_bbox_loss: 0.3200 - val_mrcnn_class_loss: 0.1233 - val_mrcnn_bbox_loss: 0.3400 - val_mrcnn_mask_loss: 0.3711
# Epoch 22/40
# 1024/1024 [==============================] - 345s 337ms/step - loss: 0.9073 - rpn_class_loss: 0.0060 - rpn_bbox_loss: 0.1781 - mrcnn_class_loss: 0.1115 - mrcnn_bbox_loss: 0.2637 - mrcnn_mask_loss: 0.3480 - val_loss: 1.2491 - val_rpn_class_loss: 0.0108 - val_rpn_bbox_loss: 0.3849 - val_mrcnn_class_loss: 0.1482 - val_mrcnn_bbox_loss: 0.3379 - val_mrcnn_mask_loss: 0.3673
# Epoch 23/40
# 1024/1024 [==============================] - 338s 330ms/step - loss: 0.8848 - rpn_class_loss: 0.0055 - rpn_bbox_loss: 0.1620 - mrcnn_class_loss: 0.1094 - mrcnn_bbox_loss: 0.2619 - mrcnn_mask_loss: 0.3460 - val_loss: 1.3356 - val_rpn_class_loss: 0.0104 - val_rpn_bbox_loss: 0.4139 - val_mrcnn_class_loss: 0.1438 - val_mrcnn_bbox_loss: 0.3726 - val_mrcnn_mask_loss: 0.3949
# Epoch 24/40
# 1024/1024 [==============================] - 348s 339ms/step - loss: 0.8902 - rpn_class_loss: 0.0056 - rpn_bbox_loss: 0.1644 - mrcnn_class_loss: 0.1100 - mrcnn_bbox_loss: 0.2611 - mrcnn_mask_loss: 0.3490 - val_loss: 1.2484 - val_rpn_class_loss: 0.0084 - val_rpn_bbox_loss: 0.3688 - val_mrcnn_class_loss: 0.1454 - val_mrcnn_bbox_loss: 0.3514 - val_mrcnn_mask_loss: 0.3744
# Epoch 25/40
# 1024/1024 [==============================] - 346s 338ms/step - loss: 0.8838 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.1612 - mrcnn_class_loss: 0.1080 - mrcnn_bbox_loss: 0.2621 - mrcnn_mask_loss: 0.3472 - val_loss: 1.3441 - val_rpn_class_loss: 0.0136 - val_rpn_bbox_loss: 0.4367 - val_mrcnn_class_loss: 0.1821 - val_mrcnn_bbox_loss: 0.3308 - val_mrcnn_mask_loss: 0.3809
# Epoch 26/40
# 1024/1024 [==============================] - 346s 338ms/step - loss: 0.8654 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.1483 - mrcnn_class_loss: 0.1079 - mrcnn_bbox_loss: 0.2571 - mrcnn_mask_loss: 0.3468 - val_loss: 1.1693 - val_rpn_class_loss: 0.0073 - val_rpn_bbox_loss: 0.3084 - val_mrcnn_class_loss: 0.1199 - val_mrcnn_bbox_loss: 0.3482 - val_mrcnn_mask_loss: 0.3855
# Epoch 27/40
# 1024/1024 [==============================] - 339s 331ms/step - loss: 0.8520 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.1469 - mrcnn_class_loss: 0.1029 - mrcnn_bbox_loss: 0.2532 - mrcnn_mask_loss: 0.3438 - val_loss: 1.3383 - val_rpn_class_loss: 0.0104 - val_rpn_bbox_loss: 0.4517 - val_mrcnn_class_loss: 0.1274 - val_mrcnn_bbox_loss: 0.3603 - val_mrcnn_mask_loss: 0.3885
# Epoch 28/40
# 1024/1024 [==============================] - 340s 332ms/step - loss: 0.8540 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.1502 - mrcnn_class_loss: 0.1020 - mrcnn_bbox_loss: 0.2520 - mrcnn_mask_loss: 0.3444 - val_loss: 1.3010 - val_rpn_class_loss: 0.0106 - val_rpn_bbox_loss: 0.4124 - val_mrcnn_class_loss: 0.1523 - val_mrcnn_bbox_loss: 0.3474 - val_mrcnn_mask_loss: 0.3782
# Epoch 29/40
# 1024/1024 [==============================] - 341s 333ms/step - loss: 0.8390 - rpn_class_loss: 0.0051 - rpn_bbox_loss: 0.1424 - mrcnn_class_loss: 0.0993 - mrcnn_bbox_loss: 0.2507 - mrcnn_mask_loss: 0.3416 - val_loss: 1.3794 - val_rpn_class_loss: 0.0093 - val_rpn_bbox_loss: 0.4693 - val_mrcnn_class_loss: 0.1318 - val_mrcnn_bbox_loss: 0.3732 - val_mrcnn_mask_loss: 0.3958
# Epoch 30/40
# 1024/1024 [==============================] - 344s 336ms/step - loss: 0.8335 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.1409 - mrcnn_class_loss: 0.0983 - mrcnn_bbox_loss: 0.2475 - mrcnn_mask_loss: 0.3420 - val_loss: 1.4728 - val_rpn_class_loss: 0.0160 - val_rpn_bbox_loss: 0.5704 - val_mrcnn_class_loss: 0.1380 - val_mrcnn_bbox_loss: 0.3532 - val_mrcnn_mask_loss: 0.3951
# Epoch 31/40
# 1024/1024 [==============================] - 343s 335ms/step - loss: 0.8249 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.1447 - mrcnn_class_loss: 0.0954 - mrcnn_bbox_loss: 0.2414 - mrcnn_mask_loss: 0.3387 - val_loss: 1.2520 - val_rpn_class_loss: 0.0081 - val_rpn_bbox_loss: 0.4189 - val_mrcnn_class_loss: 0.0999 - val_mrcnn_bbox_loss: 0.3391 - val_mrcnn_mask_loss: 0.3859
# Epoch 32/40
# 1024/1024 [==============================] - 342s 334ms/step - loss: 0.8425 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.1458 - mrcnn_class_loss: 0.0987 - mrcnn_bbox_loss: 0.2489 - mrcnn_mask_loss: 0.3441 - val_loss: 1.3701 - val_rpn_class_loss: 0.0102 - val_rpn_bbox_loss: 0.4304 - val_mrcnn_class_loss: 0.1397 - val_mrcnn_bbox_loss: 0.3727 - val_mrcnn_mask_loss: 0.4171
# Epoch 33/40
# 1024/1024 [==============================] - 340s 332ms/step - loss: 0.8167 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.1374 - mrcnn_class_loss: 0.0955 - mrcnn_bbox_loss: 0.2390 - mrcnn_mask_loss: 0.3397 - val_loss: 1.3710 - val_rpn_class_loss: 0.0096 - val_rpn_bbox_loss: 0.4168 - val_mrcnn_class_loss: 0.1677 - val_mrcnn_bbox_loss: 0.3706 - val_mrcnn_mask_loss: 0.4063
# Epoch 34/40
# 1024/1024 [==============================] - 342s 334ms/step - loss: 0.8329 - rpn_class_loss: 0.0053 - rpn_bbox_loss: 0.1457 - mrcnn_class_loss: 0.0958 - mrcnn_bbox_loss: 0.2444 - mrcnn_mask_loss: 0.3416 - val_loss: 1.3664 - val_rpn_class_loss: 0.0143 - val_rpn_bbox_loss: 0.4930 - val_mrcnn_class_loss: 0.1463 - val_mrcnn_bbox_loss: 0.3380 - val_mrcnn_mask_loss: 0.3749
# Epoch 35/40
# 1024/1024 [==============================] - 338s 331ms/step - loss: 0.7959 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.1290 - mrcnn_class_loss: 0.0923 - mrcnn_bbox_loss: 0.2347 - mrcnn_mask_loss: 0.3351 - val_loss: 1.3812 - val_rpn_class_loss: 0.0119 - val_rpn_bbox_loss: 0.4542 - val_mrcnn_class_loss: 0.1622 - val_mrcnn_bbox_loss: 0.3465 - val_mrcnn_mask_loss: 0.4065
# Epoch 36/40
# 1024/1024 [==============================] - 339s 331ms/step - loss: 0.8172 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.1411 - mrcnn_class_loss: 0.0950 - mrcnn_bbox_loss: 0.2361 - mrcnn_mask_loss: 0.3400 - val_loss: 1.2856 - val_rpn_class_loss: 0.0101 - val_rpn_bbox_loss: 0.3953 - val_mrcnn_class_loss: 0.1526 - val_mrcnn_bbox_loss: 0.3419 - val_mrcnn_mask_loss: 0.3857
# Epoch 37/40
# 1024/1024 [==============================] - 344s 336ms/step - loss: 0.7997 - rpn_class_loss: 0.0049 - rpn_bbox_loss: 0.1306 - mrcnn_class_loss: 0.0903 - mrcnn_bbox_loss: 0.2335 - mrcnn_mask_loss: 0.3404 - val_loss: 1.4051 - val_rpn_class_loss: 0.0120 - val_rpn_bbox_loss: 0.5275 - val_mrcnn_class_loss: 0.1237 - val_mrcnn_bbox_loss: 0.3618 - val_mrcnn_mask_loss: 0.3800
# Epoch 38/40
# 1024/1024 [==============================] - 341s 333ms/step - loss: 0.7904 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.1289 - mrcnn_class_loss: 0.0910 - mrcnn_bbox_loss: 0.2289 - mrcnn_mask_loss: 0.3371 - val_loss: 1.2813 - val_rpn_class_loss: 0.0095 - val_rpn_bbox_loss: 0.4215 - val_mrcnn_class_loss: 0.1486 - val_mrcnn_bbox_loss: 0.3220 - val_mrcnn_mask_loss: 0.3796
# Epoch 39/40
# 1024/1024 [==============================] - 338s 330ms/step - loss: 0.8020 - rpn_class_loss: 0.0050 - rpn_bbox_loss: 0.1367 - mrcnn_class_loss: 0.0928 - mrcnn_bbox_loss: 0.2308 - mrcnn_mask_loss: 0.3368 - val_loss: 1.4376 - val_rpn_class_loss: 0.0129 - val_rpn_bbox_loss: 0.5233 - val_mrcnn_class_loss: 0.1440 - val_mrcnn_bbox_loss: 0.3647 - val_mrcnn_mask_loss: 0.3927
# Epoch 40/40
# 1024/1024 [==============================] - 336s 328ms/step - loss: 0.7630 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.1199 - mrcnn_class_loss: 0.0869 - mrcnn_bbox_loss: 0.2195 - mrcnn_mask_loss: 0.3319 - val_loss: 1.3923 - val_rpn_class_loss: 0.0127 - val_rpn_bbox_loss: 0.4906 - val_mrcnn_class_loss: 0.1191 - val_mrcnn_bbox_loss: 0.3639 - val_mrcnn_mask_loss: 0.4061

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)

model.load_weights(model_path, by_name=True)
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE/10, 
            epochs=40, 
            layers='all')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-817d6452a3ef> in <module>()
# ----> 1 model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)
#       2
#       3 model.load_weights(model_path, by_name=True)
#       4 model.train(dataset_train, dataset_val,
#       5             learning_rate=config.LEARNING_RATE/10,
#
# ~/.local/lib/python3.6/site-packages/mask_rcnn-2.1-py3.6.egg/mrcnn/model.py in __init__(self, mode, config, model_dir)
#    1843         self.model_dir = model_dir
#    1844         self.set_log_dir()
# -> 1845         self.keras_model = self.build(mode=mode, config=config)
#    1846
#    1847     def build(self, mode, config):
#
# ~/.local/lib/python3.6/site-packages/mask_rcnn-2.1-py3.6.egg/mrcnn/model.py in build(self, mode, config)
#    2004                                      config.POOL_SIZE, config.NUM_CLASSES,
#    2005                                      train_bn=config.TRAIN_BN,
# -> 2006                                      fc_layers_size=config.FPN_CLASSIF_FC_LAYERS_SIZE)
#    2007
#    2008             mrcnn_mask = build_fpn_mask_graph(rois, mrcnn_feature_maps,
#
# ~/.local/lib/python3.6/site-packages/mask_rcnn-2.1-py3.6.egg/mrcnn/model.py in fpn_classifier_graph(rois, feature_maps, image_meta, pool_size, num_classes, train_bn, fc_layers_size)
#     926     # Shape: [batch, num_boxes, pool_height, pool_width, channels]
#     927     x = PyramidROIAlign([pool_size, pool_size],
# --> 928                         name="roi_align_classifier")([rois, image_meta] + feature_maps)
#     929     # Two 1024 FC layers (implemented with Conv2D for consistency)
#     930     x = KL.TimeDistributed(KL.Conv2D(fc_layers_size, (pool_size, pool_size), padding="valid"),
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     455             # Actually call the layer,
#     456             # collecting output(s), mask(s), and shape(s).
# --> 457             output = self.call(inputs, **kwargs)
#     458             output_mask = self.compute_mask(inputs, previous_mask)
#     459
#
# ~/.local/lib/python3.6/site-packages/mask_rcnn-2.1-py3.6.egg/mrcnn/model.py in call(self, inputs)
#     383         w = x2 - x1
#     384         # Use shape of first image. Images in a batch must have the same size.
# --> 385         image_shape = parse_image_meta_graph(image_meta)['image_shape'][0]
#     386         # Equation 1 in the Feature Pyramid Networks paper. Account for
#     387         # the fact that our coordinates are normalized here.
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in _slice_helper(tensor, slice_spec, var)
#     497                       [tensor] + begin + end + strides) as name:
#     498     if begin:
# --> 499       packed_begin, packed_end, packed_strides = (stack(begin), stack(end),
#     500                                                   stack(strides))
#     501       if (packed_begin.dtype == dtypes.int64 or
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in stack(values, axis, name)
#     862     try:
#     863       # If the input is a constant list, it can be converted to a constant op
# --> 864       return ops.convert_to_tensor(values, name=name)
#     865     except (TypeError, ValueError):
#     866       pass  # Input list contains non-constant tensors
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, preferred_dtype)
#     996       name=name,
#     997       preferred_dtype=preferred_dtype,
# --> 998       as_ref=False)
#     999
#    1000
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx)
#    1092
#    1093     if ret is None:
# -> 1094       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1095
#    1096     if ret is NotImplemented:
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     215                                          as_ref=False):
#     216   _ = as_ref
# --> 217   return constant(v, dtype=dtype, name=name)
#     218
#     219
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name, verify_shape)
#     194   tensor_value.tensor.CopyFrom(
#     195       tensor_util.make_tensor_proto(
# --> 196           value, dtype=dtype, shape=shape, verify_shape=verify_shape))
#     197   dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     198   const_tensor = g.create_op(
#
# ~/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/python/framework/tensor_util.py in make_tensor_proto(values, dtype, shape, verify_shape)
#     491           (shape_size, nparray.size))
#     492
# --> 493   tensor_proto = tensor_pb2.TensorProto(
#     494       dtype=numpy_dtype.as_datatype_enum,
#     495       tensor_shape=tensor_shape.as_shape(shape).as_proto())
#
# KeyboardInterrupt:

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)

model.load_weights(model_path, by_name=True)
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE/10, 
            epochs=30, 
            layers='all')

# %%
#model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)
#model.load_weights(model_path, by_name=True)
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=60, 
            layers='all')

# %%
# select trained model 
dir_names = next(os.walk(model.model_dir))[1]
key = config.NAME.lower()
dir_names = filter(lambda f: f.startswith(key), dir_names)
dir_names = sorted(dir_names)

if not dir_names:
    import errno
    raise FileNotFoundError(
        errno.ENOENT,
        "Could not find model directory under {}".format(self.model_dir))
    
fps = []
# Pick last directory
for d in dir_names: 
    dir_name = os.path.join(model.model_dir, d)
    # Find the last checkpoint
    checkpoints = next(os.walk(dir_name))[2]
    checkpoints = filter(lambda f: f.startswith("mask_rcnn"), checkpoints)
    checkpoints = sorted(checkpoints)
    if not checkpoints:
        print('No weight files in {}'.format(dir_name))
    else:
        checkpoint = os.path.join(dir_name, checkpoints[-1])
        fps.append(checkpoint)

model_path = sorted(fps)[-1]
print('Found model {}'.format(model_path))
# Out:
# Found model ../working_copy3/pneumonia20180926T2105/mask_rcnn_pneumonia_0021.h5

# %%
class InferenceConfig(DetectorConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode='inference', 
                          config=inference_config,
                          model_dir=ROOT_DIR)

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  ../working_copy3/pneumonia20180926T2105/mask_rcnn_pneumonia_0021.h5
# Re-starting from epoch 21

# %%
# set color for class
def get_colors_for_class_ids(class_ids):
    colors = []
    for class_id in class_ids:
        if class_id == 1:
            colors.append((.941, .204, .204))
    return colors

# %% [markdown]
# ### How does the predicted box compared to the expected value? Let's use the validation dataset to check.
#
# Note that we trained only one epoch for **demonstration purposes ONLY**. You might be able to improve performance running more epochs.

# %%
# Show few example of ground truth vs. predictions on the validation dataset 
dataset = dataset_val
fig = plt.figure(figsize=(10, 30))

for i in range(6):

    image_id = random.choice(dataset.image_ids)
    
    original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config, 
                               image_id, use_mini_mask=False)
    
    print(original_image.shape)
    plt.subplot(6, 2, 2*i + 1)
    visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                                dataset.class_names,
                                colors=get_colors_for_class_ids(gt_class_id), ax=fig.axes[-1])
    
    plt.subplot(6, 2, 2*i + 2)
    results = model.detect([original_image]) #, verbose=1)
    r = results[0]
    visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                                dataset.class_names, r['scores'], 
                                colors=get_colors_for_class_ids(r['class_ids']), ax=fig.axes[-1])
# Out:
# (512, 512, 3)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-ddda0efe4a24> in <module>()
#      12     print(original_image.shape)
#      13     plt.subplot(6, 2, 2*i + 1)
# ---> 14     visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id,
#      15                                 dataset.class_names,
#      16                                 colors=get_colors_for_class_ids(gt_class_id), ax=fig.axes[-1])
#
# AttributeError: 'function' object has no attribute 'display_instances'

# %%
# Get filenames of test dataset DICOM images
test_image_fps = get_dicom_fps(test_dicom_dir)

# %% [markdown]
# ### Final steps - Create the submission file

# %%
# Make predictions on test images, write out sample submission 
def predict(image_fps, filepath='submission.csv', min_conf=0.95): 
    
    # assume square image
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    print(resize_factor)
    #resize_factor = ORIG_SIZE 
    with open(filepath, 'w') as file:
        file.write("patientId,PredictionString\n")

        for image_id in tqdm(image_fps): 
            ds = pydicom.read_file(image_id)
            image = ds.pixel_array
            # If grayscale. Convert to RGB for consistency.
            if len(image.shape) != 3 or image.shape[2] != 3:
                image = np.stack((image,) * 3, -1) 
            image, window, scale, padding, crop = utils.resize_image(
                image,
                min_dim=config.IMAGE_MIN_DIM,
                min_scale=config.IMAGE_MIN_SCALE,
                max_dim=config.IMAGE_MAX_DIM,
                mode=config.IMAGE_RESIZE_MODE)

            patient_id = os.path.splitext(os.path.basename(image_id))[0]

            results = model.detect([image])
            r = results[0]

            out_str = ""
            out_str += patient_id 
            out_str += ","
            assert( len(r['rois']) == len(r['class_ids']) == len(r['scores']) )
            if len(r['rois']) == 0: 
                pass
            else: 
                num_instances = len(r['rois'])

                for i in range(num_instances): 
                    if r['scores'][i] > min_conf: 
                        out_str += ' '
                        out_str += str(round(r['scores'][i], 2))
                        out_str += ' '

                        # x1, y1, width, height 
                        x1 = r['rois'][i][1]
                        y1 = r['rois'][i][0]
                        width = r['rois'][i][3] - x1 
                        height = r['rois'][i][2] - y1 
                        bboxes_str = "{} {} {} {}".format(x1*resize_factor, y1*resize_factor, \
                                                           width*resize_factor, height*resize_factor)   
                        #bboxes_str = "{} {} {} {}".format(x1, y1, \
                        #                                   width, height)
                        out_str += bboxes_str

            file.write(out_str+"\n")

# %%
# predict only the first 50 entries ??
submission_fp = os.path.join(ROOT_DIR, 'submission-21epoch-1024-steps-0.95-512-size-salamander-20-repeat-min-val-error.csv')
print(submission_fp)
predict(test_image_fps, filepath=submission_fp)
# Out:
#   0%|                                                                                                                                                                       | 0/1000 [00:00<?, ?it/s]
# ../working_copy3/submission-21epoch-1024-steps-0.95-512-size-salamander-20-repeat-min-val-error.csv
# 2.0
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [02:05<00:00,  7.83it/s]

# %%
output = pd.read_csv(submission_fp, names=['patientId', 'PredictionString'])
output.head(60)

# %%
# show a few test image detection example
def visualize(): 
    image_id = random.choice(test_image_fps)
    ds = pydicom.read_file(image_id)
    
    # original image 
    image = ds.pixel_array
    
    # assume square image 
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    
    # If grayscale. Convert to RGB for consistency.
    if len(image.shape) != 3 or image.shape[2] != 3:
        image = np.stack((image,) * 3, -1) 
    resized_image, window, scale, padding, crop = utils.resize_image(
        image,
        min_dim=config.IMAGE_MIN_DIM,
        min_scale=config.IMAGE_MIN_SCALE,
        max_dim=config.IMAGE_MAX_DIM,
        mode=config.IMAGE_RESIZE_MODE)

    patient_id = os.path.splitext(os.path.basename(image_id))[0]
    print(patient_id)

    results = model.detect([resized_image])
    r = results[0]
    for bbox in r['rois']: 
        print(bbox)
        x1 = int(bbox[1] * resize_factor)
        y1 = int(bbox[0] * resize_factor)
        x2 = int(bbox[3] * resize_factor)
        y2 = int(bbox[2]  * resize_factor)
        cv2.rectangle(image, (x1,y1), (x2,y2), (77, 255, 9), 3, 1)
        width = x2 - x1 
        height = y2 - y1 
        print("x {} y {} h {} w {}".format(x1, y1, width, height))
    plt.figure() 
    plt.imshow(image, cmap=plt.cm.gist_gray)

visualize()
visualize()
visualize()
visualize()
# Out:
# 1f0ef178-e4be-4ec3-b44a-232ef178f5e9
# [284 135 368 229]
# x 270 y 568 h 188 w 168
# 270d287b-5f32-469d-9f88-f4a87f27ef47
# [179 305 342 422]
# x 610 y 358 h 234 w 326
# [193 106 272 179]
# x 212 y 386 h 146 w 158
# 219334b4-6696-4b41-90bd-0c56878ccbe6
# [107 142 188 223]
# x 284 y 214 h 162 w 162
# [ 92 278 182 362]
# x 556 y 184 h 168 w 180
# 2c96c09b-aaa8-4c07-8e69-c2210f04be2d
# [287 336 396 447]
# x 672 y 574 h 222 w 218
# [278 168 378 246]
# x 336 y 556 h 156 w 200

# %%
# remove files to allow committing (hit files limit otherwise)
# !rm -rf /kaggle/working/Mask_RCNN
