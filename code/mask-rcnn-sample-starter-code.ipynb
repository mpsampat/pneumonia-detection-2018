# %% [markdown]
# **Mask-RCNN Sample Starter Model for the RSNA Pneumonia Detection Challenge**
#
# [MD.ai](https://www.md.ai). The dataset for this challenge, created on the MD.ai platform in collaboration with the Radiological Society of North America (RSNA), the Society of Thoracic Radiology (STR), the US National Institutes of Health (NIH), and Kaggle.
# This notebook covers the basics of parsing the competition dataset, training using a detector basd on the [Mask-RCNN algorithm](https://arxiv.org/abs/1703.06870) for object detection and instance segmentation.
# **Note that the Mask-RCNN detector configuration parameters have been selected to reduce training time for demonstration purposes, they are not optimal.
# **
#
# This is based on our deep learning for medical imaging lessons:
#
# - Lesson 1. Classification of chest vs. adominal X-rays using TensorFlow/Keras [Github](https://github.com/mdai/ml-lessons/blob/master/lesson1-xray-images-classification.ipynb) [Annotator](https://public.md.ai/annotator/project/PVq9raBJ)
# - Lesson 2. Lung X-Rays Semantic Segmentation using UNets. [Github](https://github.com/mdai/ml-lessons/blob/master/lesson2-lung-xrays-segmentation.ipynb)
# [Annotator](https://public.md.ai/annotator/project/aGq4k6NW/workspace)
# - Lesson 3. RSNA Pneumonia detection using Kaggle data format [Github](https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-kaggle.ipynb) [Annotator](https://public.md.ai/annotator/project/LxR6zdR2/workspace)
# - Lesson 3. RSNA Pneumonia detection using MD.ai python client library [Github](https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-mdai-client-lib.ipynb) [Annotator](https://public.md.ai/annotator/project/LxR6zdR2/workspace)
#
# *Copyright 2018 MD.ai, Inc.
# Licensed under the Apache License, Version 2.0*

# %%
import os 
import sys
import random
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt
import json
import pydicom
from imgaug import augmenters as iaa
from tqdm import tqdm
import pandas as pd 
import glob

# %% [markdown]
# ### First: Install Kaggle API for download competition data.

# %%
DATA_DIR = '../input'

# Directory to save logs and trained model
ROOT_DIR = '../working'

# %% [markdown]
# ###  MD.ai Annotator
#
# Additionally, If you are interested in augmenting the existing annotations, you can use the MD.ai annotator to view DICOM images, and create annotatios to be exported.
# MD.ai annotator project URL for the Kaggle dataset: https://public.md.ai/annotator/project/LxR6zdR2/workspace
#
# **Annotator features**
# - The annotator can be used to view DICOM images and create image and exam level annotations.
# - You can apply the annotator to filter by label, adjudicate annotations, and assign annotation tasks to your team.
# - Notebooks can be built directly within the annotator for rapid model development.
# - The data wrangling is abstracted away by the interface and by our MD.ai library.
# - Simplifies image annotation in order to widen the participation in the futrue of medical image deep learning.
#
# The annotator allows you to create initial annotations, build and run models, modify/finetune the annotations based on predicted values, and repeat.
# The MD.ai python client library implements functions to easily download images and annotations and to prepare the datasets used to train the model for classification. See the following example notebook for parsing annotations and training using MD.ai annotator:
# https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-mdai-client-lib.ipynb
# - MD.ai URL: https://www.md.ai
# - MD.ai documentation URL: https://docs.md.ai/

# %% [markdown]
# ### Install Matterport's Mask-RCNN model from github.
# See the [Matterport's implementation of Mask-RCNN](https://github.com/matterport/Mask_RCNN).

# %%
#!git clone https://www.github.com/matterport/Mask_RCNN.git
#os.chdir('Mask_RCNN')
#!python setup.py -q install

# %%
# Import Mask RCNN
sys.path.append(os.path.join("/home/mehul/kaggle/pneumonia-detection-2018", 'Mask_RCNN'))  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log
# Out:
# Using TensorFlow backend.

# %%
train_dicom_dir = os.path.join(DATA_DIR, 'stage_1_train_images')
test_dicom_dir = os.path.join(DATA_DIR, 'stage_1_test_images')

# %% [markdown]
# ### Some setup functions and classes for Mask-RCNN
#
# - dicom_fps is a list of the dicom image path and filenames
# - image_annotions is a dictionary of the annotations keyed by the filenames
# - parsing the dataset returns a list of the image filenames and the annotations dictionary

# %%
def get_dicom_fps(dicom_dir):
    dicom_fps = glob.glob(dicom_dir+'/'+'*.dcm')
    return list(set(dicom_fps))

def parse_dataset(dicom_dir, anns): 
    image_fps = get_dicom_fps(dicom_dir)
    image_annotations = {fp: [] for fp in image_fps}
    for index, row in anns.iterrows(): 
        fp = os.path.join(dicom_dir, row['patientId']+'.dcm')
        image_annotations[fp].append(row)
    return image_fps, image_annotations

# %%
# The following parameters have been selected to reduce running time for demonstration purposes 
# These are not optimal 

class DetectorConfig(Config):
    """Configuration for training pneumonia detection on the RSNA pneumonia dataset.
    Overrides values in the base Config class.
    """
    
    # Give the configuration a recognizable name  
    NAME = 'pneumonia'
    
    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 2 
    
    BACKBONE = 'resnet50'
    
    NUM_CLASSES = 2  # background + 1 pneumonia classes
    
    IMAGE_MIN_DIM = 512
    IMAGE_MAX_DIM = 512
    RPN_ANCHOR_SCALES = (32, 64, 128, 256)
    TRAIN_ROIS_PER_IMAGE = 32
    MAX_GT_INSTANCES = 3
    DETECTION_MAX_INSTANCES = 3
    DETECTION_MIN_CONFIDENCE = 0.9
    DETECTION_NMS_THRESHOLD = 0.1

    STEPS_PER_EPOCH = 100
    
config = DetectorConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        3
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.1
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_MAX_DIM                  512
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [512 512   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               3
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           pneumonia
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
class DetectorDataset(utils.Dataset):
    """Dataset class for training pneumonia detection on the RSNA pneumonia dataset.
    """

    def __init__(self, image_fps, image_annotations, orig_height, orig_width):
        super().__init__(self)
        
        # Add classes
        self.add_class('pneumonia', 1, 'Lung Opacity')
   
        # add images 
        for i, fp in enumerate(image_fps):
            annotations = image_annotations[fp]
            self.add_image('pneumonia', image_id=i, path=fp, 
                           annotations=annotations, orig_height=orig_height, orig_width=orig_width)
            
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

    def load_image(self, image_id):
        info = self.image_info[image_id]
        fp = info['path']
        ds = pydicom.read_file(fp)
        image = ds.pixel_array
        # If grayscale. Convert to RGB for consistency.
        if len(image.shape) != 3 or image.shape[2] != 3:
            image = np.stack((image,) * 3, -1)
        return image

    def load_mask(self, image_id):
        info = self.image_info[image_id]
        annotations = info['annotations']
        count = len(annotations)
        if count == 0:
            mask = np.zeros((info['orig_height'], info['orig_width'], 1), dtype=np.uint8)
            class_ids = np.zeros((1,), dtype=np.int32)
        else:
            mask = np.zeros((info['orig_height'], info['orig_width'], count), dtype=np.uint8)
            class_ids = np.zeros((count,), dtype=np.int32)
            for i, a in enumerate(annotations):
                if a['Target'] == 1:
                    x = int(a['x'])
                    y = int(a['y'])
                    w = int(a['width'])
                    h = int(a['height'])
                    mask_instance = mask[:, :, i].copy()
                    cv2.rectangle(mask_instance, (x, y), (x+w, y+h), 255, -1)
                    mask[:, :, i] = mask_instance
                    class_ids[i] = 1
        return mask.astype(np.bool), class_ids.astype(np.int32)

# %% [markdown]
# ### Examine the annotation data, parse the dataset, and view dicom fields

# %%
# training dataset
anns = pd.read_csv(os.path.join(DATA_DIR, 'stage_1_train_labels.csv'))
anns.head()
# Out:
#                               patientId      x      y  width  height  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1

# %%
image_fps, image_annotations = parse_dataset(train_dicom_dir, anns=anns)

# %%
ds = pydicom.read_file(image_fps[0]) # read dicom image from filepath 
image = ds.pixel_array # get image array

# %%
# show dicom fields 
ds
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.8323329.12520.1517874365.493811
# (0008, 0020) Study Date                          DA: '19010101'
# (0008, 0030) Study Time                          TM: '000000.00'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 103e) Series Description                  LO: 'view: AP'
# (0010, 0010) Patient's Name                      PN: '11827075-47dd-4f3c-a7b5-aae992cce35b'
# (0010, 0020) Patient ID                          LO: '11827075-47dd-4f3c-a7b5-aae992cce35b'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1010) Patient's Age                       AS: '31'
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 5101) View Position                       CS: 'AP'
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.8323329.12520.1517874365.493810
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.8323329.12520.1517874365.493809
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1024
# (0028, 0011) Columns                             US: 1024
# (0028, 0030) Pixel Spacing                       DS: ['0.168', '0.168']
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 2110) Lossy Image Compression             CS: '01'
# (0028, 2114) Lossy Image Compression Method      CS: 'ISO_10918_1'
# (7fe0, 0010) Pixel Data                          OB: Array of 118932 bytes

# %%
# Original DICOM image size: 1024 x 1024
ORIG_SIZE = 1024

# %% [markdown]
# ### Split the data into training and validation datasets
# **Note: We have only used only a portion of the images for demonstration purposes. See comments below.**
#
#  - To use all the images do: image_fps_list = list(image_fps)
#  - Or change the number of images from 100 to a custom number

# %%
######################################################################
# Modify this line to use more or fewer images for training/validation. 
# To use all images, do: image_fps_list = list(image_fps)
image_fps_list = list(image_fps) 
#####################################################################

# split dataset into training vs. validation dataset 
# split ratio is set to 0.9 vs. 0.1 (train vs. validation, respectively)
sorted(image_fps_list)
random.seed(42)
random.shuffle(image_fps_list)

validation_split = 0.1
split_index = int((1 - validation_split) * len(image_fps_list))

image_fps_train = image_fps_list[:split_index]
image_fps_val = image_fps_list[split_index:]

print(len(image_fps_train), len(image_fps_val))
# Out:
# 23115 2569

# %% [markdown]
# ### Create and prepare the training dataset using the DetectorDataset class.

# %%
# prepare the training dataset
dataset_train = DetectorDataset(image_fps_train, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_train.prepare()

# %% [markdown]
# ### Let's look at a sample annotation. We see a bounding box with (x, y) of the the top left corner as well as the width and height.

# %%
# Show annotation(s) for a DICOM image 
test_fp = random.choice(image_fps_train)
image_annotations[test_fp]
# Out:
# [patientId    78aca32e-70f5-4d6b-a51a-f2ce862c47b2
#  x                                             NaN
#  y                                             NaN
#  width                                         NaN
#  height                                        NaN
#  Target                                          0
#  Name: 11661, dtype: object]

# %%
# prepare the validation dataset
dataset_val = DetectorDataset(image_fps_val, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_val.prepare()

# %% [markdown]
# ### Display a random image with bounding boxes

# %%
# Load and display random samples and their bounding boxes
# Suggestion: Run this a few times to see different examples. 

image_id = random.choice(dataset_train.image_ids)
image_fp = dataset_train.image_reference(image_id)
image = dataset_train.load_image(image_id)
mask, class_ids = dataset_train.load_mask(image_id)

print(image.shape)

plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(image[:, :, 0], cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
masked = np.zeros(image.shape[:2])
for i in range(mask.shape[2]):
    masked += image[:, :, 0] * mask[:, :, i]
plt.imshow(masked, cmap='gray')
plt.axis('off')

print(image_fp)
print(class_ids)
# Out:
# (1024, 1024, 3)
# ../input/stage_1_train_images/a3173197-b2f2-440a-abef-5617013b16a5.dcm
# [0]

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)

# %% [markdown]
# ### Image Augmentation. Try finetuning some variables to custom values

# %%
# Image augmentation 
augmentation = iaa.SomeOf((0, 1), [
    iaa.Fliplr(0.5),
    iaa.Affine(
        scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
        rotate=(-25, 25),
        shear=(-8, 8)
    ),
    iaa.Multiply((0.9, 1.1))
])

# %% [markdown]
# ### Now it's time to train the model. Note that training even a basic model can take a few hours.
#
# Note: the following model is for demonstration purpose only. We have limited the training to one epoch, and have set nominal values for the Detector Configuration to reduce run-time.
#
# - dataset_train and dataset_val are derived from DetectorDataset
# - DetectorDataset loads images from image filenames and  masks from the annotation data
# - model is Mask-RCNN

# %%
NUM_EPOCHS = 50

# Train Mask-RCNN Model 
import warnings 
warnings.filterwarnings("ignore")
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=NUM_EPOCHS, 
            layers='all',
            augmentation=augmentation)
# Out:
# WARNING:tensorflow:From /home/mehul/miniconda3/envs/tf7/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
#
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: ../working/pneumonia20180915T1656/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/50
# 100/100 [==============================] - 63s 632ms/step - loss: 2.9668 - rpn_class_loss: 0.1480 - rpn_bbox_loss: 0.9219 - mrcnn_class_loss: 0.3577 - mrcnn_bbox_loss: 0.9069 - mrcnn_mask_loss: 0.6322 - val_loss: 2.3393 - val_rpn_class_loss: 0.0520 - val_rpn_bbox_loss: 0.5734 - val_mrcnn_class_loss: 0.3847 - val_mrcnn_bbox_loss: 0.7351 - val_mrcnn_mask_loss: 0.5941
# Epoch 2/50
# 100/100 [==============================] - 44s 436ms/step - loss: 2.1756 - rpn_class_loss: 0.0480 - rpn_bbox_loss: 0.4876 - mrcnn_class_loss: 0.3777 - mrcnn_bbox_loss: 0.6764 - mrcnn_mask_loss: 0.5859 - val_loss: 1.9864 - val_rpn_class_loss: 0.0398 - val_rpn_bbox_loss: 0.4222 - val_mrcnn_class_loss: 0.3559 - val_mrcnn_bbox_loss: 0.6040 - val_mrcnn_mask_loss: 0.5645
# Epoch 3/50
# 100/100 [==============================] - 41s 413ms/step - loss: 2.0755 - rpn_class_loss: 0.0447 - rpn_bbox_loss: 0.4867 - mrcnn_class_loss: 0.3291 - mrcnn_bbox_loss: 0.6283 - mrcnn_mask_loss: 0.5866 - val_loss: 2.1788 - val_rpn_class_loss: 0.0429 - val_rpn_bbox_loss: 0.6365 - val_mrcnn_class_loss: 0.3176 - val_mrcnn_bbox_loss: 0.6110 - val_mrcnn_mask_loss: 0.5707
# Epoch 4/50
# 100/100 [==============================] - 42s 418ms/step - loss: 2.0873 - rpn_class_loss: 0.0422 - rpn_bbox_loss: 0.4681 - mrcnn_class_loss: 0.3604 - mrcnn_bbox_loss: 0.6391 - mrcnn_mask_loss: 0.5775 - val_loss: 2.1544 - val_rpn_class_loss: 0.0393 - val_rpn_bbox_loss: 0.5684 - val_mrcnn_class_loss: 0.3740 - val_mrcnn_bbox_loss: 0.6292 - val_mrcnn_mask_loss: 0.5435
# Epoch 5/50
# 100/100 [==============================] - 40s 397ms/step - loss: 2.0067 - rpn_class_loss: 0.0417 - rpn_bbox_loss: 0.4504 - mrcnn_class_loss: 0.3527 - mrcnn_bbox_loss: 0.6002 - mrcnn_mask_loss: 0.5617 - val_loss: 2.0071 - val_rpn_class_loss: 0.0382 - val_rpn_bbox_loss: 0.5354 - val_mrcnn_class_loss: 0.2804 - val_mrcnn_bbox_loss: 0.6069 - val_mrcnn_mask_loss: 0.5462
# Epoch 6/50
# 100/100 [==============================] - 41s 407ms/step - loss: 2.0012 - rpn_class_loss: 0.0372 - rpn_bbox_loss: 0.4864 - mrcnn_class_loss: 0.3267 - mrcnn_bbox_loss: 0.5880 - mrcnn_mask_loss: 0.5629 - val_loss: 1.9870 - val_rpn_class_loss: 0.0408 - val_rpn_bbox_loss: 0.5447 - val_mrcnn_class_loss: 0.3111 - val_mrcnn_bbox_loss: 0.5580 - val_mrcnn_mask_loss: 0.5324
# Epoch 7/50
# 100/100 [==============================] - 41s 407ms/step - loss: 2.0333 - rpn_class_loss: 0.0370 - rpn_bbox_loss: 0.4822 - mrcnn_class_loss: 0.3614 - mrcnn_bbox_loss: 0.6023 - mrcnn_mask_loss: 0.5504 - val_loss: 2.0042 - val_rpn_class_loss: 0.0438 - val_rpn_bbox_loss: 0.5699 - val_mrcnn_class_loss: 0.2704 - val_mrcnn_bbox_loss: 0.6007 - val_mrcnn_mask_loss: 0.5194
# Epoch 8/50
# 100/100 [==============================] - 41s 408ms/step - loss: 1.9257 - rpn_class_loss: 0.0350 - rpn_bbox_loss: 0.4481 - mrcnn_class_loss: 0.3227 - mrcnn_bbox_loss: 0.5867 - mrcnn_mask_loss: 0.5331 - val_loss: 2.0205 - val_rpn_class_loss: 0.0415 - val_rpn_bbox_loss: 0.6112 - val_mrcnn_class_loss: 0.2954 - val_mrcnn_bbox_loss: 0.5579 - val_mrcnn_mask_loss: 0.5143
# Epoch 9/50
# 100/100 [==============================] - 41s 413ms/step - loss: 1.9636 - rpn_class_loss: 0.0392 - rpn_bbox_loss: 0.4608 - mrcnn_class_loss: 0.3352 - mrcnn_bbox_loss: 0.5949 - mrcnn_mask_loss: 0.5336 - val_loss: 1.8235 - val_rpn_class_loss: 0.0379 - val_rpn_bbox_loss: 0.4485 - val_mrcnn_class_loss: 0.2722 - val_mrcnn_bbox_loss: 0.5542 - val_mrcnn_mask_loss: 0.5107
# Epoch 10/50
# 100/100 [==============================] - 40s 402ms/step - loss: 1.9412 - rpn_class_loss: 0.0389 - rpn_bbox_loss: 0.4366 - mrcnn_class_loss: 0.3421 - mrcnn_bbox_loss: 0.5780 - mrcnn_mask_loss: 0.5456 - val_loss: 1.9849 - val_rpn_class_loss: 0.0389 - val_rpn_bbox_loss: 0.5247 - val_mrcnn_class_loss: 0.3313 - val_mrcnn_bbox_loss: 0.5937 - val_mrcnn_mask_loss: 0.4962
# Epoch 11/50
# 100/100 [==============================] - 42s 415ms/step - loss: 1.9282 - rpn_class_loss: 0.0368 - rpn_bbox_loss: 0.4232 - mrcnn_class_loss: 0.3465 - mrcnn_bbox_loss: 0.5857 - mrcnn_mask_loss: 0.5360 - val_loss: 1.9161 - val_rpn_class_loss: 0.0378 - val_rpn_bbox_loss: 0.4436 - val_mrcnn_class_loss: 0.3699 - val_mrcnn_bbox_loss: 0.5718 - val_mrcnn_mask_loss: 0.4930
# Epoch 12/50
# 100/100 [==============================] - 40s 404ms/step - loss: 1.8610 - rpn_class_loss: 0.0368 - rpn_bbox_loss: 0.4565 - mrcnn_class_loss: 0.3063 - mrcnn_bbox_loss: 0.5527 - mrcnn_mask_loss: 0.5087 - val_loss: 1.7911 - val_rpn_class_loss: 0.0413 - val_rpn_bbox_loss: 0.4087 - val_mrcnn_class_loss: 0.3117 - val_mrcnn_bbox_loss: 0.5459 - val_mrcnn_mask_loss: 0.4835
# Epoch 13/50
# 100/100 [==============================] - 39s 390ms/step - loss: 1.8945 - rpn_class_loss: 0.0329 - rpn_bbox_loss: 0.4632 - mrcnn_class_loss: 0.3138 - mrcnn_bbox_loss: 0.5772 - mrcnn_mask_loss: 0.5075 - val_loss: 1.9344 - val_rpn_class_loss: 0.0372 - val_rpn_bbox_loss: 0.4827 - val_mrcnn_class_loss: 0.3026 - val_mrcnn_bbox_loss: 0.6065 - val_mrcnn_mask_loss: 0.5054
# Epoch 14/50
# 100/100 [==============================] - 41s 408ms/step - loss: 1.8632 - rpn_class_loss: 0.0364 - rpn_bbox_loss: 0.4664 - mrcnn_class_loss: 0.2984 - mrcnn_bbox_loss: 0.5641 - mrcnn_mask_loss: 0.4979 - val_loss: 1.8596 - val_rpn_class_loss: 0.0376 - val_rpn_bbox_loss: 0.4603 - val_mrcnn_class_loss: 0.3184 - val_mrcnn_bbox_loss: 0.5560 - val_mrcnn_mask_loss: 0.4873
# Epoch 15/50
# 100/100 [==============================] - 39s 390ms/step - loss: 1.8783 - rpn_class_loss: 0.0350 - rpn_bbox_loss: 0.4215 - mrcnn_class_loss: 0.3284 - mrcnn_bbox_loss: 0.5841 - mrcnn_mask_loss: 0.5093 - val_loss: 1.7730 - val_rpn_class_loss: 0.0362 - val_rpn_bbox_loss: 0.3882 - val_mrcnn_class_loss: 0.3105 - val_mrcnn_bbox_loss: 0.5520 - val_mrcnn_mask_loss: 0.4861
# Epoch 16/50
# 100/100 [==============================] - 41s 409ms/step - loss: 1.8092 - rpn_class_loss: 0.0347 - rpn_bbox_loss: 0.3661 - mrcnn_class_loss: 0.3248 - mrcnn_bbox_loss: 0.5788 - mrcnn_mask_loss: 0.5049 - val_loss: 1.8022 - val_rpn_class_loss: 0.0369 - val_rpn_bbox_loss: 0.3750 - val_mrcnn_class_loss: 0.3326 - val_mrcnn_bbox_loss: 0.5788 - val_mrcnn_mask_loss: 0.4788
# Epoch 17/50
# 100/100 [==============================] - 38s 381ms/step - loss: 1.8482 - rpn_class_loss: 0.0331 - rpn_bbox_loss: 0.4477 - mrcnn_class_loss: 0.3207 - mrcnn_bbox_loss: 0.5579 - mrcnn_mask_loss: 0.4888 - val_loss: 1.9415 - val_rpn_class_loss: 0.0358 - val_rpn_bbox_loss: 0.5056 - val_mrcnn_class_loss: 0.3313 - val_mrcnn_bbox_loss: 0.5870 - val_mrcnn_mask_loss: 0.4818
# Epoch 18/50
# 100/100 [==============================] - 40s 400ms/step - loss: 1.7778 - rpn_class_loss: 0.0317 - rpn_bbox_loss: 0.3998 - mrcnn_class_loss: 0.3132 - mrcnn_bbox_loss: 0.5461 - mrcnn_mask_loss: 0.4869 - val_loss: 1.8366 - val_rpn_class_loss: 0.0335 - val_rpn_bbox_loss: 0.4975 - val_mrcnn_class_loss: 0.2518 - val_mrcnn_bbox_loss: 0.5751 - val_mrcnn_mask_loss: 0.4786
# Epoch 19/50
# 100/100 [==============================] - 40s 405ms/step - loss: 1.8087 - rpn_class_loss: 0.0325 - rpn_bbox_loss: 0.4398 - mrcnn_class_loss: 0.2993 - mrcnn_bbox_loss: 0.5464 - mrcnn_mask_loss: 0.4907 - val_loss: 1.9076 - val_rpn_class_loss: 0.0404 - val_rpn_bbox_loss: 0.4647 - val_mrcnn_class_loss: 0.2974 - val_mrcnn_bbox_loss: 0.6142 - val_mrcnn_mask_loss: 0.4909
# Epoch 20/50
# 100/100 [==============================] - 41s 408ms/step - loss: 1.8125 - rpn_class_loss: 0.0341 - rpn_bbox_loss: 0.4087 - mrcnn_class_loss: 0.3009 - mrcnn_bbox_loss: 0.5642 - mrcnn_mask_loss: 0.5045 - val_loss: 1.8476 - val_rpn_class_loss: 0.0365 - val_rpn_bbox_loss: 0.4688 - val_mrcnn_class_loss: 0.3147 - val_mrcnn_bbox_loss: 0.5570 - val_mrcnn_mask_loss: 0.4706
# Epoch 21/50
# 100/100 [==============================] - 42s 420ms/step - loss: 1.8387 - rpn_class_loss: 0.0338 - rpn_bbox_loss: 0.3886 - mrcnn_class_loss: 0.3396 - mrcnn_bbox_loss: 0.5723 - mrcnn_mask_loss: 0.5044 - val_loss: 1.6816 - val_rpn_class_loss: 0.0350 - val_rpn_bbox_loss: 0.3923 - val_mrcnn_class_loss: 0.2689 - val_mrcnn_bbox_loss: 0.5195 - val_mrcnn_mask_loss: 0.4659
# Epoch 22/50
# 100/100 [==============================] - 41s 412ms/step - loss: 1.7674 - rpn_class_loss: 0.0323 - rpn_bbox_loss: 0.3925 - mrcnn_class_loss: 0.3031 - mrcnn_bbox_loss: 0.5417 - mrcnn_mask_loss: 0.4977 - val_loss: 1.7406 - val_rpn_class_loss: 0.0279 - val_rpn_bbox_loss: 0.4115 - val_mrcnn_class_loss: 0.2904 - val_mrcnn_bbox_loss: 0.5383 - val_mrcnn_mask_loss: 0.4725
# Epoch 23/50
# 100/100 [==============================] - 40s 395ms/step - loss: 1.8443 - rpn_class_loss: 0.0311 - rpn_bbox_loss: 0.4283 - mrcnn_class_loss: 0.3224 - mrcnn_bbox_loss: 0.5699 - mrcnn_mask_loss: 0.4925 - val_loss: 1.7302 - val_rpn_class_loss: 0.0287 - val_rpn_bbox_loss: 0.4122 - val_mrcnn_class_loss: 0.2794 - val_mrcnn_bbox_loss: 0.5509 - val_mrcnn_mask_loss: 0.4589
# Epoch 24/50
# 100/100 [==============================] - 41s 413ms/step - loss: 1.7713 - rpn_class_loss: 0.0290 - rpn_bbox_loss: 0.4040 - mrcnn_class_loss: 0.3205 - mrcnn_bbox_loss: 0.5370 - mrcnn_mask_loss: 0.4808 - val_loss: 1.8790 - val_rpn_class_loss: 0.0315 - val_rpn_bbox_loss: 0.5559 - val_mrcnn_class_loss: 0.2544 - val_mrcnn_bbox_loss: 0.5605 - val_mrcnn_mask_loss: 0.4768
# Epoch 25/50
# 100/100 [==============================] - 39s 388ms/step - loss: 1.7929 - rpn_class_loss: 0.0320 - rpn_bbox_loss: 0.4552 - mrcnn_class_loss: 0.3106 - mrcnn_bbox_loss: 0.5274 - mrcnn_mask_loss: 0.4677 - val_loss: 1.7651 - val_rpn_class_loss: 0.0356 - val_rpn_bbox_loss: 0.4465 - val_mrcnn_class_loss: 0.2812 - val_mrcnn_bbox_loss: 0.5411 - val_mrcnn_mask_loss: 0.4607
# Epoch 26/50
# 100/100 [==============================] - 42s 417ms/step - loss: 1.7613 - rpn_class_loss: 0.0300 - rpn_bbox_loss: 0.4057 - mrcnn_class_loss: 0.3176 - mrcnn_bbox_loss: 0.5300 - mrcnn_mask_loss: 0.4780 - val_loss: 1.8673 - val_rpn_class_loss: 0.0400 - val_rpn_bbox_loss: 0.4966 - val_mrcnn_class_loss: 0.2824 - val_mrcnn_bbox_loss: 0.5731 - val_mrcnn_mask_loss: 0.4752
# Epoch 27/50
# 100/100 [==============================] - 42s 421ms/step - loss: 1.9094 - rpn_class_loss: 0.0328 - rpn_bbox_loss: 0.4409 - mrcnn_class_loss: 0.3567 - mrcnn_bbox_loss: 0.5804 - mrcnn_mask_loss: 0.4987 - val_loss: 1.6728 - val_rpn_class_loss: 0.0321 - val_rpn_bbox_loss: 0.3921 - val_mrcnn_class_loss: 0.2776 - val_mrcnn_bbox_loss: 0.5104 - val_mrcnn_mask_loss: 0.4606
# Epoch 28/50
# 100/100 [==============================] - 41s 412ms/step - loss: 1.7908 - rpn_class_loss: 0.0311 - rpn_bbox_loss: 0.4150 - mrcnn_class_loss: 0.3244 - mrcnn_bbox_loss: 0.5345 - mrcnn_mask_loss: 0.4859 - val_loss: 1.7592 - val_rpn_class_loss: 0.0336 - val_rpn_bbox_loss: 0.3792 - val_mrcnn_class_loss: 0.3517 - val_mrcnn_bbox_loss: 0.5357 - val_mrcnn_mask_loss: 0.4589
# Epoch 29/50
# 100/100 [==============================] - 40s 403ms/step - loss: 1.7975 - rpn_class_loss: 0.0319 - rpn_bbox_loss: 0.4181 - mrcnn_class_loss: 0.3235 - mrcnn_bbox_loss: 0.5479 - mrcnn_mask_loss: 0.4761 - val_loss: 1.7543 - val_rpn_class_loss: 0.0347 - val_rpn_bbox_loss: 0.4386 - val_mrcnn_class_loss: 0.2822 - val_mrcnn_bbox_loss: 0.5348 - val_mrcnn_mask_loss: 0.4640
# Epoch 30/50
# 100/100 [==============================] - 40s 401ms/step - loss: 1.7705 - rpn_class_loss: 0.0318 - rpn_bbox_loss: 0.4002 - mrcnn_class_loss: 0.3195 - mrcnn_bbox_loss: 0.5363 - mrcnn_mask_loss: 0.4826 - val_loss: 1.7261 - val_rpn_class_loss: 0.0312 - val_rpn_bbox_loss: 0.3794 - val_mrcnn_class_loss: 0.3238 - val_mrcnn_bbox_loss: 0.5309 - val_mrcnn_mask_loss: 0.4610
# Epoch 31/50
# 100/100 [==============================] - 38s 382ms/step - loss: 1.7893 - rpn_class_loss: 0.0287 - rpn_bbox_loss: 0.3745 - mrcnn_class_loss: 0.3405 - mrcnn_bbox_loss: 0.5602 - mrcnn_mask_loss: 0.4853 - val_loss: 1.8041 - val_rpn_class_loss: 0.0328 - val_rpn_bbox_loss: 0.4428 - val_mrcnn_class_loss: 0.3201 - val_mrcnn_bbox_loss: 0.5417 - val_mrcnn_mask_loss: 0.4666
# Epoch 32/50
# 100/100 [==============================] - 39s 391ms/step - loss: 1.7025 - rpn_class_loss: 0.0278 - rpn_bbox_loss: 0.3705 - mrcnn_class_loss: 0.3241 - mrcnn_bbox_loss: 0.5058 - mrcnn_mask_loss: 0.4743 - val_loss: 1.7620 - val_rpn_class_loss: 0.0361 - val_rpn_bbox_loss: 0.4034 - val_mrcnn_class_loss: 0.3098 - val_mrcnn_bbox_loss: 0.5466 - val_mrcnn_mask_loss: 0.4660
# Epoch 33/50
# 100/100 [==============================] - 40s 400ms/step - loss: 1.7609 - rpn_class_loss: 0.0296 - rpn_bbox_loss: 0.3867 - mrcnn_class_loss: 0.3481 - mrcnn_bbox_loss: 0.5257 - mrcnn_mask_loss: 0.4708 - val_loss: 1.7960 - val_rpn_class_loss: 0.0357 - val_rpn_bbox_loss: 0.3772 - val_mrcnn_class_loss: 0.3690 - val_mrcnn_bbox_loss: 0.5330 - val_mrcnn_mask_loss: 0.4811
# Epoch 34/50
# 100/100 [==============================] - 41s 414ms/step - loss: 1.7159 - rpn_class_loss: 0.0286 - rpn_bbox_loss: 0.3690 - mrcnn_class_loss: 0.3364 - mrcnn_bbox_loss: 0.5155 - mrcnn_mask_loss: 0.4663 - val_loss: 1.6910 - val_rpn_class_loss: 0.0265 - val_rpn_bbox_loss: 0.3751 - val_mrcnn_class_loss: 0.3246 - val_mrcnn_bbox_loss: 0.5115 - val_mrcnn_mask_loss: 0.4533
# Epoch 35/50
# 100/100 [==============================] - 38s 385ms/step - loss: 1.7273 - rpn_class_loss: 0.0267 - rpn_bbox_loss: 0.3944 - mrcnn_class_loss: 0.3215 - mrcnn_bbox_loss: 0.5228 - mrcnn_mask_loss: 0.4619 - val_loss: 1.7856 - val_rpn_class_loss: 0.0344 - val_rpn_bbox_loss: 0.4540 - val_mrcnn_class_loss: 0.2827 - val_mrcnn_bbox_loss: 0.5442 - val_mrcnn_mask_loss: 0.4703
# Epoch 36/50
# 100/100 [==============================] - 39s 392ms/step - loss: 1.7189 - rpn_class_loss: 0.0270 - rpn_bbox_loss: 0.3803 - mrcnn_class_loss: 0.3251 - mrcnn_bbox_loss: 0.5312 - mrcnn_mask_loss: 0.4553 - val_loss: 1.7089 - val_rpn_class_loss: 0.0261 - val_rpn_bbox_loss: 0.3676 - val_mrcnn_class_loss: 0.3356 - val_mrcnn_bbox_loss: 0.5433 - val_mrcnn_mask_loss: 0.4363
# Epoch 37/50
# 100/100 [==============================] - 40s 404ms/step - loss: 1.7075 - rpn_class_loss: 0.0274 - rpn_bbox_loss: 0.3802 - mrcnn_class_loss: 0.3088 - mrcnn_bbox_loss: 0.5304 - mrcnn_mask_loss: 0.4608 - val_loss: 1.6584 - val_rpn_class_loss: 0.0262 - val_rpn_bbox_loss: 0.3345 - val_mrcnn_class_loss: 0.3215 - val_mrcnn_bbox_loss: 0.5311 - val_mrcnn_mask_loss: 0.4451
# Epoch 38/50
# 100/100 [==============================] - 41s 408ms/step - loss: 1.6989 - rpn_class_loss: 0.0271 - rpn_bbox_loss: 0.3880 - mrcnn_class_loss: 0.3157 - mrcnn_bbox_loss: 0.5129 - mrcnn_mask_loss: 0.4551 - val_loss: 1.8349 - val_rpn_class_loss: 0.0326 - val_rpn_bbox_loss: 0.5319 - val_mrcnn_class_loss: 0.2728 - val_mrcnn_bbox_loss: 0.5373 - val_mrcnn_mask_loss: 0.4603
# Epoch 39/50
# 100/100 [==============================] - 39s 393ms/step - loss: 1.7161 - rpn_class_loss: 0.0273 - rpn_bbox_loss: 0.3829 - mrcnn_class_loss: 0.3314 - mrcnn_bbox_loss: 0.5171 - mrcnn_mask_loss: 0.4573 - val_loss: 1.8460 - val_rpn_class_loss: 0.0291 - val_rpn_bbox_loss: 0.5264 - val_mrcnn_class_loss: 0.2455 - val_mrcnn_bbox_loss: 0.5525 - val_mrcnn_mask_loss: 0.4925
# Epoch 40/50
# 100/100 [==============================] - 40s 402ms/step - loss: 1.7128 - rpn_class_loss: 0.0281 - rpn_bbox_loss: 0.3784 - mrcnn_class_loss: 0.3273 - mrcnn_bbox_loss: 0.5081 - mrcnn_mask_loss: 0.4707 - val_loss: 1.8218 - val_rpn_class_loss: 0.0299 - val_rpn_bbox_loss: 0.4535 - val_mrcnn_class_loss: 0.3515 - val_mrcnn_bbox_loss: 0.5435 - val_mrcnn_mask_loss: 0.4433
# Epoch 41/50
# 100/100 [==============================] - 40s 399ms/step - loss: 1.7074 - rpn_class_loss: 0.0236 - rpn_bbox_loss: 0.3756 - mrcnn_class_loss: 0.3240 - mrcnn_bbox_loss: 0.5182 - mrcnn_mask_loss: 0.4660 - val_loss: 1.7797 - val_rpn_class_loss: 0.0314 - val_rpn_bbox_loss: 0.4627 - val_mrcnn_class_loss: 0.3027 - val_mrcnn_bbox_loss: 0.5320 - val_mrcnn_mask_loss: 0.4508
# Epoch 42/50
# 100/100 [==============================] - 40s 404ms/step - loss: 1.6857 - rpn_class_loss: 0.0268 - rpn_bbox_loss: 0.3820 - mrcnn_class_loss: 0.3195 - mrcnn_bbox_loss: 0.5056 - mrcnn_mask_loss: 0.4519 - val_loss: 1.7555 - val_rpn_class_loss: 0.0301 - val_rpn_bbox_loss: 0.3575 - val_mrcnn_class_loss: 0.3506 - val_mrcnn_bbox_loss: 0.5450 - val_mrcnn_mask_loss: 0.4723
# Epoch 43/50
# 100/100 [==============================] - 39s 394ms/step - loss: 1.7130 - rpn_class_loss: 0.0256 - rpn_bbox_loss: 0.3894 - mrcnn_class_loss: 0.3199 - mrcnn_bbox_loss: 0.5169 - mrcnn_mask_loss: 0.4613 - val_loss: 1.6947 - val_rpn_class_loss: 0.0254 - val_rpn_bbox_loss: 0.3741 - val_mrcnn_class_loss: 0.3014 - val_mrcnn_bbox_loss: 0.5369 - val_mrcnn_mask_loss: 0.4569
# Epoch 44/50
# 100/100 [==============================] - 40s 399ms/step - loss: 1.7345 - rpn_class_loss: 0.0254 - rpn_bbox_loss: 0.3870 - mrcnn_class_loss: 0.3362 - mrcnn_bbox_loss: 0.5278 - mrcnn_mask_loss: 0.4581 - val_loss: 1.6216 - val_rpn_class_loss: 0.0238 - val_rpn_bbox_loss: 0.3435 - val_mrcnn_class_loss: 0.3129 - val_mrcnn_bbox_loss: 0.5040 - val_mrcnn_mask_loss: 0.4375
# Epoch 45/50
# 100/100 [==============================] - 39s 392ms/step - loss: 1.6616 - rpn_class_loss: 0.0267 - rpn_bbox_loss: 0.3651 - mrcnn_class_loss: 0.3253 - mrcnn_bbox_loss: 0.4970 - mrcnn_mask_loss: 0.4475 - val_loss: 1.7069 - val_rpn_class_loss: 0.0298 - val_rpn_bbox_loss: 0.3864 - val_mrcnn_class_loss: 0.3358 - val_mrcnn_bbox_loss: 0.5203 - val_mrcnn_mask_loss: 0.4345
# Epoch 46/50
# 100/100 [==============================] - 41s 413ms/step - loss: 1.7012 - rpn_class_loss: 0.0257 - rpn_bbox_loss: 0.3672 - mrcnn_class_loss: 0.3398 - mrcnn_bbox_loss: 0.5215 - mrcnn_mask_loss: 0.4469 - val_loss: 1.6160 - val_rpn_class_loss: 0.0253 - val_rpn_bbox_loss: 0.3422 - val_mrcnn_class_loss: 0.3164 - val_mrcnn_bbox_loss: 0.4979 - val_mrcnn_mask_loss: 0.4342
# Epoch 47/50
# 100/100 [==============================] - 38s 384ms/step - loss: 1.6933 - rpn_class_loss: 0.0261 - rpn_bbox_loss: 0.3531 - mrcnn_class_loss: 0.3301 - mrcnn_bbox_loss: 0.5233 - mrcnn_mask_loss: 0.4607 - val_loss: 1.7765 - val_rpn_class_loss: 0.0262 - val_rpn_bbox_loss: 0.3841 - val_mrcnn_class_loss: 0.3804 - val_mrcnn_bbox_loss: 0.5423 - val_mrcnn_mask_loss: 0.4435
# Epoch 48/50
# 100/100 [==============================] - 41s 409ms/step - loss: 1.7387 - rpn_class_loss: 0.0224 - rpn_bbox_loss: 0.4090 - mrcnn_class_loss: 0.3452 - mrcnn_bbox_loss: 0.5105 - mrcnn_mask_loss: 0.4516 - val_loss: 1.6344 - val_rpn_class_loss: 0.0229 - val_rpn_bbox_loss: 0.3564 - val_mrcnn_class_loss: 0.3313 - val_mrcnn_bbox_loss: 0.4936 - val_mrcnn_mask_loss: 0.4301
# Epoch 49/50
# 100/100 [==============================] - 40s 403ms/step - loss: 1.6246 - rpn_class_loss: 0.0215 - rpn_bbox_loss: 0.3619 - mrcnn_class_loss: 0.3167 - mrcnn_bbox_loss: 0.4828 - mrcnn_mask_loss: 0.4417 - val_loss: 1.8115 - val_rpn_class_loss: 0.0242 - val_rpn_bbox_loss: 0.5273 - val_mrcnn_class_loss: 0.3344 - val_mrcnn_bbox_loss: 0.4917 - val_mrcnn_mask_loss: 0.4339
# Epoch 50/50
# 100/100 [==============================] - 38s 382ms/step - loss: 1.6570 - rpn_class_loss: 0.0204 - rpn_bbox_loss: 0.3663 - mrcnn_class_loss: 0.3307 - mrcnn_bbox_loss: 0.4963 - mrcnn_mask_loss: 0.4434 - val_loss: 1.7030 - val_rpn_class_loss: 0.0231 - val_rpn_bbox_loss: 0.4071 - val_mrcnn_class_loss: 0.3268 - val_mrcnn_bbox_loss: 0.5073 - val_mrcnn_mask_loss: 0.4386

# %%
# select trained model 
dir_names = next(os.walk(model.model_dir))[1]
key = config.NAME.lower()
dir_names = filter(lambda f: f.startswith(key), dir_names)
dir_names = sorted(dir_names)

if not dir_names:
    import errno
    raise FileNotFoundError(
        errno.ENOENT,
        "Could not find model directory under {}".format(self.model_dir))
    
fps = []
# Pick last directory
for d in dir_names: 
    dir_name = os.path.join(model.model_dir, d)
    # Find the last checkpoint
    checkpoints = next(os.walk(dir_name))[2]
    checkpoints = filter(lambda f: f.startswith("mask_rcnn"), checkpoints)
    checkpoints = sorted(checkpoints)
    if not checkpoints:
        print('No weight files in {}'.format(dir_name))
    else: 
      
      checkpoint = os.path.join(dir_name, checkpoints[-1])
      fps.append(checkpoint)

model_path = sorted(fps)[-1]
print('Found model {}'.format(model_path))
# Out:
# No weight files in ../working/pneumonia20180915T1627
# No weight files in ../working/pneumonia20180915T1632
# No weight files in ../working/pneumonia20180915T1643
# No weight files in ../working/pneumonia20180915T1650
# No weight files in ../working/pneumonia20180915T1654
# Found model ../working/pneumonia20180915T1656/mask_rcnn_pneumonia_0050.h5

# %%
class InferenceConfig(DetectorConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode='inference', 
                          config=inference_config,
                          model_dir=ROOT_DIR)

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  ../working/pneumonia20180915T1656/mask_rcnn_pneumonia_0050.h5
# Re-starting from epoch 50

# %%
# set color for class
def get_colors_for_class_ids(class_ids):
    colors = []
    for class_id in class_ids:
        if class_id == 1:
            colors.append((.941, .204, .204))
    return colors

# %% [markdown]
# ### How does the predicted box compared to the expected value? Let's use the validation dataset to check.
#
# Note that we trained only one epoch for **demonstration purposes ONLY**. You might be able to improve performance running more epochs.

# %%
# Show few example of ground truth vs. predictions on the validation dataset 
dataset = dataset_val
fig = plt.figure(figsize=(10, 30))

for i in range(4):

    image_id = random.choice(dataset.image_ids)
    
    original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config, 
                               image_id, use_mini_mask=False)
    
    print(original_image.shape)
    plt.subplot(6, 2, 2*i + 1)
    visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                                dataset.class_names,
                                colors=get_colors_for_class_ids(gt_class_id), ax=fig.axes[-1])
    
    plt.subplot(6, 2, 2*i + 2)
    results = model.detect([original_image]) #, verbose=1)
    r = results[0]
    visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                                dataset.class_names, r['scores'], 
                                colors=get_colors_for_class_ids(r['class_ids']), ax=fig.axes[-1])
# Out:
# (512, 512, 3)
#
# *** No instances to display ***
#
# (512, 512, 3)
# (512, 512, 3)
#
# *** No instances to display ***
#
# (512, 512, 3)
#
# *** No instances to display ***

# %%
# Get filenames of test dataset DICOM images
test_image_fps = get_dicom_fps(test_dicom_dir)

# %% [markdown]
# ### Final steps - Create the submission file

# %%
# Make predictions on test images, write out sample submission 
def predict(image_fps, filepath='submission.csv', min_conf=0.95): 
    
    # assume square image
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    #resize_factor = ORIG_SIZE 
    with open(filepath, 'w') as file:
      for image_id in tqdm(image_fps): 
        ds = pydicom.read_file(image_id)
        image = ds.pixel_array
        # If grayscale. Convert to RGB for consistency.
        if len(image.shape) != 3 or image.shape[2] != 3:
            image = np.stack((image,) * 3, -1) 
        image, window, scale, padding, crop = utils.resize_image(
            image,
            min_dim=config.IMAGE_MIN_DIM,
            min_scale=config.IMAGE_MIN_SCALE,
            max_dim=config.IMAGE_MAX_DIM,
            mode=config.IMAGE_RESIZE_MODE)
            
        patient_id = os.path.splitext(os.path.basename(image_id))[0]

        results = model.detect([image])
        r = results[0]

        out_str = ""
        out_str += patient_id 
        out_str += ","
        assert( len(r['rois']) == len(r['class_ids']) == len(r['scores']) )
        if len(r['rois']) == 0: 
            pass
        else: 
            num_instances = len(r['rois'])
  
            for i in range(num_instances): 
                if r['scores'][i] > min_conf: 
                    out_str += ' '
                    out_str += str(round(r['scores'][i], 2))
                    out_str += ' '

                    # x1, y1, width, height 
                    x1 = r['rois'][i][1]
                    y1 = r['rois'][i][0]
                    width = r['rois'][i][3] - x1 
                    height = r['rois'][i][2] - y1 
                    bboxes_str = "{} {} {} {}".format(x1*resize_factor, y1*resize_factor, \
                                                       width*resize_factor, height*resize_factor)   
#                     bboxes_str = "{} {} {} {}".format(x1, y1, \
#                                                       width, height)
                    out_str += bboxes_str

        file.write(out_str+"\n")

# %%
# predict only the first 50 entries
submission_fp = os.path.join(ROOT_DIR, 'submission.csv')
print(submission_fp)
predict(test_image_fps, filepath=submission_fp)
# Out:
#   0%|          | 2/1000 [00:00<01:29, 11.20it/s]
# ../working/submission.csv
# 100%|██████████| 1000/1000 [01:26<00:00, 11.52it/s]

# %%
output = pd.read_csv(submission_fp, names=['patientId', 'PredictionString'])
output.head(100)
# Out:
#                                patientId  \
# 0   0fa93f8a-c813-4ff1-b44d-57cbe7f54d9a
# 1   0da8c767-77b7-4c69-98d4-2c5c91b9affc
# 2   2f1cc91c-e75f-4a24-8fea-2edf6e5171f7
# 3   2c575dd0-1a23-40d1-a0b6-da6d9c2556ae
# 4   2d519447-4bcf-42ad-bb28-cf051b649fff
# 5   23ca0450-4138-4e7a-9489-0f5b6a91031d
# 6   1dad3414-88c9-4c56-af5d-3a1488af452c
# 7   14b2868e-e0fc-40f2-a54e-609bf24da493
# 8   1e70a641-8faa-4436-a075-8193b3b541e1
# 9   2e4e8d73-c213-47f2-a4f4-cebe3a6b2467
# 10  c0654897-6bfe-4b7c-abd3-dda76d0fcac2
# 11  bfefcd13-122d-4c6f-8f4f-5c53417165db
# 12  21684515-f845-4d3e-acb0-13628edaa264
# 13  245d1104-6524-4d44-ace9-e54f0645a46e
# 14  147896bf-619c-4a0f-afc3-f0459340cbb1
# 15  03aeb73d-0520-48ad-b21a-8249dfcf95d8
# 16  c1628c47-5ba3-42dd-8df3-7ad3abd57ad0
# 17  214dcd68-4220-4010-8510-4c8eee830c70
# 18  0fd9d050-6ad7-4bd8-a18b-8e583192726f
# 19  1caa4dac-4bac-419b-91d4-cac2d8408ccd
# 20  25f20eb8-ca8b-4763-b213-8dcc63df4aed
# 21  1df724c0-ccf5-4299-9037-81b1470f115a
# 22  29e4656b-0648-470c-ace8-cef7398e0fc5
# 23  1f99edfe-6ad8-4781-9f7a-cf6c3f3123ff
# 24  045a317c-52dd-4528-ae30-5c6d53e039b1
# 25  14a42065-b678-4720-805e-7540d232df8c
# 26  000924cf-0f8d-42bd-9158-1af53881a557
# 27  219334b4-6696-4b41-90bd-0c56878ccbe6
# 28  2e9e3ac8-d85c-4d0a-92a0-14030dc21c66
# 29  0ea1d0f4-e828-487f-9f29-06e094018054
# ..                                   ...
# 70  0232c2b8-f7ac-4f42-84be-510ccb7cf351
# 71  00293de0-a530-41dc-9621-0b3def01d06d
# 72  c0608b6d-a375-4cda-8133-b5ec73217435
# 73  0ff5bf5b-6af7-4537-90d0-1c47058d0627
# 74  1c187dbf-3fa4-4a39-914a-39994b76d4c5
# 75  1a9c4cb9-c796-4174-9414-ca3d653b0d5c
# 76  1d9dde4e-97cc-4163-a3d5-8b845ad60ded
# 77  0e2abdaa-d654-4824-abaa-9d6fe5b67a95
# 78  28eaff00-5fb7-40ee-8206-9d2ff5b081e0
# 79  2e81e582-821a-4b3c-bd76-48a7d39e3f82
# 80  1a2dc891-713d-4253-ad19-a1e7910ee2eb
# 81  27775937-404e-4e1a-bef0-af5d63fc0b3b
# 82  149173ac-662a-4883-834d-43ff97a29b18
# 83  c068a37d-3fe7-4a26-bb74-575ea6be194d
# 84  30c7ba0d-6b34-4a40-a92e-493c756d924a
# 85  2eec752d-9977-4ea9-b73c-78e1d196d98d
# 86  1bed6235-89c8-4cfc-b4d2-36731836830d
# 87  1a42aa5f-54c6-4ada-b381-cdf65cfc69b1
# 88  12657240-8b00-4be5-994e-6bba758e168a
# 89  23997b8b-5726-4b2d-bd45-b15fc1c4c2af
# 90  100fb3d8-99c5-4723-9385-11b236f9aae4
# 91  2e303b9f-1a06-4553-afce-3561db6420f3
# 92  1d80b0ab-2dfe-4d28-bb01-e0b60a3ce972
# 93  0297e501-88b5-4ec0-a2fd-50a7c70b42eb
# 94  1c2633c2-6fba-4a94-84e7-648ea251f1b0
# 95  26346765-2787-412c-be8f-6914ac16259e
# 96  285e0dd4-4f19-47ab-9ce0-6b02c1396f29
# 97  2b55eeed-3408-46fd-9e18-d7c5295a92b2
# 98  05b22cd6-c876-4360-8361-92845c6de8ba
# 99  0f65daf5-08f1-439a-8a50-2e64f1a8a5ac
#
#                                      PredictionString
# 0    0.98 144.0 480.0 274.0 322.0 0.97 622.0 470.0...
# 1                                                 NaN
# 2                                                 NaN
# 3                        0.97 176.0 182.0 254.0 390.0
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                        0.97 176.0 440.0 228.0 268.0
# 10                       0.95 114.0 486.0 266.0 342.0
# 11                                                NaN
# 12                       0.96 160.0 512.0 224.0 234.0
# 13                                                NaN
# 14                                                NaN
# 15   0.97 572.0 428.0 246.0 236.0 0.96 202.0 358.0...
# 16   0.98 164.0 444.0 246.0 242.0 0.97 600.0 250.0...
# 17                                                NaN
# 18                       0.95 282.0 322.0 216.0 338.0
# 19                       0.95 284.0 346.0 206.0 408.0
# 20                                                NaN
# 21                       0.95 594.0 464.0 296.0 292.0
# 22   0.97 228.0 408.0 220.0 158.0 0.96 594.0 386.0...
# 23                       0.97 578.0 516.0 274.0 274.0
# 24                       0.96 594.0 614.0 280.0 300.0
# 25                                                NaN
# 26                                                NaN
# 27   0.96 546.0 100.0 232.0 374.0 0.95 218.0 116.0...
# 28                                                NaN
# 29                                                NaN
# ..                                                ...
# 70                                                NaN
# 71                       0.97 138.0 550.0 276.0 224.0
# 72                       0.96 610.0 454.0 258.0 354.0
# 73                                                NaN
# 74                                                NaN
# 75   0.99 618.0 570.0 210.0 346.0 0.98 228.0 616.0...
# 76                                                NaN
# 77                                                NaN
# 78                       0.96 198.0 574.0 224.0 180.0
# 79   0.96 654.0 446.0 218.0 284.0 0.96 194.0 384.0...
# 80                       0.97 236.0 642.0 218.0 156.0
# 81                                                NaN
# 82                                                NaN
# 83                       0.96 256.0 374.0 206.0 272.0
# 84                                                NaN
# 85                                                NaN
# 86                                                NaN
# 87                       0.96 138.0 292.0 296.0 248.0
# 88   0.99 264.0 494.0 248.0 288.0 0.95 628.0 568.0...
# 89                       0.96 182.0 640.0 220.0 146.0
# 90                                                NaN
# 91                       0.95 550.0 444.0 286.0 270.0
# 92                                                NaN
# 93                                                NaN
# 94                                                NaN
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                       0.96 122.0 402.0 246.0 256.0
# 99                       0.98 624.0 448.0 224.0 354.0
#
# [100 rows x 2 columns]

# %%
## show submission.csv content
#os.chdir(ROOT_DIR)
#!cat submission.csv

# %%
# show a few test image detection example
def visualize(): 
    image_id = random.choice(test_image_fps)
    ds = pydicom.read_file(image_id)
    
    # original image 
    image = ds.pixel_array
    
    # assume square image 
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    
    # If grayscale. Convert to RGB for consistency.
    if len(image.shape) != 3 or image.shape[2] != 3:
        image = np.stack((image,) * 3, -1) 
    resized_image, window, scale, padding, crop = utils.resize_image(
        image,
        min_dim=config.IMAGE_MIN_DIM,
        min_scale=config.IMAGE_MIN_SCALE,
        max_dim=config.IMAGE_MAX_DIM,
        mode=config.IMAGE_RESIZE_MODE)

    patient_id = os.path.splitext(os.path.basename(image_id))[0]
    print(patient_id)

    results = model.detect([resized_image])
    r = results[0]
    for bbox in r['rois']: 
        print(bbox)
        x1 = int(bbox[1] * resize_factor)
        y1 = int(bbox[0] * resize_factor)
        x2 = int(bbox[3] * resize_factor)
        y2 = int(bbox[2]  * resize_factor)
        cv2.rectangle(image, (x1,y1), (x2,y2), (77, 255, 9), 3, 1)
        width = x2 - x1 
        height = y2 - y1 
        print("x {} y {} h {} w {}".format(x1, y1, width, height))
    plt.figure() 
    plt.imshow(image, cmap=plt.cm.gist_gray)

visualize()
# Out:
# 0d15858e-bd96-42cf-843e-57ff0c6e42a7
# [213  98 336 228]
# x 196 y 426 h 260 w 246

# %%
# remove files to allow committing (hit files limit otherwise)
#!rm -rf /kaggle/working/Mask_RCNN
