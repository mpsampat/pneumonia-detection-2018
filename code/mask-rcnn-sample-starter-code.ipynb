# %% [markdown]
# **Mask-RCNN Sample Starter Model for the RSNA Pneumonia Detection Challenge**
#
# [MD.ai](https://www.md.ai). The dataset for this challenge, created on the MD.ai platform in collaboration with the Radiological Society of North America (RSNA), the Society of Thoracic Radiology (STR), the US National Institutes of Health (NIH), and Kaggle.
# This notebook covers the basics of parsing the competition dataset, training using a detector basd on the [Mask-RCNN algorithm](https://arxiv.org/abs/1703.06870) for object detection and instance segmentation.
# **Note that the Mask-RCNN detector configuration parameters have been selected to reduce training time for demonstration purposes, they are not optimal.
# **
#
# This is based on our deep learning for medical imaging lessons:
#
# - Lesson 1. Classification of chest vs. adominal X-rays using TensorFlow/Keras [Github](https://github.com/mdai/ml-lessons/blob/master/lesson1-xray-images-classification.ipynb) [Annotator](https://public.md.ai/annotator/project/PVq9raBJ)
# - Lesson 2. Lung X-Rays Semantic Segmentation using UNets. [Github](https://github.com/mdai/ml-lessons/blob/master/lesson2-lung-xrays-segmentation.ipynb)
# [Annotator](https://public.md.ai/annotator/project/aGq4k6NW/workspace)
# - Lesson 3. RSNA Pneumonia detection using Kaggle data format [Github](https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-kaggle.ipynb) [Annotator](https://public.md.ai/annotator/project/LxR6zdR2/workspace)
# - Lesson 3. RSNA Pneumonia detection using MD.ai python client library [Github](https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-mdai-client-lib.ipynb) [Annotator](https://public.md.ai/annotator/project/LxR6zdR2/workspace)
#
# *Copyright 2018 MD.ai, Inc.
# Licensed under the Apache License, Version 2.0*

# %%
import os 
import sys
import random
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt
import json
import pydicom
from imgaug import augmenters as iaa
from tqdm import tqdm
import pandas as pd 
import glob

# %% [markdown]
# ### First: Install Kaggle API for download competition data.

# %%
DATA_DIR = '../input'

# Directory to save logs and trained model
ROOT_DIR = '../working'

# %% [markdown]
# ###  MD.ai Annotator
#
# Additionally, If you are interested in augmenting the existing annotations, you can use the MD.ai annotator to view DICOM images, and create annotatios to be exported.
# MD.ai annotator project URL for the Kaggle dataset: https://public.md.ai/annotator/project/LxR6zdR2/workspace
#
# **Annotator features**
# - The annotator can be used to view DICOM images and create image and exam level annotations.
# - You can apply the annotator to filter by label, adjudicate annotations, and assign annotation tasks to your team.
# - Notebooks can be built directly within the annotator for rapid model development.
# - The data wrangling is abstracted away by the interface and by our MD.ai library.
# - Simplifies image annotation in order to widen the participation in the futrue of medical image deep learning.
#
# The annotator allows you to create initial annotations, build and run models, modify/finetune the annotations based on predicted values, and repeat.
# The MD.ai python client library implements functions to easily download images and annotations and to prepare the datasets used to train the model for classification. See the following example notebook for parsing annotations and training using MD.ai annotator:
# https://github.com/mdai/ml-lessons/blob/master/lesson3-rsna-pneumonia-detection-mdai-client-lib.ipynb
# - MD.ai URL: https://www.md.ai
# - MD.ai documentation URL: https://docs.md.ai/

# %% [markdown]
# ### Install Matterport's Mask-RCNN model from github.
# See the [Matterport's implementation of Mask-RCNN](https://github.com/matterport/Mask_RCNN).

# %%
#!git clone https://www.github.com/matterport/Mask_RCNN.git
#os.chdir('Mask_RCNN')
#!python setup.py -q install

# %%
# Import Mask RCNN
sys.path.append(os.path.join("/home/mehul/kaggle/pneumonia-detection-2018", 'Mask_RCNN'))  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
from mrcnn.model import log
# Out:
# Using TensorFlow backend.

# %%
train_dicom_dir = os.path.join(DATA_DIR, 'stage_1_train_images')
test_dicom_dir = os.path.join(DATA_DIR, 'stage_1_test_images')

# %% [markdown]
# ### Some setup functions and classes for Mask-RCNN
#
# - dicom_fps is a list of the dicom image path and filenames
# - image_annotions is a dictionary of the annotations keyed by the filenames
# - parsing the dataset returns a list of the image filenames and the annotations dictionary

# %%
def get_dicom_fps(dicom_dir):
    dicom_fps = glob.glob(dicom_dir+'/'+'*.dcm')
    return list(set(dicom_fps))

def parse_dataset(dicom_dir, anns): 
    image_fps = get_dicom_fps(dicom_dir)
    image_annotations = {fp: [] for fp in image_fps}
    for index, row in anns.iterrows(): 
        fp = os.path.join(dicom_dir, row['patientId']+'.dcm')
        image_annotations[fp].append(row)
    return image_fps, image_annotations

# %%
# The following parameters have been selected to reduce running time for demonstration purposes 
# These are not optimal 

class DetectorConfig(Config):
    """Configuration for training pneumonia detection on the RSNA pneumonia dataset.
    Overrides values in the base Config class.
    """
    
    # Give the configuration a recognizable name  
    NAME = 'pneumonia'
    
    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 2 
    
    BACKBONE = 'resnet50'
    
    NUM_CLASSES = 2  # background + 1 pneumonia classes
    
    IMAGE_MIN_DIM = 512
    IMAGE_MAX_DIM = 512
    RPN_ANCHOR_SCALES = (16, 32, 64, 128,256)
    TRAIN_ROIS_PER_IMAGE = 32
    MAX_GT_INSTANCES = 3
    DETECTION_MAX_INSTANCES = 3
    DETECTION_MIN_CONFIDENCE = 0.4
    DETECTION_NMS_THRESHOLD = 0.1
    TRAIN_BN = 1
    STEPS_PER_EPOCH = 320
    # Image mean (RGB)
    MEAN_PIXEL = np.array([0.0,0.0,0.0])    
    # Weight decay regularization
    WEIGHT_DECAY = 0.0001
    # How many anchors per image to use for RPN training
    RPN_TRAIN_ANCHORS_PER_IMAGE = 64 #300
    # ROIs kept after non-maximum supression (training and inference)
    POST_NMS_ROIS_TRAINING = 2000
    POST_NMS_ROIS_INFERENCE = 2000
    RPN_NMS_THRESHOLD = 0.9
    MAX_GT_INSTANCES = 10
    DETECTION_MAX_INSTANCES = 5 
config = DetectorConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     2
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        5
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.1
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 2
# IMAGE_MAX_DIM                  512
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [512 512   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               10
# MEAN_PIXEL                     [0. 0. 0.]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           pneumonia
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        2000
# POST_NMS_ROIS_TRAINING         2000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (16, 32, 64, 128, 256)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.9
# RPN_TRAIN_ANCHORS_PER_IMAGE    64
# STEPS_PER_EPOCH                320
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       1
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
class DetectorDataset(utils.Dataset):
    """Dataset class for training pneumonia detection on the RSNA pneumonia dataset.
    """

    def __init__(self, image_fps, image_annotations, orig_height, orig_width):
        super().__init__(self)
        
        # Add classes
        self.add_class('pneumonia', 1, 'Lung Opacity')
   
        # add images 
        for i, fp in enumerate(image_fps):
            annotations = image_annotations[fp]
            self.add_image('pneumonia', image_id=i, path=fp, 
                           annotations=annotations, orig_height=orig_height, orig_width=orig_width)
            
    def image_reference(self, image_id):
        info = self.image_info[image_id]
        return info['path']

    def load_image(self, image_id):
        info = self.image_info[image_id]
        fp = info['path']
        ds = pydicom.read_file(fp)
        image = ds.pixel_array
        image = (image - np.mean(image))/np.std(image)
        # If grayscale. Convert to RGB for consistency.
        if len(image.shape) != 3 or image.shape[2] != 3:
            image = np.stack((image,) * 3, -1)
        return image

    def load_mask(self, image_id):
        info = self.image_info[image_id]
        annotations = info['annotations']
        count = len(annotations)
        if count == 0:
            mask = np.zeros((info['orig_height'], info['orig_width'], 1), dtype=np.uint8)
            class_ids = np.zeros((1,), dtype=np.int32)
        else:
            mask = np.zeros((info['orig_height'], info['orig_width'], count), dtype=np.uint8)
            class_ids = np.zeros((count,), dtype=np.int32)
            for i, a in enumerate(annotations):
                if a['Target'] == 1:
                    x = int(a['x'])
                    y = int(a['y'])
                    w = int(a['width'])
                    h = int(a['height'])
                    mask_instance = mask[:, :, i].copy()
                    cv2.rectangle(mask_instance, (x, y), (x+w, y+h), 255, -1)
                    mask[:, :, i] = mask_instance
                    class_ids[i] = 1
        return mask.astype(np.bool), class_ids.astype(np.int32)

# %% [markdown]
# ### Examine the annotation data, parse the dataset, and view dicom fields

# %%
# training dataset
anns = pd.read_csv(os.path.join(DATA_DIR, 'stage_1_train_labels.csv'))
anns.head()
# Out:
#                               patientId      x      y  width  height  Target
# 0  0004cfab-14fd-4e49-80ba-63a80b6bddd6    NaN    NaN    NaN     NaN       0
# 1  00313ee0-9eaa-42f4-b0ab-c148ed3241cd    NaN    NaN    NaN     NaN       0
# 2  00322d4d-1c29-4943-afc9-b6754be640eb    NaN    NaN    NaN     NaN       0
# 3  003d8fa0-6bf1-40ed-b54c-ac657f8495c5    NaN    NaN    NaN     NaN       0
# 4  00436515-870c-4b36-a041-de91049b9ab4  264.0  152.0  213.0   379.0       1

# %%
image_fps, image_annotations = parse_dataset(train_dicom_dir, anns=anns)

# %%
ds = pydicom.read_file(image_fps[0]) # read dicom image from filepath 
image = ds.pixel_array # get image array

# %%
# show dicom fields 
ds
# Out:
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0016) SOP Class UID                       UI: Secondary Capture Image Storage
# (0008, 0018) SOP Instance UID                    UI: 1.2.276.0.7230010.3.1.4.8323329.4011.1517874305.405903
# (0008, 0020) Study Date                          DA: '19010101'
# (0008, 0030) Study Time                          TM: '000000.00'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'CR'
# (0008, 0064) Conversion Type                     CS: 'WSD'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 103e) Series Description                  LO: 'view: AP'
# (0010, 0010) Patient's Name                      PN: 'b35dfbda-395c-4c9d-befb-331f6ac3da84'
# (0010, 0020) Patient ID                          LO: 'b35dfbda-395c-4c9d-befb-331f6ac3da84'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0010, 1010) Patient's Age                       AS: '69'
# (0018, 0015) Body Part Examined                  CS: 'CHEST'
# (0018, 5101) View Position                       CS: 'AP'
# (0020, 000d) Study Instance UID                  UI: 1.2.276.0.7230010.3.1.2.8323329.4011.1517874305.405902
# (0020, 000e) Series Instance UID                 UI: 1.2.276.0.7230010.3.1.3.8323329.4011.1517874305.405901
# (0020, 0010) Study ID                            SH: ''
# (0020, 0011) Series Number                       IS: '1'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0020) Patient Orientation                 CS: ''
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 1024
# (0028, 0011) Columns                             US: 1024
# (0028, 0030) Pixel Spacing                       DS: ['0.168', '0.168']
# (0028, 0100) Bits Allocated                      US: 8
# (0028, 0101) Bits Stored                         US: 8
# (0028, 0102) High Bit                            US: 7
# (0028, 0103) Pixel Representation                US: 0
# (0028, 2110) Lossy Image Compression             CS: '01'
# (0028, 2114) Lossy Image Compression Method      CS: 'ISO_10918_1'
# (7fe0, 0010) Pixel Data                          OB: Array of 95048 bytes

# %%
# Original DICOM image size: 1024 x 1024
ORIG_SIZE = 1024

# %% [markdown]
# ### Split the data into training and validation datasets
# **Note: We have only used only a portion of the images for demonstration purposes. See comments below.**
#
#  - To use all the images do: image_fps_list = list(image_fps)
#  - Or change the number of images from 100 to a custom number

# %%
######################################################################
# Modify this line to use more or fewer images for training/validation. 
# To use all images, do: image_fps_list = list(image_fps)
image_fps_list = list(image_fps) 
#####################################################################

# split dataset into training vs. validation dataset 
# split ratio is set to 0.9 vs. 0.1 (train vs. validation, respectively)
sorted(image_fps_list)
random.seed(42)
random.shuffle(image_fps_list)

validation_split = 0.1
split_index = int((1 - validation_split) * len(image_fps_list))

image_fps_train = image_fps_list[:split_index]
image_fps_val = image_fps_list[split_index:]

print(len(image_fps_train), len(image_fps_val))
# Out:
# 23115 2569

# %% [markdown]
# ### Create and prepare the training dataset using the DetectorDataset class.

# %%
# prepare the training dataset
dataset_train = DetectorDataset(image_fps_train, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_train.prepare()

# %% [markdown]
# ### Let's look at a sample annotation. We see a bounding box with (x, y) of the the top left corner as well as the width and height.

# %%
# Show annotation(s) for a DICOM image 
test_fp = random.choice(image_fps_train)
image_annotations[test_fp]
# Out:
# [patientId    6067a125-b3e5-4723-bc09-0d502ade3894
#  x                                             NaN
#  y                                             NaN
#  width                                         NaN
#  height                                        NaN
#  Target                                          0
#  Name: 8565, dtype: object]

# %%
# prepare the validation dataset
dataset_val = DetectorDataset(image_fps_val, image_annotations, ORIG_SIZE, ORIG_SIZE)
dataset_val.prepare()

# %% [markdown]
# ### Display a random image with bounding boxes

# %%
# Load and display random samples and their bounding boxes
# Suggestion: Run this a few times to see different examples. 

image_id = random.choice(dataset_train.image_ids)
image_fp = dataset_train.image_reference(image_id)
image = dataset_train.load_image(image_id)
mask, class_ids = dataset_train.load_mask(image_id)

print(image.shape)

plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(image[:, :, 0], cmap='gray')
plt.axis('off')

plt.subplot(1, 2, 2)
masked = np.zeros(image.shape[:2])
for i in range(mask.shape[2]):
    masked += image[:, :, 0] * mask[:, :, i]
plt.imshow(masked, cmap='gray')
plt.axis('off')

print(image_fp)
print(class_ids)
# Out:
# (1024, 1024, 3)
# ../input/stage_1_train_images/3ae1c3de-e2a7-44f5-b794-b1ef71640d0f.dcm
# [1]

# %%
model = modellib.MaskRCNN(mode='training', config=config, model_dir=ROOT_DIR)

# %% [markdown]
# ### Image Augmentation. Try finetuning some variables to custom values

# %%
# Image augmentation 
augmentation = iaa.SomeOf((0, 2), [
    iaa.Affine(
        scale={"x": (0.95, 1.05), "y": (0.95, 1.05)},
        translate_percent={"x": (-0.05, 0.05), "y": (-0.05, 0.05)},
        rotate=(-5, 5),
        shear=(-2, 2)
    ),
    iaa.Multiply((0.9, 1.1))
])

# %% [markdown]
# ### Now it's time to train the model. Note that training even a basic model can take a few hours.
#
# Note: the following model is for demonstration purpose only. We have limited the training to one epoch, and have set nominal values for the Detector Configuration to reduce run-time.
#
# - dataset_train and dataset_val are derived from DetectorDataset
# - DetectorDataset loads images from image filenames and  masks from the annotation data
# - model is Mask-RCNN

# %%
NUM_EPOCHS = 50

# Train Mask-RCNN Model 
import warnings 
warnings.filterwarnings("ignore")
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=NUM_EPOCHS, 
            layers='all',
            augmentation=augmentation)
# Out:
# WARNING:tensorflow:From /home/mehul/miniconda3/envs/tf7/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
#
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: ../working/pneumonia20180915T2037/mask_rcnn_pneumonia_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/50
# 320/320 [==============================] - 160s 498ms/step - loss: 2.6019 - rpn_class_loss: 0.4382 - rpn_bbox_loss: 0.7725 - mrcnn_class_loss: 0.2835 - mrcnn_bbox_loss: 0.7433 - mrcnn_mask_loss: 0.3644 - val_loss: 2.6691 - val_rpn_class_loss: 0.1469 - val_rpn_bbox_loss: 0.6281 - val_mrcnn_class_loss: 0.2581 - val_mrcnn_bbox_loss: 1.0308 - val_mrcnn_mask_loss: 0.6051
# Epoch 2/50
# 320/320 [==============================] - 117s 367ms/step - loss: 2.5785 - rpn_class_loss: 0.1007 - rpn_bbox_loss: 0.6913 - mrcnn_class_loss: 0.3091 - mrcnn_bbox_loss: 0.8351 - mrcnn_mask_loss: 0.6424 - val_loss: 2.5108 - val_rpn_class_loss: 0.0782 - val_rpn_bbox_loss: 0.6551 - val_mrcnn_class_loss: 0.3694 - val_mrcnn_bbox_loss: 0.7593 - val_mrcnn_mask_loss: 0.6489
# Epoch 3/50
# 320/320 [==============================] - 131s 409ms/step - loss: 2.5720 - rpn_class_loss: 0.0685 - rpn_bbox_loss: 0.6988 - mrcnn_class_loss: 0.4192 - mrcnn_bbox_loss: 0.7334 - mrcnn_mask_loss: 0.6521 - val_loss: 2.6249 - val_rpn_class_loss: 0.0659 - val_rpn_bbox_loss: 0.7481 - val_mrcnn_class_loss: 0.4199 - val_mrcnn_bbox_loss: 0.7472 - val_mrcnn_mask_loss: 0.6438
# Epoch 4/50
# 320/320 [==============================] - 127s 396ms/step - loss: 2.5846 - rpn_class_loss: 0.0579 - rpn_bbox_loss: 0.7279 - mrcnn_class_loss: 0.4164 - mrcnn_bbox_loss: 0.7353 - mrcnn_mask_loss: 0.6470 - val_loss: 2.5162 - val_rpn_class_loss: 0.0548 - val_rpn_bbox_loss: 0.7158 - val_mrcnn_class_loss: 0.4100 - val_mrcnn_bbox_loss: 0.6968 - val_mrcnn_mask_loss: 0.6388
# Epoch 5/50
# 320/320 [==============================] - 139s 433ms/step - loss: 2.5167 - rpn_class_loss: 0.0522 - rpn_bbox_loss: 0.7227 - mrcnn_class_loss: 0.3989 - mrcnn_bbox_loss: 0.7008 - mrcnn_mask_loss: 0.6420 - val_loss: 2.4470 - val_rpn_class_loss: 0.0520 - val_rpn_bbox_loss: 0.6943 - val_mrcnn_class_loss: 0.3946 - val_mrcnn_bbox_loss: 0.6729 - val_mrcnn_mask_loss: 0.6332
# Epoch 6/50
# 320/320 [==============================] - 131s 411ms/step - loss: 2.4660 - rpn_class_loss: 0.0450 - rpn_bbox_loss: 0.7205 - mrcnn_class_loss: 0.3769 - mrcnn_bbox_loss: 0.6875 - mrcnn_mask_loss: 0.6360 - val_loss: 2.4223 - val_rpn_class_loss: 0.0525 - val_rpn_bbox_loss: 0.6791 - val_mrcnn_class_loss: 0.3948 - val_mrcnn_bbox_loss: 0.6680 - val_mrcnn_mask_loss: 0.6278
# Epoch 7/50
# 320/320 [==============================] - 129s 404ms/step - loss: 2.4472 - rpn_class_loss: 0.0468 - rpn_bbox_loss: 0.7505 - mrcnn_class_loss: 0.3558 - mrcnn_bbox_loss: 0.6649 - mrcnn_mask_loss: 0.6291 - val_loss: 2.5243 - val_rpn_class_loss: 0.0540 - val_rpn_bbox_loss: 0.8111 - val_mrcnn_class_loss: 0.3670 - val_mrcnn_bbox_loss: 0.6717 - val_mrcnn_mask_loss: 0.6205
# Epoch 8/50
# 320/320 [==============================] - 135s 421ms/step - loss: 2.4073 - rpn_class_loss: 0.0470 - rpn_bbox_loss: 0.7224 - mrcnn_class_loss: 0.3550 - mrcnn_bbox_loss: 0.6578 - mrcnn_mask_loss: 0.6250 - val_loss: 2.3637 - val_rpn_class_loss: 0.0470 - val_rpn_bbox_loss: 0.7080 - val_mrcnn_class_loss: 0.3433 - val_mrcnn_bbox_loss: 0.6517 - val_mrcnn_mask_loss: 0.6136
# Epoch 9/50
# 320/320 [==============================] - 127s 396ms/step - loss: 2.3752 - rpn_class_loss: 0.0438 - rpn_bbox_loss: 0.7220 - mrcnn_class_loss: 0.3366 - mrcnn_bbox_loss: 0.6546 - mrcnn_mask_loss: 0.6181 - val_loss: 2.2651 - val_rpn_class_loss: 0.0419 - val_rpn_bbox_loss: 0.6589 - val_mrcnn_class_loss: 0.3371 - val_mrcnn_bbox_loss: 0.6260 - val_mrcnn_mask_loss: 0.6013
# Epoch 10/50
# 320/320 [==============================] - 130s 406ms/step - loss: 2.3790 - rpn_class_loss: 0.0414 - rpn_bbox_loss: 0.7441 - mrcnn_class_loss: 0.3433 - mrcnn_bbox_loss: 0.6347 - mrcnn_mask_loss: 0.6154 - val_loss: 2.3871 - val_rpn_class_loss: 0.0436 - val_rpn_bbox_loss: 0.8055 - val_mrcnn_class_loss: 0.3141 - val_mrcnn_bbox_loss: 0.6172 - val_mrcnn_mask_loss: 0.6067
# Epoch 11/50
# 320/320 [==============================] - 129s 402ms/step - loss: 2.3812 - rpn_class_loss: 0.0441 - rpn_bbox_loss: 0.7713 - mrcnn_class_loss: 0.3105 - mrcnn_bbox_loss: 0.6414 - mrcnn_mask_loss: 0.6139 - val_loss: 2.2935 - val_rpn_class_loss: 0.0377 - val_rpn_bbox_loss: 0.6730 - val_mrcnn_class_loss: 0.3544 - val_mrcnn_bbox_loss: 0.6342 - val_mrcnn_mask_loss: 0.5942
# Epoch 12/50
# 320/320 [==============================] - 130s 407ms/step - loss: 2.3115 - rpn_class_loss: 0.0407 - rpn_bbox_loss: 0.7333 - mrcnn_class_loss: 0.3262 - mrcnn_bbox_loss: 0.6033 - mrcnn_mask_loss: 0.6080 - val_loss: 2.3695 - val_rpn_class_loss: 0.0433 - val_rpn_bbox_loss: 0.7900 - val_mrcnn_class_loss: 0.3090 - val_mrcnn_bbox_loss: 0.6224 - val_mrcnn_mask_loss: 0.6049
# Epoch 13/50
# 320/320 [==============================] - 128s 400ms/step - loss: 2.2423 - rpn_class_loss: 0.0397 - rpn_bbox_loss: 0.6895 - mrcnn_class_loss: 0.3080 - mrcnn_bbox_loss: 0.6041 - mrcnn_mask_loss: 0.6010 - val_loss: 2.2135 - val_rpn_class_loss: 0.0451 - val_rpn_bbox_loss: 0.6918 - val_mrcnn_class_loss: 0.2897 - val_mrcnn_bbox_loss: 0.6029 - val_mrcnn_mask_loss: 0.5841
# Epoch 14/50
# 320/320 [==============================] - 136s 425ms/step - loss: 2.2380 - rpn_class_loss: 0.0373 - rpn_bbox_loss: 0.6845 - mrcnn_class_loss: 0.3170 - mrcnn_bbox_loss: 0.6027 - mrcnn_mask_loss: 0.5965 - val_loss: 2.1498 - val_rpn_class_loss: 0.0329 - val_rpn_bbox_loss: 0.6373 - val_mrcnn_class_loss: 0.3243 - val_mrcnn_bbox_loss: 0.5741 - val_mrcnn_mask_loss: 0.5812
# Epoch 15/50
# 320/320 [==============================] - 142s 444ms/step - loss: 2.1857 - rpn_class_loss: 0.0392 - rpn_bbox_loss: 0.6464 - mrcnn_class_loss: 0.3149 - mrcnn_bbox_loss: 0.5940 - mrcnn_mask_loss: 0.5912 - val_loss: 2.1779 - val_rpn_class_loss: 0.0373 - val_rpn_bbox_loss: 0.6671 - val_mrcnn_class_loss: 0.3116 - val_mrcnn_bbox_loss: 0.5879 - val_mrcnn_mask_loss: 0.5740
# Epoch 16/50
# 320/320 [==============================] - 132s 413ms/step - loss: 2.1633 - rpn_class_loss: 0.0385 - rpn_bbox_loss: 0.6434 - mrcnn_class_loss: 0.3176 - mrcnn_bbox_loss: 0.5840 - mrcnn_mask_loss: 0.5798 - val_loss: 2.1511 - val_rpn_class_loss: 0.0417 - val_rpn_bbox_loss: 0.6611 - val_mrcnn_class_loss: 0.2991 - val_mrcnn_bbox_loss: 0.5687 - val_mrcnn_mask_loss: 0.5805
# Epoch 17/50
# 320/320 [==============================] - 135s 421ms/step - loss: 2.1346 - rpn_class_loss: 0.0390 - rpn_bbox_loss: 0.6307 - mrcnn_class_loss: 0.3064 - mrcnn_bbox_loss: 0.5827 - mrcnn_mask_loss: 0.5758 - val_loss: 2.0583 - val_rpn_class_loss: 0.0376 - val_rpn_bbox_loss: 0.5697 - val_mrcnn_class_loss: 0.3089 - val_mrcnn_bbox_loss: 0.5774 - val_mrcnn_mask_loss: 0.5647
# Epoch 18/50
# 320/320 [==============================] - 129s 404ms/step - loss: 2.1088 - rpn_class_loss: 0.0372 - rpn_bbox_loss: 0.6318 - mrcnn_class_loss: 0.2905 - mrcnn_bbox_loss: 0.5771 - mrcnn_mask_loss: 0.5721 - val_loss: 2.1792 - val_rpn_class_loss: 0.0375 - val_rpn_bbox_loss: 0.7288 - val_mrcnn_class_loss: 0.2723 - val_mrcnn_bbox_loss: 0.5731 - val_mrcnn_mask_loss: 0.5675
# Epoch 19/50
# 320/320 [==============================] - 128s 402ms/step - loss: 2.1181 - rpn_class_loss: 0.0370 - rpn_bbox_loss: 0.6428 - mrcnn_class_loss: 0.2958 - mrcnn_bbox_loss: 0.5745 - mrcnn_mask_loss: 0.5680 - val_loss: 2.0380 - val_rpn_class_loss: 0.0364 - val_rpn_bbox_loss: 0.5822 - val_mrcnn_class_loss: 0.2945 - val_mrcnn_bbox_loss: 0.5702 - val_mrcnn_mask_loss: 0.5548
# Epoch 20/50
# 320/320 [==============================] - 129s 404ms/step - loss: 2.0510 - rpn_class_loss: 0.0342 - rpn_bbox_loss: 0.6036 - mrcnn_class_loss: 0.2943 - mrcnn_bbox_loss: 0.5590 - mrcnn_mask_loss: 0.5598 - val_loss: 2.0959 - val_rpn_class_loss: 0.0334 - val_rpn_bbox_loss: 0.6548 - val_mrcnn_class_loss: 0.2756 - val_mrcnn_bbox_loss: 0.5595 - val_mrcnn_mask_loss: 0.5726
# Epoch 21/50
# 320/320 [==============================] - 130s 406ms/step - loss: 2.1017 - rpn_class_loss: 0.0346 - rpn_bbox_loss: 0.6268 - mrcnn_class_loss: 0.3002 - mrcnn_bbox_loss: 0.5705 - mrcnn_mask_loss: 0.5695 - val_loss: 2.0320 - val_rpn_class_loss: 0.0315 - val_rpn_bbox_loss: 0.6194 - val_mrcnn_class_loss: 0.3077 - val_mrcnn_bbox_loss: 0.5500 - val_mrcnn_mask_loss: 0.5233
# Epoch 22/50
# 320/320 [==============================] - 136s 426ms/step - loss: 2.0433 - rpn_class_loss: 0.0330 - rpn_bbox_loss: 0.6090 - mrcnn_class_loss: 0.2883 - mrcnn_bbox_loss: 0.5615 - mrcnn_mask_loss: 0.5515 - val_loss: 2.0464 - val_rpn_class_loss: 0.0340 - val_rpn_bbox_loss: 0.6572 - val_mrcnn_class_loss: 0.2745 - val_mrcnn_bbox_loss: 0.5394 - val_mrcnn_mask_loss: 0.5413
# Epoch 23/50
# 320/320 [==============================] - 130s 407ms/step - loss: 1.9873 - rpn_class_loss: 0.0342 - rpn_bbox_loss: 0.5607 - mrcnn_class_loss: 0.2987 - mrcnn_bbox_loss: 0.5445 - mrcnn_mask_loss: 0.5493 - val_loss: 1.9130 - val_rpn_class_loss: 0.0327 - val_rpn_bbox_loss: 0.5991 - val_mrcnn_class_loss: 0.2600 - val_mrcnn_bbox_loss: 0.4903 - val_mrcnn_mask_loss: 0.5309
# Epoch 24/50
# 320/320 [==============================] - 128s 400ms/step - loss: 2.0130 - rpn_class_loss: 0.0316 - rpn_bbox_loss: 0.6207 - mrcnn_class_loss: 0.2849 - mrcnn_bbox_loss: 0.5322 - mrcnn_mask_loss: 0.5436 - val_loss: 2.0086 - val_rpn_class_loss: 0.0327 - val_rpn_bbox_loss: 0.6637 - val_mrcnn_class_loss: 0.2539 - val_mrcnn_bbox_loss: 0.5274 - val_mrcnn_mask_loss: 0.5309
# Epoch 25/50
# 320/320 [==============================] - 139s 434ms/step - loss: 1.9716 - rpn_class_loss: 0.0324 - rpn_bbox_loss: 0.5843 - mrcnn_class_loss: 0.2873 - mrcnn_bbox_loss: 0.5354 - mrcnn_mask_loss: 0.5322 - val_loss: 1.8781 - val_rpn_class_loss: 0.0324 - val_rpn_bbox_loss: 0.5196 - val_mrcnn_class_loss: 0.2521 - val_mrcnn_bbox_loss: 0.5372 - val_mrcnn_mask_loss: 0.5369
# Epoch 26/50
# 320/320 [==============================] - 134s 417ms/step - loss: 1.9026 - rpn_class_loss: 0.0305 - rpn_bbox_loss: 0.5508 - mrcnn_class_loss: 0.2754 - mrcnn_bbox_loss: 0.5297 - mrcnn_mask_loss: 0.5161 - val_loss: 1.8862 - val_rpn_class_loss: 0.0299 - val_rpn_bbox_loss: 0.6117 - val_mrcnn_class_loss: 0.2415 - val_mrcnn_bbox_loss: 0.4960 - val_mrcnn_mask_loss: 0.5071
# Epoch 27/50
# 320/320 [==============================] - 132s 412ms/step - loss: 1.9022 - rpn_class_loss: 0.0308 - rpn_bbox_loss: 0.5527 - mrcnn_class_loss: 0.2761 - mrcnn_bbox_loss: 0.5285 - mrcnn_mask_loss: 0.5142 - val_loss: 1.9247 - val_rpn_class_loss: 0.0363 - val_rpn_bbox_loss: 0.5884 - val_mrcnn_class_loss: 0.2803 - val_mrcnn_bbox_loss: 0.5260 - val_mrcnn_mask_loss: 0.4938
# Epoch 28/50
# 320/320 [==============================] - 134s 419ms/step - loss: 1.8618 - rpn_class_loss: 0.0302 - rpn_bbox_loss: 0.5246 - mrcnn_class_loss: 0.2848 - mrcnn_bbox_loss: 0.5133 - mrcnn_mask_loss: 0.5088 - val_loss: 1.7880 - val_rpn_class_loss: 0.0268 - val_rpn_bbox_loss: 0.5432 - val_mrcnn_class_loss: 0.2669 - val_mrcnn_bbox_loss: 0.4709 - val_mrcnn_mask_loss: 0.4801
# Epoch 29/50
# 320/320 [==============================] - 133s 414ms/step - loss: 1.8473 - rpn_class_loss: 0.0286 - rpn_bbox_loss: 0.5348 - mrcnn_class_loss: 0.2694 - mrcnn_bbox_loss: 0.5100 - mrcnn_mask_loss: 0.5045 - val_loss: 1.8567 - val_rpn_class_loss: 0.0310 - val_rpn_bbox_loss: 0.5412 - val_mrcnn_class_loss: 0.2708 - val_mrcnn_bbox_loss: 0.5037 - val_mrcnn_mask_loss: 0.5100
# Epoch 30/50
# 320/320 [==============================] - 127s 396ms/step - loss: 1.8145 - rpn_class_loss: 0.0300 - rpn_bbox_loss: 0.5194 - mrcnn_class_loss: 0.2795 - mrcnn_bbox_loss: 0.4899 - mrcnn_mask_loss: 0.4957 - val_loss: 1.7056 - val_rpn_class_loss: 0.0286 - val_rpn_bbox_loss: 0.4726 - val_mrcnn_class_loss: 0.2525 - val_mrcnn_bbox_loss: 0.4844 - val_mrcnn_mask_loss: 0.4676
# Epoch 31/50
# 320/320 [==============================] - 126s 395ms/step - loss: 1.8001 - rpn_class_loss: 0.0293 - rpn_bbox_loss: 0.5156 - mrcnn_class_loss: 0.2735 - mrcnn_bbox_loss: 0.5008 - mrcnn_mask_loss: 0.4809 - val_loss: 1.7059 - val_rpn_class_loss: 0.0283 - val_rpn_bbox_loss: 0.4761 - val_mrcnn_class_loss: 0.2853 - val_mrcnn_bbox_loss: 0.4518 - val_mrcnn_mask_loss: 0.4643
# Epoch 32/50
# 320/320 [==============================] - 135s 423ms/step - loss: 1.7637 - rpn_class_loss: 0.0253 - rpn_bbox_loss: 0.4941 - mrcnn_class_loss: 0.2705 - mrcnn_bbox_loss: 0.4897 - mrcnn_mask_loss: 0.4841 - val_loss: 1.7562 - val_rpn_class_loss: 0.0237 - val_rpn_bbox_loss: 0.5737 - val_mrcnn_class_loss: 0.2352 - val_mrcnn_bbox_loss: 0.4553 - val_mrcnn_mask_loss: 0.4682
# Epoch 33/50
# 320/320 [==============================] - 138s 430ms/step - loss: 1.7493 - rpn_class_loss: 0.0248 - rpn_bbox_loss: 0.4961 - mrcnn_class_loss: 0.2682 - mrcnn_bbox_loss: 0.4815 - mrcnn_mask_loss: 0.4787 - val_loss: 1.7690 - val_rpn_class_loss: 0.0274 - val_rpn_bbox_loss: 0.5460 - val_mrcnn_class_loss: 0.2403 - val_mrcnn_bbox_loss: 0.4824 - val_mrcnn_mask_loss: 0.4730
# Epoch 34/50
# 320/320 [==============================] - 125s 392ms/step - loss: 1.7453 - rpn_class_loss: 0.0253 - rpn_bbox_loss: 0.4924 - mrcnn_class_loss: 0.2747 - mrcnn_bbox_loss: 0.4740 - mrcnn_mask_loss: 0.4788 - val_loss: 1.7674 - val_rpn_class_loss: 0.0235 - val_rpn_bbox_loss: 0.5504 - val_mrcnn_class_loss: 0.2572 - val_mrcnn_bbox_loss: 0.4629 - val_mrcnn_mask_loss: 0.4733
# Epoch 35/50
# 320/320 [==============================] - 137s 427ms/step - loss: 1.7046 - rpn_class_loss: 0.0251 - rpn_bbox_loss: 0.4722 - mrcnn_class_loss: 0.2640 - mrcnn_bbox_loss: 0.4735 - mrcnn_mask_loss: 0.4697 - val_loss: 1.7063 - val_rpn_class_loss: 0.0246 - val_rpn_bbox_loss: 0.5139 - val_mrcnn_class_loss: 0.2591 - val_mrcnn_bbox_loss: 0.4560 - val_mrcnn_mask_loss: 0.4526
# Epoch 36/50
# 320/320 [==============================] - 129s 402ms/step - loss: 1.7232 - rpn_class_loss: 0.0251 - rpn_bbox_loss: 0.4963 - mrcnn_class_loss: 0.2626 - mrcnn_bbox_loss: 0.4705 - mrcnn_mask_loss: 0.4687 - val_loss: 1.8108 - val_rpn_class_loss: 0.0269 - val_rpn_bbox_loss: 0.5707 - val_mrcnn_class_loss: 0.2736 - val_mrcnn_bbox_loss: 0.4844 - val_mrcnn_mask_loss: 0.4551
# Epoch 37/50
# 320/320 [==============================] - 128s 401ms/step - loss: 1.7292 - rpn_class_loss: 0.0228 - rpn_bbox_loss: 0.4922 - mrcnn_class_loss: 0.2765 - mrcnn_bbox_loss: 0.4739 - mrcnn_mask_loss: 0.4637 - val_loss: 1.6818 - val_rpn_class_loss: 0.0244 - val_rpn_bbox_loss: 0.5454 - val_mrcnn_class_loss: 0.2486 - val_mrcnn_bbox_loss: 0.4288 - val_mrcnn_mask_loss: 0.4347
# Epoch 38/50
# 320/320 [==============================] - 136s 424ms/step - loss: 1.6645 - rpn_class_loss: 0.0209 - rpn_bbox_loss: 0.4685 - mrcnn_class_loss: 0.2678 - mrcnn_bbox_loss: 0.4544 - mrcnn_mask_loss: 0.4528 - val_loss: 1.6767 - val_rpn_class_loss: 0.0286 - val_rpn_bbox_loss: 0.5243 - val_mrcnn_class_loss: 0.2305 - val_mrcnn_bbox_loss: 0.4501 - val_mrcnn_mask_loss: 0.4433
# Epoch 39/50
# 320/320 [==============================] - 136s 425ms/step - loss: 1.6857 - rpn_class_loss: 0.0208 - rpn_bbox_loss: 0.4765 - mrcnn_class_loss: 0.2715 - mrcnn_bbox_loss: 0.4589 - mrcnn_mask_loss: 0.4580 - val_loss: 1.7401 - val_rpn_class_loss: 0.0246 - val_rpn_bbox_loss: 0.5662 - val_mrcnn_class_loss: 0.2521 - val_mrcnn_bbox_loss: 0.4503 - val_mrcnn_mask_loss: 0.4470
# Epoch 40/50
# 320/320 [==============================] - 132s 413ms/step - loss: 1.6572 - rpn_class_loss: 0.0176 - rpn_bbox_loss: 0.4815 - mrcnn_class_loss: 0.2582 - mrcnn_bbox_loss: 0.4469 - mrcnn_mask_loss: 0.4530 - val_loss: 1.6129 - val_rpn_class_loss: 0.0246 - val_rpn_bbox_loss: 0.4640 - val_mrcnn_class_loss: 0.2329 - val_mrcnn_bbox_loss: 0.4544 - val_mrcnn_mask_loss: 0.4370
# Epoch 41/50
# 320/320 [==============================] - 128s 401ms/step - loss: 1.6396 - rpn_class_loss: 0.0195 - rpn_bbox_loss: 0.4624 - mrcnn_class_loss: 0.2679 - mrcnn_bbox_loss: 0.4425 - mrcnn_mask_loss: 0.4472 - val_loss: 1.6304 - val_rpn_class_loss: 0.0237 - val_rpn_bbox_loss: 0.4723 - val_mrcnn_class_loss: 0.2501 - val_mrcnn_bbox_loss: 0.4447 - val_mrcnn_mask_loss: 0.4395
# Epoch 42/50
# 320/320 [==============================] - 131s 410ms/step - loss: 1.5673 - rpn_class_loss: 0.0185 - rpn_bbox_loss: 0.4202 - mrcnn_class_loss: 0.2626 - mrcnn_bbox_loss: 0.4259 - mrcnn_mask_loss: 0.4400 - val_loss: 1.6908 - val_rpn_class_loss: 0.0197 - val_rpn_bbox_loss: 0.5803 - val_mrcnn_class_loss: 0.2628 - val_mrcnn_bbox_loss: 0.4088 - val_mrcnn_mask_loss: 0.4193
# Epoch 43/50
# 320/320 [==============================] - 124s 387ms/step - loss: 1.6249 - rpn_class_loss: 0.0183 - rpn_bbox_loss: 0.4706 - mrcnn_class_loss: 0.2632 - mrcnn_bbox_loss: 0.4332 - mrcnn_mask_loss: 0.4397 - val_loss: 1.5853 - val_rpn_class_loss: 0.0195 - val_rpn_bbox_loss: 0.4872 - val_mrcnn_class_loss: 0.2500 - val_mrcnn_bbox_loss: 0.4138 - val_mrcnn_mask_loss: 0.4147
# Epoch 44/50
# 320/320 [==============================] - 126s 394ms/step - loss: 1.5995 - rpn_class_loss: 0.0164 - rpn_bbox_loss: 0.4535 - mrcnn_class_loss: 0.2628 - mrcnn_bbox_loss: 0.4318 - mrcnn_mask_loss: 0.4350 - val_loss: 1.4920 - val_rpn_class_loss: 0.0154 - val_rpn_bbox_loss: 0.4335 - val_mrcnn_class_loss: 0.2313 - val_mrcnn_bbox_loss: 0.4010 - val_mrcnn_mask_loss: 0.4106
# Epoch 45/50
# 320/320 [==============================] - 139s 435ms/step - loss: 1.6020 - rpn_class_loss: 0.0184 - rpn_bbox_loss: 0.4561 - mrcnn_class_loss: 0.2584 - mrcnn_bbox_loss: 0.4316 - mrcnn_mask_loss: 0.4375 - val_loss: 1.6978 - val_rpn_class_loss: 0.0199 - val_rpn_bbox_loss: 0.5735 - val_mrcnn_class_loss: 0.2290 - val_mrcnn_bbox_loss: 0.4388 - val_mrcnn_mask_loss: 0.4366
# Epoch 46/50
# 320/320 [==============================] - 129s 403ms/step - loss: 1.5723 - rpn_class_loss: 0.0169 - rpn_bbox_loss: 0.4610 - mrcnn_class_loss: 0.2400 - mrcnn_bbox_loss: 0.4236 - mrcnn_mask_loss: 0.4309 - val_loss: 1.5416 - val_rpn_class_loss: 0.0182 - val_rpn_bbox_loss: 0.5499 - val_mrcnn_class_loss: 0.2107 - val_mrcnn_bbox_loss: 0.3693 - val_mrcnn_mask_loss: 0.3935
# Epoch 47/50
# 320/320 [==============================] - 138s 430ms/step - loss: 1.5841 - rpn_class_loss: 0.0163 - rpn_bbox_loss: 0.4522 - mrcnn_class_loss: 0.2539 - mrcnn_bbox_loss: 0.4291 - mrcnn_mask_loss: 0.4326 - val_loss: 1.4902 - val_rpn_class_loss: 0.0154 - val_rpn_bbox_loss: 0.3903 - val_mrcnn_class_loss: 0.2537 - val_mrcnn_bbox_loss: 0.4239 - val_mrcnn_mask_loss: 0.4068
# Epoch 48/50
# 320/320 [==============================] - 126s 393ms/step - loss: 1.5692 - rpn_class_loss: 0.0176 - rpn_bbox_loss: 0.4710 - mrcnn_class_loss: 0.2340 - mrcnn_bbox_loss: 0.4168 - mrcnn_mask_loss: 0.4297 - val_loss: 1.8264 - val_rpn_class_loss: 0.0246 - val_rpn_bbox_loss: 0.6977 - val_mrcnn_class_loss: 0.2430 - val_mrcnn_bbox_loss: 0.4309 - val_mrcnn_mask_loss: 0.4302
# Epoch 49/50
# 320/320 [==============================] - 149s 467ms/step - loss: 1.5831 - rpn_class_loss: 0.0164 - rpn_bbox_loss: 0.4586 - mrcnn_class_loss: 0.2453 - mrcnn_bbox_loss: 0.4348 - mrcnn_mask_loss: 0.4280 - val_loss: 1.6185 - val_rpn_class_loss: 0.0188 - val_rpn_bbox_loss: 0.5506 - val_mrcnn_class_loss: 0.2224 - val_mrcnn_bbox_loss: 0.4177 - val_mrcnn_mask_loss: 0.4089
# Epoch 50/50
# 320/320 [==============================] - 133s 414ms/step - loss: 1.5166 - rpn_class_loss: 0.0164 - rpn_bbox_loss: 0.4286 - mrcnn_class_loss: 0.2406 - mrcnn_bbox_loss: 0.4094 - mrcnn_mask_loss: 0.4216 - val_loss: 1.5010 - val_rpn_class_loss: 0.0141 - val_rpn_bbox_loss: 0.4572 - val_mrcnn_class_loss: 0.2235 - val_mrcnn_bbox_loss: 0.3990 - val_mrcnn_mask_loss: 0.4072

# %%
# select trained model 
dir_names = next(os.walk(model.model_dir))[1]
key = config.NAME.lower()
dir_names = filter(lambda f: f.startswith(key), dir_names)
dir_names = sorted(dir_names)

if not dir_names:
    import errno
    raise FileNotFoundError(
        errno.ENOENT,
        "Could not find model directory under {}".format(self.model_dir))
    
fps = []
# Pick last directory
for d in dir_names: 
    dir_name = os.path.join(model.model_dir, d)
    # Find the last checkpoint
    checkpoints = next(os.walk(dir_name))[2]
    checkpoints = filter(lambda f: f.startswith("mask_rcnn"), checkpoints)
    checkpoints = sorted(checkpoints)
    if not checkpoints:
        print('No weight files in {}'.format(dir_name))
    else: 
      
      checkpoint = os.path.join(dir_name, checkpoints[-1])
      fps.append(checkpoint)

model_path = sorted(fps)[-1]
print('Found model {}'.format(model_path))
# Out:
# No weight files in ../working/pneumonia20180915T1627
# No weight files in ../working/pneumonia20180915T1632
# No weight files in ../working/pneumonia20180915T1643
# No weight files in ../working/pneumonia20180915T1650
# No weight files in ../working/pneumonia20180915T1654
# No weight files in ../working/pneumonia20180915T1731
# No weight files in ../working/pneumonia20180915T1749
# No weight files in ../working/pneumonia20180915T2009
# No weight files in ../working/pneumonia20180915T2012
# No weight files in ../working/pneumonia20180915T2022
# No weight files in ../working/pneumonia20180915T2036
# Found model ../working/pneumonia20180915T2037/mask_rcnn_pneumonia_0050.h5

# %%
class InferenceConfig(DetectorConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode='inference', 
                          config=inference_config,
                          model_dir=ROOT_DIR)

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  ../working/pneumonia20180915T2037/mask_rcnn_pneumonia_0050.h5
# Re-starting from epoch 50

# %%
# set color for class
def get_colors_for_class_ids(class_ids):
    colors = []
    for class_id in class_ids:
        if class_id == 1:
            colors.append((.941, .204, .204))
    return colors

# %% [markdown]
# ### How does the predicted box compared to the expected value? Let's use the validation dataset to check.
#
# Note that we trained only one epoch for **demonstration purposes ONLY**. You might be able to improve performance running more epochs.

# %%
# Show few example of ground truth vs. predictions on the validation dataset 
dataset = dataset_val
fig = plt.figure(figsize=(10, 30))

for i in range(4):

    image_id = random.choice(dataset.image_ids)
    
    original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config, 
                               image_id, use_mini_mask=False)
    
    print(original_image.shape)
    plt.subplot(6, 2, 2*i + 1)
    visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                                dataset.class_names,
                                colors=get_colors_for_class_ids(gt_class_id), ax=fig.axes[-1])
    
    plt.subplot(6, 2, 2*i + 2)
    results = model.detect([original_image]) #, verbose=1)
    r = results[0]
    visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                                dataset.class_names, r['scores'], 
                                colors=get_colors_for_class_ids(r['class_ids']), ax=fig.axes[-1])
# Out:
# (512, 512, 3)
#
# *** No instances to display ***
#
# (512, 512, 3)
#
# *** No instances to display ***
#
# (512, 512, 3)
# (512, 512, 3)

# %%
# Get filenames of test dataset DICOM images
test_image_fps = get_dicom_fps(test_dicom_dir)

# %% [markdown]
# ### Final steps - Create the submission file

# %%
# Make predictions on test images, write out sample submission 
def predict(image_fps, filepath='submission.csv', min_conf=0.95): 
    
    # assume square image
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    #resize_factor = ORIG_SIZE 
    with open(filepath, 'w') as file:
      file.write("patientId,PredictionString\n")
      for image_id in tqdm(image_fps): 
        ds = pydicom.read_file(image_id)
        image = ds.pixel_array
        image = (image - np.mean(image))/np.std(image)
        # If grayscale. Convert to RGB for consistency.
        if len(image.shape) != 3 or image.shape[2] != 3:
            image = np.stack((image,) * 3, -1) 
        image, window, scale, padding, crop = utils.resize_image(
            image,
            min_dim=config.IMAGE_MIN_DIM,
            min_scale=config.IMAGE_MIN_SCALE,
            max_dim=config.IMAGE_MAX_DIM,
            mode=config.IMAGE_RESIZE_MODE)
            
        patient_id = os.path.splitext(os.path.basename(image_id))[0]

        results = model.detect([image])
        r = results[0]

        out_str = ""
        out_str += patient_id 
        out_str += ","
        assert( len(r['rois']) == len(r['class_ids']) == len(r['scores']) )
        if len(r['rois']) == 0: 
            pass
        else: 
            num_instances = len(r['rois'])
  
            for i in range(num_instances): 
                if r['scores'][i] > min_conf: 
                    out_str += ' '
                    out_str += str(round(r['scores'][i], 2))
                    out_str += ' '

                    # x1, y1, width, height 
                    x1 = r['rois'][i][1]
                    y1 = r['rois'][i][0]
                    width = r['rois'][i][3] - x1 
                    height = r['rois'][i][2] - y1 
                    bboxes_str = "{} {} {} {}".format(x1*resize_factor, y1*resize_factor, \
                                                       width*resize_factor, height*resize_factor)   
#                     bboxes_str = "{} {} {} {}".format(x1, y1, \
#                                                       width, height)
                    out_str += bboxes_str

        file.write(out_str+"\n")

# %%
# predict only the first 50 entries
submission_fp = os.path.join(ROOT_DIR, 'submission.csv')
print(submission_fp)
predict(test_image_fps, filepath=submission_fp)
# Out:
#   0%|          | 1/1000 [00:00<01:57,  8.50it/s]
# ../working/submission.csv
# 100%|██████████| 1000/1000 [01:52<00:00,  8.92it/s]

# %%
output = pd.read_csv(submission_fp, names=['patientId', 'PredictionString'])
output.head(100)
# Out:
#                                patientId  \
# 0                              patientId
# 1   232f6bcd-2006-459a-9b30-b51beea28044
# 2   c0760d93-760c-4be7-afca-5e9914e6f8f1
# 3   246bf123-5a0d-4a3d-b4b4-6e442f8a830c
# 4   1505f53a-4da5-416e-a279-66849672051c
# 5   23817810-a792-4c97-a15c-24d3c9da1f3b
# 6   1d5af9ab-1f62-47b2-980f-71e8409d7c3c
# 7   12eddc6c-2d66-4df7-8da1-edd5b5fc81a9
# 8   0e533087-5959-46e5-9fa5-95761a7d472f
# 9   20903dac-37a5-4afb-b88d-18ac705c5c08
# 10  1f7a3519-99e6-4466-9859-5e628bebff73
# 11  c1e73a4e-7afe-4ec5-8af6-ce8315d7a2f2
# 12  26f62d1f-5b9f-4eed-af49-d6a48e8ff3f7
# 13  1d9dde4e-97cc-4163-a3d5-8b845ad60ded
# 14  12f231d5-3a76-48ca-8fda-35f7fc382075
# 15  1c2fbe4f-6785-420d-a7ef-d81b84ff45ec
# 16  29c7e6ff-0de0-499d-9049-c2aae8303cd0
# 17  0fcd1318-e6ae-4d14-b466-769128285665
# 18  23ca6e02-56e8-4872-b323-ded9792a7fa9
# 19  05744f1d-2fa5-41ce-85d3-3df6a7302064
# 20  03c6601a-9044-447d-8521-eca222ea1c1e
# 21  23b10103-d1f2-4180-896a-efde9c4ad10a
# 22  313677e1-a894-4abc-814c-42ce8ab44dde
# 23  27511036-dc83-4708-a928-d0e9f2923299
# 24  2c917d3a-95cb-4c11-802c-f83e28cb37bc
# 25  12ee00f1-d4ea-4546-a07c-d43280aca538
# 26  153fce06-c27b-4eda-8db1-9f1c60ccf4a2
# 27  2a1d9cf8-871f-4aaa-a461-cbefbb880b09
# 28  c04f9256-7358-42ef-b843-19dbf64ef287
# 29  24c876fa-93e4-4dd6-b1f1-a6f5f4aab729
# ..                                   ...
# 70  25b15466-0151-43e1-b52a-830905c853d4
# 71  023558cc-fcca-4fc2-9749-175e2727d49d
# 72  1af50916-9b55-4df5-b1d3-dde1af2bc441
# 73  050068ca-78f7-4394-b8de-6ebe347192e9
# 74  0572881e-d1dd-4757-a54e-b240b30da946
# 75  13b42b81-7e2f-436f-9dd7-63ec96eccb6e
# 76  25f9974d-1a95-48d4-a064-35b709a09ed9
# 77  14a42065-b678-4720-805e-7540d232df8c
# 78  2e974d90-0e16-4c34-9dee-137daa6b54e3
# 79  1ba15f4b-4b0e-4d13-8937-fd3e0d34babe
# 80  1ac5f0e8-f431-4400-b3f5-4a2224e540b2
# 81  308e8db6-f833-45b2-adb7-0f019ff96135
# 82  0dd92ecf-3247-4a0c-a77e-21d20fddcc2a
# 83  1fd15b31-7b21-483d-bbef-e9893d6a051b
# 84  0d2b7272-c9e2-4ab9-a8a6-5806a6572348
# 85  2e827502-06a4-425a-9ee3-9a0accbf3a79
# 86  27feebaa-f4dc-4c68-9348-f0ff35134e43
# 87  03946ed8-d581-4403-b052-753820035d6d
# 88  2a740d72-0dc4-4439-93ed-60cad708d7c4
# 89  1d0386e4-e101-4f48-a7cb-d4d763316d47
# 90  0e245423-3ccd-41ee-84a5-b9f0a20dba71
# 91  0f1a4a99-3a8a-4d4b-be2c-8a003274ed53
# 92  0111d61a-8a5d-4dc8-8c00-7365f8a8de3d
# 93  1c7c7be7-497e-4751-89e4-09d4209a8e2a
# 94  25310577-2bea-495f-b73c-7eff7954571e
# 95  2f42fe81-bd2a-4b14-966b-589873d13663
# 96  05b22cd6-c876-4360-8361-92845c6de8ba
# 97  229c584f-7174-4fcf-b740-7127cbf53525
# 98  0567d70b-5a94-4363-a162-7207ffaff023
# 99  000db696-cf54-4385-b10b-6b16fbb3f985
#
#                                      PredictionString
# 0                                    PredictionString
# 1    0.98 556.0 354.0 322.0 422.0 0.96 126.0 488.0...
# 2                        0.96 654.0 382.0 276.0 428.0
# 3                        0.96 568.0 524.0 298.0 308.0
# 4                        0.96 208.0 578.0 192.0 234.0
# 5    0.96 636.0 474.0 252.0 322.0 0.96 170.0 612.0...
# 6    0.98 592.0 360.0 252.0 278.0 0.97 226.0 424.0...
# 7                        0.96 590.0 406.0 280.0 380.0
# 8                        0.97 214.0 276.0 248.0 306.0
# 9                        0.97 244.0 414.0 216.0 332.0
# 10   0.99 580.0 378.0 260.0 322.0 0.97 226.0 332.0...
# 11   0.98 328.0 450.0 216.0 350.0 0.97 670.0 576.0...
# 12   0.98 572.0 292.0 272.0 432.0 0.96 188.0 386.0...
# 13   0.96 272.0 352.0 242.0 264.0 0.96 640.0 372.0...
# 14                       0.97 478.0 406.0 252.0 402.0
# 15                       0.99 234.0 322.0 204.0 322.0
# 16                       0.95 252.0 388.0 208.0 264.0
# 17                       0.97 582.0 522.0 272.0 286.0
# 18   0.98 282.0 460.0 200.0 274.0 0.98 630.0 448.0...
# 19                       0.98 216.0 374.0 222.0 330.0
# 20                                                NaN
# 21                       0.98 202.0 462.0 232.0 232.0
# 22                       0.98 214.0 444.0 252.0 274.0
# 23                       0.98 580.0 274.0 262.0 356.0
# 24   0.97 532.0 356.0 254.0 368.0 0.96 142.0 596.0...
# 25   0.98 298.0 354.0 250.0 484.0 0.96 640.0 412.0...
# 26                       0.98 198.0 478.0 226.0 264.0
# 27                       0.96 518.0 416.0 248.0 336.0
# 28                       0.98 566.0 454.0 266.0 300.0
# 29                       0.96 602.0 636.0 244.0 278.0
# ..                                                ...
# 70                       0.95 110.0 482.0 210.0 306.0
# 71   0.98 286.0 378.0 230.0 288.0 0.97 646.0 438.0...
# 72                       0.98 258.0 548.0 214.0 208.0
# 73                                                NaN
# 74   0.98 514.0 436.0 246.0 352.0 0.97 250.0 202.0...
# 75   0.97 316.0 390.0 192.0 282.0 0.95 638.0 558.0...
# 76                       0.96 248.0 294.0 224.0 212.0
# 77                       0.97 230.0 420.0 250.0 302.0
# 78                                                NaN
# 79   0.99 216.0 542.0 216.0 208.0 0.98 592.0 454.0...
# 80   0.99 118.0 446.0 256.0 292.0 0.97 520.0 378.0...
# 81                                                NaN
# 82                       0.99 282.0 444.0 226.0 312.0
# 83                       0.96 612.0 456.0 280.0 324.0
# 84                       0.98 186.0 486.0 222.0 340.0
# 85                       0.97 244.0 460.0 234.0 274.0
# 86   0.98 268.0 578.0 238.0 206.0 0.97 646.0 526.0...
# 87   0.97 594.0 476.0 276.0 330.0 0.95 224.0 444.0...
# 88                       0.99 636.0 414.0 302.0 370.0
# 89   0.97 190.0 566.0 202.0 198.0 0.96 586.0 390.0...
# 90   0.98 364.0 274.0 208.0 322.0 0.95 662.0 254.0...
# 91   0.99 176.0 318.0 224.0 446.0 0.95 566.0 214.0...
# 92   0.98 342.0 456.0 200.0 262.0 0.96 664.0 520.0...
# 93                       0.97 500.0 384.0 278.0 414.0
# 94   0.98 132.0 344.0 244.0 410.0 0.95 568.0 470.0...
# 95   0.97 342.0 436.0 190.0 282.0 0.95 682.0 396.0...
# 96   0.98 148.0 460.0 274.0 264.0 0.97 574.0 426.0...
# 97                       0.99 252.0 524.0 208.0 304.0
# 98   0.98 580.0 360.0 294.0 424.0 0.98 186.0 458.0...
# 99                       0.97 626.0 382.0 208.0 398.0
#
# [100 rows x 2 columns]

# %%
## show submission.csv content
#os.chdir(ROOT_DIR)
#!cat submission.csv

# %%
# show a few test image detection example
def visualize(): 
    image_id = random.choice(test_image_fps)
    ds = pydicom.read_file(image_id)
    
    # original image 
    image = ds.pixel_array
    
    # assume square image 
    resize_factor = ORIG_SIZE / config.IMAGE_SHAPE[0]
    
    # If grayscale. Convert to RGB for consistency.
    if len(image.shape) != 3 or image.shape[2] != 3:
        image = np.stack((image,) * 3, -1) 
    resized_image, window, scale, padding, crop = utils.resize_image(
        image,
        min_dim=config.IMAGE_MIN_DIM,
        min_scale=config.IMAGE_MIN_SCALE,
        max_dim=config.IMAGE_MAX_DIM,
        mode=config.IMAGE_RESIZE_MODE)

    patient_id = os.path.splitext(os.path.basename(image_id))[0]
    print(patient_id)

    results = model.detect([resized_image])
    r = results[0]
    for bbox in r['rois']: 
        print(bbox)
        x1 = int(bbox[1] * resize_factor)
        y1 = int(bbox[0] * resize_factor)
        x2 = int(bbox[3] * resize_factor)
        y2 = int(bbox[2]  * resize_factor)
        cv2.rectangle(image, (x1,y1), (x2,y2), (77, 255, 9), 3, 1)
        width = x2 - x1 
        height = y2 - y1 
        print("x {} y {} h {} w {}".format(x1, y1, width, height))
    plt.figure() 
    plt.imshow(image, cmap=plt.cm.gist_gray)

# %%
# remove files to allow committing (hit files limit otherwise)
#!rm -rf /kaggle/working/Mask_RCNN

# %%
visualize()
visualize()
visualize()
visualize()
visualize()
visualize()
# Out:
# 2f6ac842-e243-4c5f-a48c-d70862e316d5
# [188 124 356 235]
# x 248 y 376 h 222 w 336
# 22956af6-6152-4458-a39d-a45706b8a96c
# [246 127 386 241]
# x 254 y 492 h 228 w 280
# [261 340 432 468]
# x 680 y 522 h 256 w 342
# 2a5752c7-6f90-4c5f-a5bd-9dd7736097ef
# [205  83 342 186]
# x 166 y 410 h 206 w 274
# 2c376b9a-167a-43d3-bcc2-b4af32fb9f74
# [271 111 416 241]
# x 222 y 542 h 260 w 290
# [ 67 102 163 218]
# x 204 y 134 h 232 w 192
# 0479d585-4e1e-44b3-aabe-4aa8437a54c5
# [ 75 138 165 249]
# x 276 y 150 h 222 w 180
# [161 105 309 224]
# x 210 y 322 h 238 w 296
# 27feebaa-f4dc-4c68-9348-f0ff35134e43
# [288 134 393 253]
# x 268 y 576 h 238 w 210
# [261 324 420 442]
# x 648 y 522 h 236 w 318
